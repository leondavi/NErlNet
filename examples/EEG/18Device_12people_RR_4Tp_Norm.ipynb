# %% [raw]
# This Experimnet is:
# z score normalization was applied
# 18 Devices
# 12 workers
# 12 people- each person send to 2 workers with RR policy
#
# There is 4 training phase, and 1 prediction phase.
# training phases 1-2 ->person 1-6
# training phases 3-4 ->person 7-12

# %%
import set_jupyter_env
from apiServer import *
import pandas as pd

# %%
API = ApiServer()

# %%
API.showJsons()
# Out:
# Distributed Configuration Files
# --------------------
#
# 0.	dc_10w_14d_8r_3s_10c_synt.json
# 1.	dc_12w_12c_13d_4s_4r_tiles_rr.json
# 2.	dc_5d_4c_4s_4r_12w.json
# 3.	dc_AEC_1d_2c_1s_4r_4w.json
# 4.	dc_EEG_18d_12c_6s_10r_12w_RR.json
# 5.	dc_EEG_18d_9c_3s_5r_9w_RR.json
# 6.	dc_EEG_1d_1c_3s_2r_3w_RR.json
# 7.	dc_EEG_4d_3c_3s_2r_3w.json
# 8.	dc_EEG_8d_1c_3s_2r_3w_RR.json
# 9.	dc_EEG_8d_3c_3s_2r_3w.json
# 10.	dc_EEG_8d_3c_3s_2r_3w_RR.json
# 11.	dc_EEG_8d_3c_3s_2r_3w_demo_RR.json
# 12.	dc_EEG_8d_3c_3s_5r_3w_RR.json
# 13.	dc_EEG_8d_8c_3s_5r_8w_RR.json
# 14.	dc_FedTorchTest_5d_2s_2r_4c_4w.json
# 15.	dc_dist_14d.json
# 16.	dc_dist_2d_3c_2s_3r_6w.json
# 17.	dc_fed_dist_14d.json
# 18.	dc_fed_dist_2d_3c_2s_3r_6w.json
# 19.	dc_fed_synt_1d_2c_2r_1s_4w_1ws.json
# 20.	dc_mnist_13d_12w_4r_3s_3tokens.json
# 21.	dc_mnist_4w_5d_4r_4s_rr.json
# 22.	dc_synt_8d_8w_2c_4s_4r.json
# 23.	dc_synt_8d_8w_4c_6r_4s.json
# 24.	dc_synt_distributed_w5_c3_6r_3s_3d.json
# 25.	dc_test_synt_1d_2c_1s_4r_4w.json
# 26.	dc_test_synt_1d_2c_2s_4r_4w.json
#
# Connection Map Files
# --------------------
#
# 0.	conn_1Router1Client1S.json
# 1.	conn_1Router1Client2S.json
# 2.	conn_1Router2Clients1S.json
# 3.	conn_1Router3Clients1S.json
# 4.	conn_1Router4Clients1S.json
# 5.	conn_1Router4Clients1fed.json
# 6.	conn_1Router4Clients2Sources.json
# 7.	conn_1Router4Clients2Sources1fed.json
# 8.	conn_2R4C1S_health_david.json
# 9.	conn_2Router2Clients1Source.json
# 10.	conn_2Router2Clients1Source_david.json
# 11.	conn_2Router2Clients2Source.json
# 12.	conn_2Router2ClientsGUI.json
# 13.	conn_2Router3Clients.json
# 14.	conn_3Router3Clients.json
# 15.	conn_4Router12Client4S.json
# 16.	conn_4Router4Client4S.json
# 17.	conn_4Router4Clients4S_mnist.json
# 18.	conn_6RouterCycle6Clients1Source.json
# 19.	conn_6RouterCycle8Clients1Source.json
# 20.	conn_6RouterLine6Clients1Source.json
# 21.	conn_8RouterCycle8Clients1Source.json
# 22.	conn_8Routers10Clients3S.json
# 23.	conn_EEG_10Router12Clients6Source_EEG.json
# 24.	conn_EEG_2Router1Clients3Source_EEG.json
# 25.	conn_EEG_2Router3Clients3Source_EEG.json
# 26.	conn_EEG_5Router3Clients3Source_EEG.json
# 27.	conn_EEG_5Router8Clients3Source_EEG.json
# 28.	conn_EEG_5Router9Clients3Source_EEG.json
# 29.	conn_EEG_M10Router12Clients6Source_EEG.json
# 30.	conn_fed_dist_14d.json
# 31.	conn_fed_dist_2d_3c_2s_3r_6w.json
# 32.	conn_fed_synt_1d_2c_2r_1s_4w_1ws.json
# 33.	conn_synt_8d_8w_4c_6r_4s.json
# 34.	conn_synt_dc_8d_8w_2c_4s_4r.json
# 35.	conn_synt_distributed_w5_c3_6r_3s_3d.json
# 36.	conn_test_synt_1d_2c_1s_4r_4w.json
# 37.	conn_test_synt_1d_2c_2s_4r_4w.json
#
# Experiments Flow Files
# --------------------
#
# 0.	exp_AEC_1d_2c_1s_4r_4w.json
# 1.	exp_EEG_1s_3w_small_sample_RR.json
# 2.	exp_EEG_3c_3s_2r_3w_3people.json
# 3.	exp_EEG_3c_3s_2r_3w_half3_people.json
# 4.	exp_EEG_3c_3s_2r_3w_half3_people_3exp_tr_phase.json
# 5.	exp_EEG_3s_3w_half3_people_RR.json
# 6.	exp_EEG_3s_8w_3_people_RR.json
# 7.	exp_EEG_3s_8w_3people_RR.json
# 8.	exp_EEG_3s_8w_half3_people_RR.json
# 9.	exp_EEG_3s_9w_3people_RR.json
# 10.	exp_EEG_6s_12w_12people_RR_4Tp.json
# 11.	exp_EEG_6s_12w_6people_RR_1Tp.json
# 12.	exp_EEG_6s_12w_6people_RR_2Tp.json
# 13.	exp_EEG_6s_12w_6people_RR_2Tp_CMTest.json
# 14.	exp_EEG_norm_6s_12w_12people_RR_4Tp.json
# 15.	exp_FedTorchTest_5d_2s_2r_4c_4w.json
# 16.	exp_dist_14d.json
# 17.	exp_dist_14d_10c_3s_8r_10w.json
# 18.	exp_dist_2d_3c_2s_3r_6w.json
# 19.	exp_fed_dist_14d.json
# 20.	exp_fed_dist_2d_3c_2s_3r_6w.json
# 21.	exp_fed_synt_1d_2c_2r_1s_4w_1ws.json
# 22.	exp_mnist_5d_4c_4s_4w_4r.json
# 23.	exp_new_arc.json
# 24.	exp_synt_8d_8w_2c_4s_4r.json
# 25.	exp_synt_8d_8w_4c_6r_4s.json
# 26.	exp_synt_distributed_w5_c3_6r_3s_3d.json
# 27.	exp_test_synt_1d_2c_1s_4r_4w new.json
# 28.	exp_tiles_13d_12c_4s_4r_12w_rr.json
# 29.	exp_tiles_4d_4c_4s_4r_12w.json

# %%
dc = 4
conn = 29
exp = 14
API.setJsons(dc , conn , exp)

# %%
dc_path , conn_path , exp_path = API.getUserJsons()

# %%
exp_name = "EEG_Emotion_18Devices_12Persons_RR"
API.initialization(exp_name, dc_path, conn_path, exp_path)
# Out:
# [INFO][2024-08-08 07:13:28,372]
# Network components:
#                  Receiver's Address: http://10.0.0.11:8930
#                  Frequency: 5 [batches/sec]
#                  Batchsize: 10 [samples]
#                  devicesIp: ['10.0.0.11', '10.0.0.8', '10.0.0.12', '10.0.0.10', '10.0.0.32', '10.0.0.33', '10.0.0.34', '10.0.0.35', '10.0.0.47', '10.0.0.48', '10.0.0.49', '10.0.0.50', '10.0.0.51', '10.0.0.52', '10.0.0.53', '10.0.0.54', '10.0.0.55', '10.0.0.56']
#                  mainServerIp: 10.0.0.11
#                  mainServerPort: 8900
#                  apiServerIp: 10.0.0.11
#                  apiServerPort: 8930
#                  Clients: ['c1', 'c2', 'c3', 'c4', 'c5', 'c6', 'c7', 'c8', 'c9', 'c10', 'c11', 'c12']
#                  Workers: ['w1', 'w2', 'w3', 'w4', 'w5', 'w6', 'w7', 'w8', 'w9', 'w10', 'w11', 'w12']
#                  Sources: ['s1', 's2', 's3', 's4', 's5', 's6']
#                  Routers: ['r1', 'r2', 'r3', 'r4', 'r5', 'r6', 'r7', 'r8', 'r9', 'rms']
# [INFO][2024-08-08 07:13:28,373] Connections:
# [INFO][2024-08-08 07:13:28,376] 		 rms : ['mainServer', 'r1', 'r2', 'r3', 'r4', 'r5', 'r6', 'r7', 'r8', 'r9']
# [INFO][2024-08-08 07:13:28,377] 		 r1 : ['c1', 'c2', 'r2']
# [INFO][2024-08-08 07:13:28,378] 		 r2 : ['c3', 'c4', 'r3']
# [INFO][2024-08-08 07:13:28,378] 		 r3 : ['c5', 'c6', 'r4']
# [INFO][2024-08-08 07:13:28,380] 		 r4 : ['c7', 'c8', 'r5']
# [INFO][2024-08-08 07:13:28,380] 		 r5 : ['c9', 'c10', 'r6']
# [INFO][2024-08-08 07:13:28,381] 		 r6 : ['c11', 'c12', 'r7']
# [INFO][2024-08-08 07:13:28,381] 		 r7 : ['s1', 's2', 'r8', 'r4', 'r2', 'r5']
# [INFO][2024-08-08 07:13:28,382] 		 r8 : ['s3', 's4', 'r9', 'r3', 'r4', 'r1']
# [INFO][2024-08-08 07:13:28,382] 		 r9 : ['s5', 's6', 'r3', 'r5', 'r1', 'r6', 'r2']
# [INFO][2024-08-08 07:13:28,383] Experiment name: EEG_Valence_Recognition_DEAP
# [INFO][2024-08-08 07:13:28,383] Batch size: 10
# [INFO][2024-08-08 07:13:28,384] Number of features: 70
# [INFO][2024-08-08 07:13:28,384] Number of labels: 9
# [INFO][2024-08-08 07:13:28,385]
# [INFO][2024-08-08 07:13:28,385] Phases:
# [INFO][2024-08-08 07:13:28,386]    Phase name: training_phase1
# [INFO][2024-08-08 07:13:28,386]    Phase type: training
# [INFO][2024-08-08 07:13:28,387]    Sources: s1,s2,s3,s4,s5,s6
# [INFO][2024-08-08 07:13:28,387]
# [INFO][2024-08-08 07:13:28,391]     Source pieces:
# [INFO][2024-08-08 07:13:28,391]          Source name: s1
# [INFO][2024-08-08 07:13:28,392]          Batch size: 10
# [INFO][2024-08-08 07:13:28,393]          Phase: training
# [INFO][2024-08-08 07:13:28,393]          Starting offset: 10
# [INFO][2024-08-08 07:13:28,397]          Number of batches: 780
# [INFO][2024-08-08 07:13:28,398]          Workers target: w1,w2
# [INFO][2024-08-08 07:13:28,398]       ----------------------
# [INFO][2024-08-08 07:13:28,399]
# [INFO][2024-08-08 07:13:28,399]          Source name: s2
# [INFO][2024-08-08 07:13:28,400]          Batch size: 10
# [INFO][2024-08-08 07:13:28,401]          Phase: training
# [INFO][2024-08-08 07:13:28,401]          Starting offset: 19520
# [INFO][2024-08-08 07:13:28,402]          Number of batches: 780
# [INFO][2024-08-08 07:13:28,403]          Workers target: w3,w4
# [INFO][2024-08-08 07:13:28,403]       ----------------------
# [INFO][2024-08-08 07:13:28,403]
# [INFO][2024-08-08 07:13:28,404]          Source name: s3
# [INFO][2024-08-08 07:13:28,404]          Batch size: 10
# [INFO][2024-08-08 07:13:28,405]          Phase: training
# [INFO][2024-08-08 07:13:28,405]          Starting offset: 39040
# [INFO][2024-08-08 07:13:28,406]          Number of batches: 780
# [INFO][2024-08-08 07:13:28,407]          Workers target: w5,w6
# [INFO][2024-08-08 07:13:28,407]       ----------------------
# [INFO][2024-08-08 07:13:28,408]
# [INFO][2024-08-08 07:13:28,408]          Source name: s4
# [INFO][2024-08-08 07:13:28,408]          Batch size: 10
# [INFO][2024-08-08 07:13:28,409]          Phase: training
# [INFO][2024-08-08 07:13:28,410]          Starting offset: 58650
# [INFO][2024-08-08 07:13:28,410]          Number of batches: 780
# [INFO][2024-08-08 07:13:28,411]          Workers target: w7,w8
# [INFO][2024-08-08 07:13:28,411]       ----------------------
# [INFO][2024-08-08 07:13:28,412]
# [INFO][2024-08-08 07:13:28,412]          Source name: s5
# [INFO][2024-08-08 07:13:28,413]          Batch size: 10
# [INFO][2024-08-08 07:13:28,413]          Phase: training
# [INFO][2024-08-08 07:13:28,414]          Starting offset: 78170
# [INFO][2024-08-08 07:13:28,414]          Number of batches: 780
# [INFO][2024-08-08 07:13:28,415]          Workers target: w9,w10
# [INFO][2024-08-08 07:13:28,415]       ----------------------
# [INFO][2024-08-08 07:13:28,416]
# [INFO][2024-08-08 07:13:28,416]          Source name: s6
# [INFO][2024-08-08 07:13:28,417]          Batch size: 10
# [INFO][2024-08-08 07:13:28,417]          Phase: training
# [INFO][2024-08-08 07:13:28,418]          Starting offset: 97690
# [INFO][2024-08-08 07:13:28,418]          Number of batches: 780
# [INFO][2024-08-08 07:13:28,419]          Workers target: w11,w12
# [INFO][2024-08-08 07:13:28,419]       ----------------------
# [INFO][2024-08-08 07:13:28,420]
# [INFO][2024-08-08 07:13:28,420]    Phase name: training_phase2
# [INFO][2024-08-08 07:13:28,421]    Phase type: training
# [INFO][2024-08-08 07:13:28,421]    Sources: s1,s2,s3,s4,s5,s6
# [INFO][2024-08-08 07:13:28,422]
# [INFO][2024-08-08 07:13:28,422]     Source pieces:
# [INFO][2024-08-08 07:13:28,423]          Source name: s1
# [INFO][2024-08-08 07:13:28,425]          Batch size: 10
# [INFO][2024-08-08 07:13:28,425]          Phase: training
# [INFO][2024-08-08 07:13:28,426]          Starting offset: 7810
# [INFO][2024-08-08 07:13:28,427]          Number of batches: 780
# [INFO][2024-08-08 07:13:28,427]          Workers target: w1,w2
# [INFO][2024-08-08 07:13:28,428]       ----------------------
# [INFO][2024-08-08 07:13:28,428]
# [INFO][2024-08-08 07:13:28,429]          Source name: s2
# [INFO][2024-08-08 07:13:28,429]          Batch size: 10
# [INFO][2024-08-08 07:13:28,432]          Phase: training
# [INFO][2024-08-08 07:13:28,433]          Starting offset: 27325
# [INFO][2024-08-08 07:13:28,434]          Number of batches: 780
# [INFO][2024-08-08 07:13:28,434]          Workers target: w3,w4
# [INFO][2024-08-08 07:13:28,435]       ----------------------
# [INFO][2024-08-08 07:13:28,435]
# [INFO][2024-08-08 07:13:28,436]          Source name: s3
# [INFO][2024-08-08 07:13:28,436]          Batch size: 10
# [INFO][2024-08-08 07:13:28,438]          Phase: training
# [INFO][2024-08-08 07:13:28,438]          Starting offset: 46845
# [INFO][2024-08-08 07:13:28,439]          Number of batches: 780
# [INFO][2024-08-08 07:13:28,439]          Workers target: w5,w6
# [INFO][2024-08-08 07:13:28,439]       ----------------------
# [INFO][2024-08-08 07:13:28,440]
# [INFO][2024-08-08 07:13:28,441]          Source name: s4
# [INFO][2024-08-08 07:13:28,441]          Batch size: 10
# [INFO][2024-08-08 07:13:28,442]          Phase: training
# [INFO][2024-08-08 07:13:28,442]          Starting offset: 66455
# [INFO][2024-08-08 07:13:28,443]          Number of batches: 780
# [INFO][2024-08-08 07:13:28,443]          Workers target: w7,w8
# [INFO][2024-08-08 07:13:28,444]       ----------------------
# [INFO][2024-08-08 07:13:28,444]
# [INFO][2024-08-08 07:13:28,445]          Source name: s5
# [INFO][2024-08-08 07:13:28,446]          Batch size: 10
# [INFO][2024-08-08 07:13:28,446]          Phase: training
# [INFO][2024-08-08 07:13:28,447]          Starting offset: 85975
# [INFO][2024-08-08 07:13:28,447]          Number of batches: 780
# [INFO][2024-08-08 07:13:28,448]          Workers target: w9,w10
# [INFO][2024-08-08 07:13:28,448]       ----------------------
# [INFO][2024-08-08 07:13:28,449]
# [INFO][2024-08-08 07:13:28,449]          Source name: s6
# [INFO][2024-08-08 07:13:28,450]          Batch size: 10
# [INFO][2024-08-08 07:13:28,450]          Phase: training
# [INFO][2024-08-08 07:13:28,451]          Starting offset: 105495
# [INFO][2024-08-08 07:13:28,451]          Number of batches: 780
# [INFO][2024-08-08 07:13:28,452]          Workers target: w11,w12
# [INFO][2024-08-08 07:13:28,452]       ----------------------
# [INFO][2024-08-08 07:13:28,453]
# [INFO][2024-08-08 07:13:28,454]    Phase name: training_phase3
# [INFO][2024-08-08 07:13:28,454]    Phase type: training
# [INFO][2024-08-08 07:13:28,455]    Sources: s1,s2,s3,s4,s5,s6
# [INFO][2024-08-08 07:13:28,455]
# [INFO][2024-08-08 07:13:28,456]     Source pieces:
# [INFO][2024-08-08 07:13:28,456]          Source name: s1
# [INFO][2024-08-08 07:13:28,457]          Batch size: 10
# [INFO][2024-08-08 07:13:28,457]          Phase: training
# [INFO][2024-08-08 07:13:28,458]          Starting offset: 17120
# [INFO][2024-08-08 07:13:28,458]          Number of batches: 780
# [INFO][2024-08-08 07:13:28,459]          Workers target: w1,w2
# [INFO][2024-08-08 07:13:28,459]       ----------------------
# [INFO][2024-08-08 07:13:28,460]
# [INFO][2024-08-08 07:13:28,460]          Source name: s2
# [INFO][2024-08-08 07:13:28,461]          Batch size: 10
# [INFO][2024-08-08 07:13:28,461]          Phase: training
# [INFO][2024-08-08 07:13:28,462]          Starting offset: 136640
# [INFO][2024-08-08 07:13:28,466]          Number of batches: 780
# [INFO][2024-08-08 07:13:28,467]          Workers target: w3,w4
# [INFO][2024-08-08 07:13:28,468]       ----------------------
# [INFO][2024-08-08 07:13:28,468]
# [INFO][2024-08-08 07:13:28,469]          Source name: s3
# [INFO][2024-08-08 07:13:28,469]          Batch size: 10
# [INFO][2024-08-08 07:13:28,470]          Phase: training
# [INFO][2024-08-08 07:13:28,470]          Starting offset: 145160
# [INFO][2024-08-08 07:13:28,471]          Number of batches: 780
# [INFO][2024-08-08 07:13:28,471]          Workers target: w5,w6
# [INFO][2024-08-08 07:13:28,472]       ----------------------
# [INFO][2024-08-08 07:13:28,472]
# [INFO][2024-08-08 07:13:28,473]          Source name: s4
# [INFO][2024-08-08 07:13:28,473]          Batch size: 10
# [INFO][2024-08-08 07:13:28,474]          Phase: training
# [INFO][2024-08-08 07:13:28,474]          Starting offset: 175680
# [INFO][2024-08-08 07:13:28,475]          Number of batches: 780
# [INFO][2024-08-08 07:13:28,475]          Workers target: w7,w8
# [INFO][2024-08-08 07:13:28,476]       ----------------------
# [INFO][2024-08-08 07:13:28,476]
# [INFO][2024-08-08 07:13:28,477]          Source name: s5
# [INFO][2024-08-08 07:13:28,477]          Batch size: 10
# [INFO][2024-08-08 07:13:28,478]          Phase: training
# [INFO][2024-08-08 07:13:28,479]          Starting offset: 195200
# [INFO][2024-08-08 07:13:28,480]          Number of batches: 780
# [INFO][2024-08-08 07:13:28,480]          Workers target: w9,w10
# [INFO][2024-08-08 07:13:28,482]       ----------------------
# [INFO][2024-08-08 07:13:28,483]
# [INFO][2024-08-08 07:13:28,483]          Source name: s6
# [INFO][2024-08-08 07:13:28,484]          Batch size: 10
# [INFO][2024-08-08 07:13:28,484]          Phase: training
# [INFO][2024-08-08 07:13:28,485]          Starting offset: 214720
# [INFO][2024-08-08 07:13:28,485]          Number of batches: 780
# [INFO][2024-08-08 07:13:28,486]          Workers target: w11,w12
# [INFO][2024-08-08 07:13:28,486]       ----------------------
# [INFO][2024-08-08 07:13:28,486]
# [INFO][2024-08-08 07:13:28,487]    Phase name: training_phase4
# [INFO][2024-08-08 07:13:28,487]    Phase type: training
# [INFO][2024-08-08 07:13:28,488]    Sources: s1,s2,s3,s4,s5,s6
# [INFO][2024-08-08 07:13:28,488]
# [INFO][2024-08-08 07:13:28,489]     Source pieces:
# [INFO][2024-08-08 07:13:28,489]          Source name: s1
# [INFO][2024-08-08 07:13:28,490]          Batch size: 10
# [INFO][2024-08-08 07:13:28,490]          Phase: training
# [INFO][2024-08-08 07:13:28,491]          Starting offset: 124925
# [INFO][2024-08-08 07:13:28,491]          Number of batches: 780
# [INFO][2024-08-08 07:13:28,492]          Workers target: w1,w2
# [INFO][2024-08-08 07:13:28,494]       ----------------------
# [INFO][2024-08-08 07:13:28,495]
# [INFO][2024-08-08 07:13:28,495]          Source name: s2
# [INFO][2024-08-08 07:13:28,496]          Batch size: 10
# [INFO][2024-08-08 07:13:28,496]          Phase: training
# [INFO][2024-08-08 07:13:28,497]          Starting offset: 144445
# [INFO][2024-08-08 07:13:28,497]          Number of batches: 780
# [INFO][2024-08-08 07:13:28,498]          Workers target: w3,w4
# [INFO][2024-08-08 07:13:28,498]       ----------------------
# [INFO][2024-08-08 07:13:28,499]
# [INFO][2024-08-08 07:13:28,499]          Source name: s3
# [INFO][2024-08-08 07:13:28,500]          Batch size: 10
# [INFO][2024-08-08 07:13:28,500]          Phase: training
# [INFO][2024-08-08 07:13:28,501]          Starting offset: 163965
# [INFO][2024-08-08 07:13:28,501]          Number of batches: 780
# [INFO][2024-08-08 07:13:28,502]          Workers target: w5,w6
# [INFO][2024-08-08 07:13:28,502]       ----------------------
# [INFO][2024-08-08 07:13:28,503]
# [INFO][2024-08-08 07:13:28,503]          Source name: s4
# [INFO][2024-08-08 07:13:28,504]          Batch size: 10
# [INFO][2024-08-08 07:13:28,504]          Phase: training
# [INFO][2024-08-08 07:13:28,505]          Starting offset: 183485
# [INFO][2024-08-08 07:13:28,505]          Number of batches: 780
# [INFO][2024-08-08 07:13:28,506]          Workers target: w7,w8
# [INFO][2024-08-08 07:13:28,506]       ----------------------
# [INFO][2024-08-08 07:13:28,507]
# [INFO][2024-08-08 07:13:28,507]          Source name: s5
# [INFO][2024-08-08 07:13:28,508]          Batch size: 10
# [INFO][2024-08-08 07:13:28,508]          Phase: training
# [INFO][2024-08-08 07:13:28,509]          Starting offset: 203005
# [INFO][2024-08-08 07:13:28,510]          Number of batches: 780
# [INFO][2024-08-08 07:13:28,510]          Workers target: w9,w10
# [INFO][2024-08-08 07:13:28,511]       ----------------------
# [INFO][2024-08-08 07:13:28,511]
# [INFO][2024-08-08 07:13:28,512]          Source name: s6
# [INFO][2024-08-08 07:13:28,512]          Batch size: 10
# [INFO][2024-08-08 07:13:28,513]          Phase: training
# [INFO][2024-08-08 07:13:28,513]          Starting offset: 222525
# [INFO][2024-08-08 07:13:28,514]          Number of batches: 780
# [INFO][2024-08-08 07:13:28,514]          Workers target: w11,w12
# [INFO][2024-08-08 07:13:28,515]       ----------------------
# [INFO][2024-08-08 07:13:28,515]
# [INFO][2024-08-08 07:13:28,516]    Phase name: prediction_phase
# [INFO][2024-08-08 07:13:28,516]    Phase type: prediction
# [INFO][2024-08-08 07:13:28,517]    Sources: s1,s2,s3,s4,s5,s6
# [INFO][2024-08-08 07:13:28,517]
# [INFO][2024-08-08 07:13:28,518]     Source pieces:
# [INFO][2024-08-08 07:13:28,522]          Source name: s1
# [INFO][2024-08-08 07:13:28,522]          Batch size: 10
# [INFO][2024-08-08 07:13:28,523]          Phase: prediction
# [INFO][2024-08-08 07:13:28,523]          Starting offset: 15610
# [INFO][2024-08-08 07:13:28,524]          Number of batches: 391
# [INFO][2024-08-08 07:13:28,524]          Workers target: w1,w2
# [INFO][2024-08-08 07:13:28,525]       ----------------------
# [INFO][2024-08-08 07:13:28,525]
# [INFO][2024-08-08 07:13:28,525]          Source name: s2
# [INFO][2024-08-08 07:13:28,526]          Batch size: 10
# [INFO][2024-08-08 07:13:28,527]          Phase: prediction
# [INFO][2024-08-08 07:13:28,527]          Starting offset: 35130
# [INFO][2024-08-08 07:13:28,528]          Number of batches: 391
# [INFO][2024-08-08 07:13:28,528]          Workers target: w3,w4
# [INFO][2024-08-08 07:13:28,528]       ----------------------
# [INFO][2024-08-08 07:13:28,529]
# [INFO][2024-08-08 07:13:28,529]          Source name: s3
# [INFO][2024-08-08 07:13:28,530]          Batch size: 10
# [INFO][2024-08-08 07:13:28,530]          Phase: prediction
# [INFO][2024-08-08 07:13:28,530]          Starting offset: 54650
# [INFO][2024-08-08 07:13:28,531]          Number of batches: 391
# [INFO][2024-08-08 07:13:28,531]          Workers target: w5,w6
# [INFO][2024-08-08 07:13:28,532]       ----------------------
# [INFO][2024-08-08 07:13:28,532]
# [INFO][2024-08-08 07:13:28,532]          Source name: s4
# [INFO][2024-08-08 07:13:28,533]          Batch size: 10
# [INFO][2024-08-08 07:13:28,533]          Phase: prediction
# [INFO][2024-08-08 07:13:28,534]          Starting offset: 74260
# [INFO][2024-08-08 07:13:28,534]          Number of batches: 391
# [INFO][2024-08-08 07:13:28,535]          Workers target: w7,w8
# [INFO][2024-08-08 07:13:28,535]       ----------------------
# [INFO][2024-08-08 07:13:28,535]
# [INFO][2024-08-08 07:13:28,536]          Source name: s5
# [INFO][2024-08-08 07:13:28,536]          Batch size: 10
# [INFO][2024-08-08 07:13:28,537]          Phase: prediction
# [INFO][2024-08-08 07:13:28,537]          Starting offset: 93780
# [INFO][2024-08-08 07:13:28,537]          Number of batches: 391
# [INFO][2024-08-08 07:13:28,538]          Workers target: w9,w10
# [INFO][2024-08-08 07:13:28,538]       ----------------------
# [INFO][2024-08-08 07:13:28,539]
# [INFO][2024-08-08 07:13:28,539]          Source name: s6
# [INFO][2024-08-08 07:13:28,539]          Batch size: 10
# [INFO][2024-08-08 07:13:28,540]          Phase: prediction
# [INFO][2024-08-08 07:13:28,540]          Starting offset: 113300
# [INFO][2024-08-08 07:13:28,541]          Number of batches: 391
# [INFO][2024-08-08 07:13:28,541]          Workers target: w11,w12
# [INFO][2024-08-08 07:13:28,541]       ----------------------
# [INFO][2024-08-08 07:13:28,542]
# [INFO][2024-08-08 07:13:28,542] Initializing ApiServer receiver thread
#  * Serving Flask app 'receiver'
#  * Debug mode: off
# [INFO][2024-08-08 07:13:30,552] *** Remember to execute NerlnetRun.sh on each device before running the experiment! ***

# %%
# %pip install networkx pygraphviz
import networkx as nx
def visualize_nerlnet_graph(api_server_inst,  connections : dict , components): # connections is a dictionary with keys as routers and values as lists of their neighbors
    print("Connections: " , list(connections.items()))
    routers = list(connections.keys())
    print("Routers: " , routers)
    workers = list(components.map_worker_to_client.keys())
    print("Workers: " , workers)
    graph = nx.Graph()
    nodes = routers + components.sources + components.clients + workers + [API_SERVER_STR , MAIN_SERVER_STR]
    edges = [] # list of tuples
    for router , neighbors in list(connections.items()):
        for neighbor in neighbors:
            if (router,neighbor) not in edges:
                print(f"Adding edge ({router} , {neighbor}) to graph")
                edges.append((router , neighbor))
    edges.append((API_SERVER_STR , MAIN_SERVER_STR)) # Always connected
    for worker in workers:
        edges.append((worker , components.map_worker_to_client[worker]))
    graph.add_nodes_from(nodes)
    graph.add_edges_from(edges)
    
    my_labels = {'mainServer': 'mS' , 'apiServer': 'aS'}
    nx.relabel_nodes(graph, my_labels , copy=False)
    
    default_colors = {node:'#A90433' for node in graph.nodes()}
    node_colors = {node:default_colors[node] for node in graph.nodes()}
    nx.set_node_attributes(graph, node_colors, 'color')
    colors = nx.get_node_attributes(graph, 'color').values()

    pos = nx.nx_agraph.graphviz_layout(graph)
    angle = 100
    
    plt.figure(figsize=(8,6),dpi=150)
    nx.draw_networkx(graph, pos, with_labels=True, node_color=colors , node_size=200, font_size=8, font_color='white' , edge_color='black' , width=1.5)
    plt.show()
visualize_nerlnet_graph(API , API.json_dir_parser.json_from_path(conn_path)['connectionsMap'] , globe.components)
# Out:
# Requirement already satisfied: networkx in /tmp/nerlnet/virtualenv/lib/python3.8/site-packages (3.1)
# Requirement already satisfied: pygraphviz in /tmp/nerlnet/virtualenv/lib/python3.8/site-packages (1.11)
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Connections:  [('rms', ['mainServer', 'r1', 'r2', 'r3', 'r4', 'r5', 'r6', 'r7', 'r8', 'r9']), ('r1', ['c1', 'c2', 'r2']), ('r2', ['c3', 'c4', 'r3']), ('r3', ['c5', 'c6', 'r4']), ('r4', ['c7', 'c8', 'r5']), ('r5', ['c9', 'c10', 'r6']), ('r6', ['c11', 'c12', 'r7']), ('r7', ['s1', 's2', 'r8', 'r4', 'r2', 'r5']), ('r8', ['s3', 's4', 'r9', 'r3', 'r4', 'r1']), ('r9', ['s5', 's6', 'r3', 'r5', 'r1', 'r6', 'r2'])]
# Routers:  ['rms', 'r1', 'r2', 'r3', 'r4', 'r5', 'r6', 'r7', 'r8', 'r9']
# Workers:  ['w1', 'w2', 'w3', 'w4', 'w5', 'w6', 'w7', 'w8', 'w9', 'w10', 'w11', 'w12']
# Adding edge (rms , mainServer) to graph
# Adding edge (rms , r1) to graph
# Adding edge (rms , r2) to graph
# Adding edge (rms , r3) to graph
# Adding edge (rms , r4) to graph
# Adding edge (rms , r5) to graph
# Adding edge (rms , r6) to graph
# Adding edge (rms , r7) to graph
# Adding edge (rms , r8) to graph
# Adding edge (rms , r9) to graph
# Adding edge (r1 , c1) to graph
# Adding edge (r1 , c2) to graph
# Adding edge (r1 , r2) to graph
# Adding edge (r2 , c3) to graph
# Adding edge (r2 , c4) to graph
# Adding edge (r2 , r3) to graph
# Adding edge (r3 , c5) to graph
# Adding edge (r3 , c6) to graph
# Adding edge (r3 , r4) to graph
# Adding edge (r4 , c7) to graph
# Adding edge (r4 , c8) to graph
# Adding edge (r4 , r5) to graph
# Adding edge (r5 , c9) to graph
# Adding edge (r5 , c10) to graph
# Adding edge (r5 , r6) to graph
# Adding edge (r6 , c11) to graph
# Adding edge (r6 , c12) to graph
# Adding edge (r6 , r7) to graph
# Adding edge (r7 , s1) to graph
# Adding edge (r7 , s2) to graph
# Adding edge (r7 , r8) to graph
# Adding edge (r7 , r4) to graph
# Adding edge (r7 , r2) to graph
# Adding edge (r7 , r5) to graph
# Adding edge (r8 , s3) to graph
# Adding edge (r8 , s4) to graph
# Adding edge (r8 , r9) to graph
# Adding edge (r8 , r3) to graph
# Adding edge (r8 , r4) to graph
# Adding edge (r8 , r1) to graph
# Adding edge (r9 , s5) to graph
# Adding edge (r9 , s6) to graph
# Adding edge (r9 , r3) to graph
# Adding edge (r9 , r5) to graph
# Adding edge (r9 , r1) to graph
# Adding edge (r9 , r6) to graph
# Adding edge (r9 , r2) to graph

# %%
API.send_jsons_to_devices()
# Out:
# [INFO][2024-08-08 07:13:34,544] Sending distributed configurations to devices is completed

# %%
API.run_current_experiment_phase()
# Out:
# [INFO][2024-08-08 07:13:34,553] Experiment phase: training_phase1 of type training starts running...
# [INFO][2024-08-08 07:13:34,554] Sending data to sources
# [INFO][2024-08-08 07:14:28,865] Data is ready in sources
# [INFO][2024-08-08 07:14:28,985] Phase training requested from Main Server

# %%
stats_train1 = API.get_experiment_flow(exp_name).generate_stats()

# %%
stats_train1.get_loss_ts(plot=True)

# %%
import pandas as pd
workers_comm_dict = stats_train1.get_communication_stats_workers()
df_train = pd.DataFrame.from_dict(workers_comm_dict)
plt.figure()
df_selected_train = df_train.iloc[[3,5]]
data_train = pd.melt(df_selected_train.reset_index(), id_vars=['index'], value_vars=df_train.columns)
batches_stats = sns.barplot(x='variable', y='value', hue='index', data=data_train)
plt.ylabel('Number Of Batches')
plt.xlabel('Worker')
plt.title("Received & Dropped Batches At Freq. 5B/s (Training1 Phase)")

batches_stats.legend(loc='upper right', bbox_to_anchor=(1.5, 0.2), shadow=True, ncol=1)
plt.show()

# %%
missed_dict = stats_train1.get_missed_batches()
print(missed_dict)

# %%
API.next_experiment_phase()
API.run_current_experiment_phase()

# %%
stats_train2 = API.get_experiment_flow(exp_name).generate_stats()

# %%
stats_train2.get_loss_ts(plot=True)

# %%
import pandas as pd
workers_comm_dict = stats_train2.get_communication_stats_workers()
df_train = pd.DataFrame.from_dict(workers_comm_dict)
plt.figure()
df_selected_train = df_train.iloc[[3,5]]
data_train = pd.melt(df_selected_train.reset_index(), id_vars=['index'], value_vars=df_train.columns)
batches_stats = sns.barplot(x='variable', y='value', hue='index', data=data_train)
plt.ylabel('Number Of Batches')
plt.xlabel('Worker')
plt.title("Received & Dropped Batches At Freq. 5B/s (Training2 Phase)")

batches_stats.legend(loc='upper right', bbox_to_anchor=(1.5, 0.2), shadow=True, ncol=1)
plt.show()

# %%
API.next_experiment_phase()
API.run_current_experiment_phase()

# %%
stats_train3 = API.get_experiment_flow(exp_name).generate_stats()

# %%
stats_train3.get_loss_ts(plot=True)

# %%
import pandas as pd
workers_comm_dict = stats_train3.get_communication_stats_workers()
df_train = pd.DataFrame.from_dict(workers_comm_dict)
plt.figure()
df_selected_train = df_train.iloc[[3,5]]
data_train = pd.melt(df_selected_train.reset_index(), id_vars=['index'], value_vars=df_train.columns)
batches_stats = sns.barplot(x='variable', y='value', hue='index', data=data_train)
plt.ylabel('Number Of Batches')
plt.xlabel('Worker')
plt.title("Received & Dropped Batches At Freq. 5B/s (Training3 Phase)")

batches_stats.legend(loc='upper right', bbox_to_anchor=(1.5, 0.2), shadow=True, ncol=1)
plt.show()

# %%
API.next_experiment_phase()
API.run_current_experiment_phase()

# %%
stats_train4 = API.get_experiment_flow(exp_name).generate_stats()

# %%
stats_train4.get_loss_ts(plot=True)

# %%
import pandas as pd
workers_comm_dict = stats_train4.get_communication_stats_workers()
df_train = pd.DataFrame.from_dict(workers_comm_dict)
plt.figure()
df_selected_train = df_train.iloc[[3,5]]
data_train = pd.melt(df_selected_train.reset_index(), id_vars=['index'], value_vars=df_train.columns)
batches_stats = sns.barplot(x='variable', y='value', hue='index', data=data_train)
plt.ylabel('Number Of Batches')
plt.xlabel('Worker')
plt.title("Received & Dropped Batches At Freq. 5B/s (Training4 Phase)")

batches_stats.legend(loc='upper right', bbox_to_anchor=(1.5, 0.2), shadow=True, ncol=1)
plt.show()

# %%
API.next_experiment_phase()
API.run_current_experiment_phase()

# %%
stats_pred = API.get_experiment_flow(exp_name).generate_stats()

# %%
import pandas as pd
workers_comm_dict = stats_pred.get_communication_stats_workers()
df_pred = pd.DataFrame.from_dict(workers_comm_dict)
plt.figure()
df_selected_pred = df_pred.iloc[[4,6]]
data_pred = pd.melt(df_selected_pred.reset_index(), id_vars=['index'], value_vars=df_pred.columns)
batches_stats = sns.barplot(x='variable', y='value', hue='index', data=data_pred)
plt.ylabel('Number Of Batches')
plt.xlabel('Worker')
plt.title("Received & Dropped Batches At Freq. 5B/s (Prediction Phase)")

batches_stats.legend(loc='upper right', bbox_to_anchor=(1.5, 0.2), shadow=True, ncol=1)
plt.show()

# %%
_ , conf_mats = stats_pred.get_confusion_matrices(plot=True)
