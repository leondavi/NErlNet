# %%
import set_jupyter_env
from apiServer import *
import pandas as pd

# %%
API = ApiServer()

# %%
API.showJsons()
# Out:
# Distributed Configuration Files
# --------------------
#
# 0.	dc_10w_14d_8r_3s_10c_synt.json
# 1.	dc_12w_12c_13d_4s_4r_tiles_rr.json
# 2.	dc_5d_4c_4s_4r_12w.json
# 3.	dc_AEC_1d_2c_1s_4r_4w.json
# 4.	dc_EEG_18d_12c_6s_10r_12w_RR.json
# 5.	dc_EEG_18d_9c_3s_5r_9w_RR.json
# 6.	dc_EEG_1d_1c_3s_2r_3w_RR.json
# 7.	dc_EEG_1d_2c_1s_4r_4w.json
# 8.	dc_EEG_3d_1c_1s_1r_1w.json
# 9.	dc_EEG_4d_3c_3s_2r_3w.json
# 10.	dc_EEG_8d_1c_3s_2r_3w_RR.json
# 11.	dc_EEG_8d_3c_3s_2r_3w.json
# 12.	dc_EEG_8d_3c_3s_2r_3w_RR.json
# 13.	dc_EEG_8d_3c_3s_2r_3w_demo_RR.json
# 14.	dc_EEG_8d_3c_3s_5r_3w_RR.json
# 15.	dc_EEG_8d_8c_3s_5r_8w_RR.json
# 16.	dc_FedTorchTest_5d_2s_2r_4c_4w.json
# 17.	dc_dist_14d.json
# 18.	dc_dist_2d_3c_2s_3r_6w.json
# 19.	dc_fed_dist_14d.json
# 20.	dc_fed_dist_2d_3c_2s_3r_6w.json
# 21.	dc_fed_synt_1d_2c_2r_1s_4w_1ws.json
# 22.	dc_mnist_13d_12w_4r_3s_3tokens.json
# 23.	dc_mnist_4w_5d_4r_4s_rr.json
# 24.	dc_synt_8d_8w_2c_4s_4r.json
# 25.	dc_synt_8d_8w_4c_6r_4s.json
# 26.	dc_synt_distributed_w5_c3_6r_3s_3d.json
# 27.	dc_test_synt_1d_2c_1s_4r_4w.json
# 28.	dc_test_synt_1d_2c_2s_4r_4w.json
#
# Connection Map Files
# --------------------
#
# 0.	conn_1Router1Client1S.json
# 1.	conn_1Router1Client2S.json
# 2.	conn_1Router2Clients1S.json
# 3.	conn_1Router3Clients1S.json
# 4.	conn_1Router4Clients1S.json
# 5.	conn_1Router4Clients1fed.json
# 6.	conn_1Router4Clients2Sources.json
# 7.	conn_1Router4Clients2Sources1fed.json
# 8.	conn_2R4C1S_health_david.json
# 9.	conn_2Router2Clients1Source.json
# 10.	conn_2Router2Clients1Source_david.json
# 11.	conn_2Router2Clients2Source.json
# 12.	conn_2Router2ClientsGUI.json
# 13.	conn_2Router3Clients.json
# 14.	conn_3Router3Clients.json
# 15.	conn_4Router12Client4S.json
# 16.	conn_4Router4Client4S.json
# 17.	conn_4Router4Clients4S_mnist.json
# 18.	conn_6RouterCycle6Clients1Source.json
# 19.	conn_6RouterCycle8Clients1Source.json
# 20.	conn_6RouterLine6Clients1Source.json
# 21.	conn_8RouterCycle8Clients1Source.json
# 22.	conn_8Routers10Clients3S.json
# 23.	conn_EEG_10Router12Clients6Source_EEG.json
# 24.	conn_EEG_1Router1Clients1Source_EEG.json
# 25.	conn_EEG_1d_2c_1s_4r_4w.json
# 26.	conn_EEG_2Router1Clients3Source_EEG.json
# 27.	conn_EEG_2Router3Clients3Source_EEG.json
# 28.	conn_EEG_5Router3Clients3Source_EEG.json
# 29.	conn_EEG_5Router8Clients3Source_EEG.json
# 30.	conn_EEG_5Router9Clients3Source_EEG.json
# 31.	conn_EEG_M10Router12Clients6Source_EEG.json
# 32.	conn_fed_dist_14d.json
# 33.	conn_fed_dist_2d_3c_2s_3r_6w.json
# 34.	conn_fed_synt_1d_2c_2r_1s_4w_1ws.json
# 35.	conn_synt_8d_8w_4c_6r_4s.json
# 36.	conn_synt_dc_8d_8w_2c_4s_4r.json
# 37.	conn_synt_distributed_w5_c3_6r_3s_3d.json
# 38.	conn_test_synt_1d_2c_1s_4r_4w.json
# 39.	conn_test_synt_1d_2c_2s_4r_4w.json
#
# Experiments Flow Files
# --------------------
#
# 0.	exp_AEC_1d_2c_1s_4r_4w.json
# 1.	exp_EEG_1d_2c_1s_4r_4w.json
# 2.	exp_EEG_1s_1w_10epochs.json
# 3.	exp_EEG_1s_1w_10phase.json
# 4.	exp_EEG_1s_3w_small_sample_RR.json
# 5.	exp_EEG_3c_3s_2r_3w_3people.json
# 6.	exp_EEG_3c_3s_2r_3w_half3_people.json
# 7.	exp_EEG_3c_3s_2r_3w_half3_people_3exp_tr_phase.json
# 8.	exp_EEG_3s_3w_half3_people_RR.json
# 9.	exp_EEG_3s_8w_3_people_RR.json
# 10.	exp_EEG_3s_8w_3people_RR.json
# 11.	exp_EEG_3s_8w_3people_RR_2Tp.json
# 12.	exp_EEG_3s_8w_half3_people_RR.json
# 13.	exp_EEG_3s_9w_3people_RR.json
# 14.	exp_EEG_6s_12w_12people_RR_4Tp.json
# 15.	exp_EEG_6s_12w_6people_RR_1Tp.json
# 16.	exp_EEG_6s_12w_6people_RR_2Tp.json
# 17.	exp_EEG_6s_12w_6people_RR_2Tp_CMTest.json
# 18.	exp_EEG_norm_1s_1w_1pepole.json
# 19.	exp_EEG_norm_6s_12w_12people_RR_4Tp.json
# 20.	exp_EEG_norm_6s_12w_18people_RR_6Tp.json
# 21.	exp_EEG_norm_6s_12w_24people_RR_8Tp.json
# 22.	exp_FedTorchTest_5d_2s_2r_4c_4w.json
# 23.	exp_dist_14d.json
# 24.	exp_dist_14d_10c_3s_8r_10w.json
# 25.	exp_dist_2d_3c_2s_3r_6w.json
# 26.	exp_fed_dist_14d.json
# 27.	exp_fed_dist_2d_3c_2s_3r_6w.json
# 28.	exp_fed_synt_1d_2c_2r_1s_4w_1ws.json
# 29.	exp_mnist_5d_4c_4s_4w_4r.json
# 30.	exp_new_arc.json
# 31.	exp_synt_8d_8w_2c_4s_4r.json
# 32.	exp_synt_8d_8w_4c_6r_4s.json
# 33.	exp_synt_distributed_w5_c3_6r_3s_3d.json
# 34.	exp_test_synt_1d_2c_1s_4r_4w new.json
# 35.	exp_tiles_13d_12c_4s_4r_12w_rr.json
# 36.	exp_tiles_4d_4c_4s_4r_12w.json

# %%
dc = 8
conn = 24
exp = 2
API.setJsons(dc , conn , exp)

# %%
dc_path , conn_path , exp_path = API.getUserJsons()

# %%
exp_name = "EEG_Emotion_confusion_Matrix_test"
API.initialization(exp_name, dc_path, conn_path, exp_path)
# Out:
# [INFO][2024-08-11 15:01:56,123]
# Network components:
#                  Receiver's Address: http://10.0.0.11:9000
#                  Frequency: 2 [batches/sec]
#                  Batchsize: 10 [samples]
#                  devicesIp: ['10.0.0.11', '10.0.0.8', '10.0.0.12']
#                  mainServerIp: 10.0.0.11
#                  mainServerPort: 8900
#                  apiServerIp: 10.0.0.11
#                  apiServerPort: 9000
#                  Clients: ['c1']
#                  Workers: ['w1']
#                  Sources: ['s1']
#                  Routers: ['r1']
# [INFO][2024-08-11 15:01:56,124] Connections:
# [INFO][2024-08-11 15:01:56,124] 		 r1 : ['mainServer', 'c1', 's1']
# [INFO][2024-08-11 15:01:56,126] Experiment name: EEG_Valence_Recognition_DEAP
# [INFO][2024-08-11 15:01:56,129] Batch size: 10
# [INFO][2024-08-11 15:01:56,130] Number of features: 70
# [INFO][2024-08-11 15:01:56,131] Number of labels: 9
# [INFO][2024-08-11 15:01:56,132]
# [INFO][2024-08-11 15:01:56,134] Phases:
# [INFO][2024-08-11 15:01:56,135]    Phase name: training_phase
# [INFO][2024-08-11 15:01:56,136]    Phase type: training
# [INFO][2024-08-11 15:01:56,137]    Sources: s1
# [INFO][2024-08-11 15:01:56,138]
# [INFO][2024-08-11 15:01:56,139]     Source pieces:
# [INFO][2024-08-11 15:01:56,140]          Source name: s1
# [INFO][2024-08-11 15:01:56,141]          Batch size: 10
# [INFO][2024-08-11 15:01:56,142]          Phase: training
# [INFO][2024-08-11 15:01:56,143]          Starting offset: 10
# [INFO][2024-08-11 15:01:56,144]          Number of batches: 100
# [INFO][2024-08-11 15:01:56,144]          Workers target: w1
# [INFO][2024-08-11 15:01:56,145]       ----------------------
# [INFO][2024-08-11 15:01:56,147]
# [INFO][2024-08-11 15:01:56,148]    Phase name: prediction_phase1
# [INFO][2024-08-11 15:01:56,149]    Phase type: prediction
# [INFO][2024-08-11 15:01:56,149]    Sources: s1
# [INFO][2024-08-11 15:01:56,150]
# [INFO][2024-08-11 15:01:56,150]     Source pieces:
# [INFO][2024-08-11 15:01:56,151]          Source name: s1
# [INFO][2024-08-11 15:01:56,152]          Batch size: 10
# [INFO][2024-08-11 15:01:56,152]          Phase: prediction
# [INFO][2024-08-11 15:01:56,153]          Starting offset: 10
# [INFO][2024-08-11 15:01:56,153]          Number of batches: 10
# [INFO][2024-08-11 15:01:56,154]          Workers target: w1
# [INFO][2024-08-11 15:01:56,154]       ----------------------
# [INFO][2024-08-11 15:01:56,155]
# [INFO][2024-08-11 15:01:56,155]    Phase name: prediction_phase2
# [INFO][2024-08-11 15:01:56,156]    Phase type: prediction
# [INFO][2024-08-11 15:01:56,156]    Sources: s1
# [INFO][2024-08-11 15:01:56,157]
# [INFO][2024-08-11 15:01:56,157]     Source pieces:
# [INFO][2024-08-11 15:01:56,158]          Source name: s1
# [INFO][2024-08-11 15:01:56,158]          Batch size: 10
# [INFO][2024-08-11 15:01:56,159]          Phase: prediction
# [INFO][2024-08-11 15:01:56,159]          Starting offset: 15610
# [INFO][2024-08-11 15:01:56,159]          Number of batches: 10
# [INFO][2024-08-11 15:01:56,160]          Workers target: w1
# [INFO][2024-08-11 15:01:56,160]       ----------------------
# [INFO][2024-08-11 15:01:56,161]
# [INFO][2024-08-11 15:01:56,161] Initializing ApiServer receiver thread
#  * Serving Flask app 'receiver'
#  * Debug mode: off
# [INFO][2024-08-11 15:01:58,166] *** Remember to execute NerlnetRun.sh on each device before running the experiment! ***

# %%
# %pip install networkx pygraphviz
import networkx as nx
def visualize_nerlnet_graph(api_server_inst,  connections : dict , components): # connections is a dictionary with keys as routers and values as lists of their neighbors
    print("Connections: " , list(connections.items()))
    routers = list(connections.keys())
    print("Routers: " , routers)
    workers = list(components.map_worker_to_client.keys())
    print("Workers: " , workers)
    graph = nx.Graph()
    nodes = routers + components.sources + components.clients + workers + [API_SERVER_STR , MAIN_SERVER_STR]
    edges = [] # list of tuples
    for router , neighbors in list(connections.items()):
        for neighbor in neighbors:
            if (router,neighbor) not in edges:
                print(f"Adding edge ({router} , {neighbor}) to graph")
                edges.append((router , neighbor))
    edges.append((API_SERVER_STR , MAIN_SERVER_STR)) # Always connected
    for worker in workers:
        edges.append((worker , components.map_worker_to_client[worker]))
    graph.add_nodes_from(nodes)
    graph.add_edges_from(edges)
    
    my_labels = {'mainServer': 'mS' , 'apiServer': 'aS'}
    nx.relabel_nodes(graph, my_labels , copy=False)
    
    default_colors = {node:'#A90433' for node in graph.nodes()}
    node_colors = {node:default_colors[node] for node in graph.nodes()}
    nx.set_node_attributes(graph, node_colors, 'color')
    colors = nx.get_node_attributes(graph, 'color').values()

    pos = nx.nx_agraph.graphviz_layout(graph)
    angle = 100
    
    plt.figure(figsize=(8,6),dpi=150)
    nx.draw_networkx(graph, pos, with_labels=True, node_color=colors , node_size=200, font_size=8, font_color='white' , edge_color='black' , width=1.5)
    plt.show()
visualize_nerlnet_graph(API , API.json_dir_parser.json_from_path(conn_path)['connectionsMap'] , globe.components)
# Out:
# Requirement already satisfied: networkx in /tmp/nerlnet/virtualenv/lib/python3.8/site-packages (3.1)
# Requirement already satisfied: pygraphviz in /tmp/nerlnet/virtualenv/lib/python3.8/site-packages (1.11)
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Connections:  [('r1', ['mainServer', 'c1', 's1'])]
# Routers:  ['r1']
# Workers:  ['w1']
# Adding edge (r1 , mainServer) to graph
# Adding edge (r1 , c1) to graph
# Adding edge (r1 , s1) to graph

# %%
API.send_jsons_to_devices()
# Out:
# [INFO][2024-08-11 15:02:00,881] Sending distributed configurations to devices is completed

# %%
API.run_current_experiment_phase()
# Out:
# [INFO][2024-08-11 15:02:00,888] Experiment phase: training_phase of type training starts running...
# [INFO][2024-08-11 15:02:00,889] Sending data to sources
# [INFO][2024-08-11 15:02:01,699] Data is ready in sources
# [INFO][2024-08-11 15:02:01,700] Phase training requested from Main Server
# [INFO][2024-08-11 15:08:22,941] Processing experiment phase data
# [INFO][2024-08-11 15:08:22,953] Processing experiment phase data completed
# [INFO][2024-08-11 15:08:22,954] Start generating communication statistics for training_phase of type training
# [INFO][2024-08-11 15:08:22,955] Statistics requested from Main Server
# [INFO][2024-08-11 15:08:23,360] Statistics received from Main Server
# [INFO][2024-08-11 15:08:23,361] Phase of training_phase training completed

# %%
stats_train1 = API.get_experiment_flow(exp_name).generate_stats()

# %%
loss_ts = stats_train1.get_loss_ts(plot=True, smoothing = True, log_plot = True)

# %%
stats_train1.plot_batches_status(plot=True)

# %%
missed_dict = stats_train1.get_missed_batches()
print(missed_dict)
# Out:
# {}

# %%
API.next_experiment_phase()
API.run_current_experiment_phase()
# Out:
# [INFO][2024-08-11 15:08:24,120] Experiment phase: prediction_phase1 of type prediction starts running...
# [INFO][2024-08-11 15:08:24,121] Sending data to sources
# [INFO][2024-08-11 15:08:24,319] Data is ready in sources
# [INFO][2024-08-11 15:08:24,320] Phase prediction requested from Main Server
# [INFO][2024-08-11 15:08:29,141] Processing experiment phase data
# [INFO][2024-08-11 15:08:29,143] Processing experiment phase data completed
# [INFO][2024-08-11 15:08:29,143] Start generating communication statistics for prediction_phase1 of type prediction
# [INFO][2024-08-11 15:08:29,144] Statistics requested from Main Server
# [INFO][2024-08-11 15:08:29,549] Statistics received from Main Server
# [INFO][2024-08-11 15:08:29,551] Phase of prediction_phase1 prediction completed

# %%
stats_pred = API.get_experiment_flow(exp_name).generate_stats()

# %%
stats_pred.plot_batches_status(plot=True)

# %%
_ , conf_mats_workers = stats_pred.get_confusion_matrices(plot = True)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 _ , conf_mats_workers = stats_pred.get_confusion_matrices(plot = True)
#
# File /usr/local/lib/nerlnet-lib/NErlNet/src_py/apiServer/stats.py:272, in Stats.get_confusion_matrices(self, normalize, plot, saveToFile)
#     270 for j , pred_class in enumerate(classes):
#     271     conf_mat = confusion_matrix_worker_dict[(worker , pred_class)]
# --> 272     heatmap = sns.heatmap(data=conf_mat ,ax=ax[i,j], annot=True , fmt="d", cmap='Blues',annot_kws={"size": 8}, cbar_kws={'pad': 0.1})
#     273     cbar = heatmap.collections[0].colorbar
#     274     cbar.ax.tick_params(labelsize = 8)
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed
