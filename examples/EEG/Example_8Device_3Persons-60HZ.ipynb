# %%
import set_jupyter_env
from apiServer import *
import pandas as pd

# %%
API = ApiServer()

# %%
API.showJsons()
# Out:
# Distributed Configuration Files
# --------------------
#
# 0.	dc_10w_14d_8r_3s_10c_synt.json
# 1.	dc_AEC_1d_2c_1s_4r_4w.json
# 2.	dc_EEG_4d_3c_3s_2r_3w.json
# 3.	dc_EEG_8d_3c_3s_2r_3w.json
# 4.	dc_dist_14d.json
# 5.	dc_dist_2d_3c_2s_3r_6w.json
# 6.	dc_fed_dist_14d.json
# 7.	dc_fed_dist_2d_3c_2s_3r_6w.json
# 8.	dc_fed_synt_1d_2c_2r_1s_4w_1ws.json
# 9.	dc_synt_8d_8w_2c_4s_4r.json
# 10.	dc_synt_8d_8w_4c_6r_4s.json
# 11.	dc_synt_distributed_w5_c3_6r_3s_3d.json
# 12.	dc_test_synt_1d_2c_1s_4r_4w.json
# 13.	dc_test_synt_1d_2c_2s_4r_4w.json
#
# Connection Map Files
# --------------------
#
# 0.	conn_1Router1Client1S.json
# 1.	conn_1Router1Client2S.json
# 2.	conn_1Router2Clients1S.json
# 3.	conn_1Router3Clients1S.json
# 4.	conn_1Router4Clients1S.json
# 5.	conn_1Router4Clients1fed.json
# 6.	conn_1Router4Clients2Sources.json
# 7.	conn_1Router4Clients2Sources1fed.json
# 8.	conn_2R4C1S_health_david.json
# 9.	conn_2Router2Clients1Source.json
# 10.	conn_2Router2Clients1Source_david.json
# 11.	conn_2Router2Clients2Source.json
# 12.	conn_2Router2ClientsGUI.json
# 13.	conn_2Router3Clients.json
# 14.	conn_3Router3Clients.json
# 15.	conn_6RouterCycle6Clients1Source.json
# 16.	conn_6RouterCycle8Clients1Source.json
# 17.	conn_6RouterLine6Clients1Source.json
# 18.	conn_8RouterCycle8Clients1Source.json
# 19.	conn_8Routers10Clients3S.json
# 20.	conn_EEG_2Router3Clients3Source_EEG.json
# 21.	conn_fed_dist_14d.json
# 22.	conn_fed_dist_2d_3c_2s_3r_6w.json
# 23.	conn_fed_synt_1d_2c_2r_1s_4w_1ws.json
# 24.	conn_synt_8d_8w_4c_6r_4s.json
# 25.	conn_synt_dc_8d_8w_2c_4s_4r.json
# 26.	conn_synt_distributed_w5_c3_6r_3s_3d.json
# 27.	conn_test_synt_1d_2c_1s_4r_4w.json
# 28.	conn_test_synt_1d_2c_2s_4r_4w.json
#
# Experiments Flow Files
# --------------------
#
# 0.	exp_AEC_1d_2c_1s_4r_4w.json
# 1.	exp_EEG_3c_3s_2r_1w_half3_people.json
# 2.	exp_EEG_3c_3s_2r_3w_3people.json
# 3.	exp_dist_14d.json
# 4.	exp_dist_14d_10c_3s_8r_10w.json
# 5.	exp_dist_2d_3c_2s_3r_6w.json
# 6.	exp_fed_dist_14d.json
# 7.	exp_fed_dist_2d_3c_2s_3r_6w.json
# 8.	exp_fed_synt_1d_2c_2r_1s_4w_1ws.json
# 9.	exp_new_arc.json
# 10.	exp_synt_8d_8w_2c_4s_4r.json
# 11.	exp_synt_8d_8w_4c_6r_4s.json
# 12.	exp_synt_distributed_w5_c3_6r_3s_3d.json
# 13.	exp_test_synt_1d_2c_1s_4r_4w new.json

# %%
dc = 3
conn = 20
exp = 1
API.setJsons(dc , conn , exp)

# %%
dc_path , conn_path , exp_path = API.getUserJsons()

# %%
exp_name = "EEG_Emotion_8Devices_3Persons_half"
API.initialization(exp_name, dc_path, conn_path, exp_path)
# Out:
# [INFO][2024-07-17 16:27:07,097]
# Network components:
#                  Receiver's Address: http://10.0.0.11:8901
#                  Frequency: 60 [batches/sec]
#                  Batchsize: 5 [samples]
#                  devicesIp: ['10.0.0.11', '10.0.0.8', '10.0.0.12', '10.0.0.10', '10.0.0.32', '10.0.0.33', '10.0.0.34', '10.0.0.35']
#                  mainServerIp: 10.0.0.11
#                  mainServerPort: 8900
#                  apiServerIp: 10.0.0.11
#                  apiServerPort: 8901
#                  Clients: ['c1', 'c2', 'c3']
#                  Workers: ['w1', 'w2', 'w3']
#                  Sources: ['s1', 's2', 's3']
#                  Routers: ['r1', 'r2']
# [INFO][2024-07-17 16:27:07,098] Connections:
# [INFO][2024-07-17 16:27:07,099] 		 r1 : ['mainServer', 'c1', 'c2', 'c3', 'r2']
# [INFO][2024-07-17 16:27:07,099] 		 r2 : ['s1', 's2', 's3', 'r1']
# [INFO][2024-07-17 16:27:07,100] Experiment name: EEG_Valence_Recognition_DEAP
# [INFO][2024-07-17 16:27:07,100] Batch size: 5
# [INFO][2024-07-17 16:27:07,101] Number of features: 70
# [INFO][2024-07-17 16:27:07,101] Number of labels: 9
# [INFO][2024-07-17 16:27:07,102]
# [INFO][2024-07-17 16:27:07,102] Phases:
# [INFO][2024-07-17 16:27:07,103]    Phase name: training_phase
# [INFO][2024-07-17 16:27:07,104]    Phase type: training
# [INFO][2024-07-17 16:27:07,105]    Sources: s1,s2,s3
# [INFO][2024-07-17 16:27:07,106]
# [INFO][2024-07-17 16:27:07,106]     Source pieces:
# [INFO][2024-07-17 16:27:07,108]          Source name: s1
# [INFO][2024-07-17 16:27:07,108]          Batch size: 5
# [INFO][2024-07-17 16:27:07,109]          Phase: training
# [INFO][2024-07-17 16:27:07,112]          Starting offset: 0
# [INFO][2024-07-17 16:27:07,113]          Number of batches: 800
# [INFO][2024-07-17 16:27:07,115]          Workers target: w1
# [INFO][2024-07-17 16:27:07,115]       ----------------------
# [INFO][2024-07-17 16:27:07,116]
# [INFO][2024-07-17 16:27:07,117]          Source name: s2
# [INFO][2024-07-17 16:27:07,117]          Batch size: 5
# [INFO][2024-07-17 16:27:07,118]          Phase: training
# [INFO][2024-07-17 16:27:07,118]          Starting offset: 19520
# [INFO][2024-07-17 16:27:07,122]          Number of batches: 800
# [INFO][2024-07-17 16:27:07,126]          Workers target: w2
# [INFO][2024-07-17 16:27:07,127]       ----------------------
# [INFO][2024-07-17 16:27:07,127]
# [INFO][2024-07-17 16:27:07,128]          Source name: s3
# [INFO][2024-07-17 16:27:07,128]          Batch size: 5
# [INFO][2024-07-17 16:27:07,129]          Phase: training
# [INFO][2024-07-17 16:27:07,129]          Starting offset: 39040
# [INFO][2024-07-17 16:27:07,130]          Number of batches: 800
# [INFO][2024-07-17 16:27:07,130]          Workers target: w3
# [INFO][2024-07-17 16:27:07,131]       ----------------------
# [INFO][2024-07-17 16:27:07,132]
# [INFO][2024-07-17 16:27:07,132]    Phase name: prediction_phase
# [INFO][2024-07-17 16:27:07,132]    Phase type: prediction
# [INFO][2024-07-17 16:27:07,133]    Sources: s1,s2,s3
# [INFO][2024-07-17 16:27:07,135]
# [INFO][2024-07-17 16:27:07,136]     Source pieces:
# [INFO][2024-07-17 16:27:07,136]          Source name: s1
# [INFO][2024-07-17 16:27:07,138]          Batch size: 5
# [INFO][2024-07-17 16:27:07,138]          Phase: prediction
# [INFO][2024-07-17 16:27:07,139]          Starting offset: 15610
# [INFO][2024-07-17 16:27:07,139]          Number of batches: 200
# [INFO][2024-07-17 16:27:07,140]          Workers target: w1
# [INFO][2024-07-17 16:27:07,140]       ----------------------
# [INFO][2024-07-17 16:27:07,140]
# [INFO][2024-07-17 16:27:07,141]          Source name: s2
# [INFO][2024-07-17 16:27:07,141]          Batch size: 5
# [INFO][2024-07-17 16:27:07,142]          Phase: prediction
# [INFO][2024-07-17 16:27:07,142]          Starting offset: 35130
# [INFO][2024-07-17 16:27:07,143]          Number of batches: 200
# [INFO][2024-07-17 16:27:07,143]          Workers target: w2
# [INFO][2024-07-17 16:27:07,143]       ----------------------
# [INFO][2024-07-17 16:27:07,144]
# [INFO][2024-07-17 16:27:07,144]          Source name: s3
# [INFO][2024-07-17 16:27:07,145]          Batch size: 5
# [INFO][2024-07-17 16:27:07,145]          Phase: prediction
# [INFO][2024-07-17 16:27:07,146]          Starting offset: 54650
# [INFO][2024-07-17 16:27:07,146]          Number of batches: 200
# [INFO][2024-07-17 16:27:07,146]          Workers target: w3
# [INFO][2024-07-17 16:27:07,147]       ----------------------
# [INFO][2024-07-17 16:27:07,147]
# [INFO][2024-07-17 16:27:07,148] Initializing ApiServer receiver thread
#  * Serving Flask app 'receiver'
#  * Debug mode: off
# [INFO][2024-07-17 16:27:09,154] *** Remember to execute NerlnetRun.sh on each device before running the experiment! ***

# %%
# %pip install networkx pygraphviz
import networkx as nx
def visualize_nerlnet_graph(api_server_inst,  connections : dict , components): # connections is a dictionary with keys as routers and values as lists of their neighbors
    print("Connections: " , list(connections.items()))
    routers = list(connections.keys())
    print("Routers: " , routers)
    workers = list(components.map_worker_to_client.keys())
    print("Workers: " , workers)
    graph = nx.Graph()
    nodes = routers + components.sources + components.clients + workers + [API_SERVER_STR , MAIN_SERVER_STR]
    edges = [] # list of tuples
    for router , neighbors in list(connections.items()):
        for neighbor in neighbors:
            if (router,neighbor) not in edges:
                print(f"Adding edge ({router} , {neighbor}) to graph")
                edges.append((router , neighbor))
    edges.append((API_SERVER_STR , MAIN_SERVER_STR)) # Always connected
    for worker in workers:
        edges.append((worker , components.map_worker_to_client[worker]))
    graph.add_nodes_from(nodes)
    graph.add_edges_from(edges)
    
    my_labels = {'mainServer': 'mS' , 'apiServer': 'aS'}
    nx.relabel_nodes(graph, my_labels , copy=False)
    
    default_colors = {node:'#A90433' for node in graph.nodes()}
    node_colors = {node:default_colors[node] for node in graph.nodes()}
    nx.set_node_attributes(graph, node_colors, 'color')
    colors = nx.get_node_attributes(graph, 'color').values()

    pos = nx.nx_agraph.graphviz_layout(graph)
    angle = 100
    
    plt.figure(figsize=(8,6),dpi=150)
    nx.draw_networkx(graph, pos, with_labels=True, node_color=colors , node_size=200, font_size=8, font_color='white' , edge_color='black' , width=1.5)
    plt.show()
visualize_nerlnet_graph(API , API.json_dir_parser.json_from_path(conn_path)['connectionsMap'] , globe.components)
# Out:
# Collecting networkx
#   Downloading networkx-3.1-py3-none-any.whl.metadata (5.3 kB)
# Collecting pygraphviz
#   Downloading pygraphviz-1.11.zip (120 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.8/120.8 kB 2.0 MB/s eta 0:00:002.9 MB/s eta 0:00:01
#   Preparing metadata (setup.py) ... done
# Downloading networkx-3.1-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 20.5 MB/s eta 0:00:00 MB/s eta 0:00:01
# Building wheels for collected packages: pygraphviz
#   Building wheel for pygraphviz (setup.py) ... done
#   Created wheel for pygraphviz: filename=pygraphviz-1.11-cp38-cp38-linux_x86_64.whl size=185124 sha256=84ab178e1109dce3b5b345e4cf8b7dcb4f1350dcb59f5c9aa02f01183ca0cc6e
#   Stored in directory: /home/nerlnet/.cache/pip/wheels/18/40/e7/956a32b20107fb00d198b075df8fc3446748358035b9c25114
# Successfully built pygraphviz
# Installing collected packages: pygraphviz, networkx
# Successfully installed networkx-3.1 pygraphviz-1.11
#
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Connections:  [('r1', ['mainServer', 'c1', 'c2', 'c3', 'r2']), ('r2', ['s1', 's2', 's3', 'r1'])]
# Routers:  ['r1', 'r2']
# Workers:  ['w1', 'w2', 'w3']
# Adding edge (r1 , mainServer) to graph
# Adding edge (r1 , c1) to graph
# Adding edge (r1 , c2) to graph
# Adding edge (r1 , c3) to graph
# Adding edge (r1 , r2) to graph
# Adding edge (r2 , s1) to graph
# Adding edge (r2 , s2) to graph
# Adding edge (r2 , s3) to graph
# Adding edge (r2 , r1) to graph

# %%
API.send_jsons_to_devices()
# Out:
# [INFO][2024-07-17 16:28:15,158] Sending distributed configurations to devices is completed

# %%
API.run_current_experiment_phase()
# Out:
# [INFO][2024-07-17 16:28:15,279] Experiment phase: training_phase of type training starts running...
# [INFO][2024-07-17 16:28:15,281] Sending data to sources
# [INFO][2024-07-17 16:28:30,332] Data is ready in sources
# [INFO][2024-07-17 16:28:30,333] Phase training requested from Main Server
# [INFO][2024-07-17 16:39:52,320] Processing experiment phase data
# [INFO][2024-07-17 16:39:52,342] Processing experiment phase data completed
# [INFO][2024-07-17 16:39:52,343] Start generating communication statistics for training_phase of type training
# [INFO][2024-07-17 16:39:52,345] Statistics requested from Main Server
# [INFO][2024-07-17 16:39:52,749] Statistics received from Main Server
# [INFO][2024-07-17 16:39:52,751] Phase of training_phase training completed

# %%
stats_train = API.get_experiment_flow(exp_name).generate_stats()

# %%
stats_train.get_loss_ts(plot=True)
# Out:
#            w2        w1        w3
# 0    0.333333  0.333333  0.333333
# 1    0.333333  0.288889  0.333333
# 2    0.444444  0.222222  0.444444
# 3    0.555556  0.288889  0.444444
# 4    0.555556  0.333333  0.444444
# ..        ...       ...       ...
# 792       NaN       NaN  0.000645
# 793       NaN       NaN  0.000000
# 794       NaN       NaN  0.000000
# 795       NaN       NaN  0.000513
# 796       NaN       NaN  0.000000
#
# [797 rows x 3 columns]

# %%
import pandas as pd
workers_comm_dict = stats_train.get_communication_stats_workers()
df_train = pd.DataFrame.from_dict(workers_comm_dict)
plt.figure()
df_selected_train = df_train.iloc[[3,5]]
data_train = pd.melt(df_selected_train.reset_index(), id_vars=['index'], value_vars=df_train.columns)
batches_stats = sns.barplot(x='variable', y='value', hue='index', data=data_train)
plt.ylabel('Number Of Batches')
plt.xlabel('Worker')
plt.title("Received & Dropped Batches At Freq. 300B/s (Training Phase)")

batches_stats.legend(loc='upper right', bbox_to_anchor=(1.5, 0.2), shadow=True, ncol=1)
plt.show()

# %%
API.next_experiment_phase()
API.run_current_experiment_phase()

# %%
stats_pred = API.get_experiment_flow(exp_name).generate_stats()

# %%
conf_mats_sources_workers , conf_mats_workers = stats_pred.get_confusion_matrices(plot=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 conf_mats_sources_workers , conf_mats_workers = stats_pred.get_confusion_matrices(plot=True)
#
# NameError: name 'stats_pred' is not defined
