# %% [raw]
# This Experimnet is:
# 18 Devices
# 12 workers
# 6 people- each person send to 2 workers with RR policy
#
# There is 2 training phase, and 1 prediction phase.

# %%
import set_jupyter_env
from apiServer import *
import pandas as pd

# %%
API = ApiServer()

# %%
API.showJsons()
# Out:
# Distributed Configuration Files
# --------------------
#
# 0.	dc_10w_14d_8r_3s_10c_synt.json
# 1.	dc_12w_12c_13d_4s_4r_tiles_rr.json
# 2.	dc_5d_4c_4s_4r_12w.json
# 3.	dc_AEC_1d_2c_1s_4r_4w.json
# 4.	dc_EEG_18d_12c_6s_10r_12w_RR.json
# 5.	dc_EEG_18d_9c_3s_5r_9w_RR.json
# 6.	dc_EEG_1d_1c_3s_2r_3w_RR.json
# 7.	dc_EEG_4d_3c_3s_2r_3w.json
# 8.	dc_EEG_8d_1c_3s_2r_3w_RR.json
# 9.	dc_EEG_8d_3c_3s_2r_3w.json
# 10.	dc_EEG_8d_3c_3s_2r_3w_RR.json
# 11.	dc_EEG_8d_3c_3s_2r_3w_demo_RR.json
# 12.	dc_EEG_8d_3c_3s_5r_3w_RR.json
# 13.	dc_EEG_8d_8c_3s_5r_8w_RR.json
# 14.	dc_FedTorchTest_5d_2s_2r_4c_4w.json
# 15.	dc_dist_14d.json
# 16.	dc_dist_2d_3c_2s_3r_6w.json
# 17.	dc_fed_dist_14d.json
# 18.	dc_fed_dist_2d_3c_2s_3r_6w.json
# 19.	dc_fed_synt_1d_2c_2r_1s_4w_1ws.json
# 20.	dc_mnist_13d_12w_4r_3s_3tokens.json
# 21.	dc_mnist_4w_5d_4r_4s_rr.json
# 22.	dc_synt_8d_8w_2c_4s_4r.json
# 23.	dc_synt_8d_8w_4c_6r_4s.json
# 24.	dc_synt_distributed_w5_c3_6r_3s_3d.json
# 25.	dc_test_synt_1d_2c_1s_4r_4w.json
# 26.	dc_test_synt_1d_2c_2s_4r_4w.json
#
# Connection Map Files
# --------------------
#
# 0.	conn_1Router1Client1S.json
# 1.	conn_1Router1Client2S.json
# 2.	conn_1Router2Clients1S.json
# 3.	conn_1Router3Clients1S.json
# 4.	conn_1Router4Clients1S.json
# 5.	conn_1Router4Clients1fed.json
# 6.	conn_1Router4Clients2Sources.json
# 7.	conn_1Router4Clients2Sources1fed.json
# 8.	conn_2R4C1S_health_david.json
# 9.	conn_2Router2Clients1Source.json
# 10.	conn_2Router2Clients1Source_david.json
# 11.	conn_2Router2Clients2Source.json
# 12.	conn_2Router2ClientsGUI.json
# 13.	conn_2Router3Clients.json
# 14.	conn_3Router3Clients.json
# 15.	conn_4Router12Client4S.json
# 16.	conn_4Router4Client4S.json
# 17.	conn_4Router4Clients4S_mnist.json
# 18.	conn_6RouterCycle6Clients1Source.json
# 19.	conn_6RouterCycle8Clients1Source.json
# 20.	conn_6RouterLine6Clients1Source.json
# 21.	conn_8RouterCycle8Clients1Source.json
# 22.	conn_8Routers10Clients3S.json
# 23.	conn_EEG_10Router12Clients6Source_EEG.json
# 24.	conn_EEG_2Router1Clients3Source_EEG.json
# 25.	conn_EEG_2Router3Clients3Source_EEG.json
# 26.	conn_EEG_5Router3Clients3Source_EEG.json
# 27.	conn_EEG_5Router8Clients3Source_EEG.json
# 28.	conn_EEG_5Router9Clients3Source_EEG.json
# 29.	conn_fed_dist_14d.json
# 30.	conn_fed_dist_2d_3c_2s_3r_6w.json
# 31.	conn_fed_synt_1d_2c_2r_1s_4w_1ws.json
# 32.	conn_synt_8d_8w_4c_6r_4s.json
# 33.	conn_synt_dc_8d_8w_2c_4s_4r.json
# 34.	conn_synt_distributed_w5_c3_6r_3s_3d.json
# 35.	conn_test_synt_1d_2c_1s_4r_4w.json
# 36.	conn_test_synt_1d_2c_2s_4r_4w.json
#
# Experiments Flow Files
# --------------------
#
# 0.	exp_AEC_1d_2c_1s_4r_4w.json
# 1.	exp_EEG_3c_3s_2r_3w_3people.json
# 2.	exp_EEG_3c_3s_2r_3w_half3_people.json
# 3.	exp_EEG_3c_3s_2r_3w_half3_people_3exp_tr_phase.json
# 4.	exp_EEG_3c_3s_2r_3w_small_sample_RR.json
# 5.	exp_EEG_3s_3w_half3_people_RR.json
# 6.	exp_EEG_3s_8w_3_people_RR.json
# 7.	exp_EEG_3s_8w_3people_RR.json
# 8.	exp_EEG_3s_8w_half3_people_RR.json
# 9.	exp_EEG_3s_9w_3people_RR.json
# 10.	exp_EEG_6s_12w_6people_RR_1Tp.json
# 11.	exp_EEG_6s_12w_6people_RR_2Tp.json
# 12.	exp_FedTorchTest_5d_2s_2r_4c_4w.json
# 13.	exp_dist_14d.json
# 14.	exp_dist_14d_10c_3s_8r_10w.json
# 15.	exp_dist_2d_3c_2s_3r_6w.json
# 16.	exp_fed_dist_14d.json
# 17.	exp_fed_dist_2d_3c_2s_3r_6w.json
# 18.	exp_fed_synt_1d_2c_2r_1s_4w_1ws.json
# 19.	exp_mnist_5d_4c_4s_4w_4r.json
# 20.	exp_new_arc.json
# 21.	exp_synt_8d_8w_2c_4s_4r.json
# 22.	exp_synt_8d_8w_4c_6r_4s.json
# 23.	exp_synt_distributed_w5_c3_6r_3s_3d.json
# 24.	exp_test_synt_1d_2c_1s_4r_4w new.json
# 25.	exp_tiles_13d_12c_4s_4r_12w_rr.json
# 26.	exp_tiles_4d_4c_4s_4r_12w.json

# %%
dc = 4
conn = 23
exp = 11
API.setJsons(dc , conn , exp)

# %%
dc_path , conn_path , exp_path = API.getUserJsons()

# %%
exp_name = "EEG_Emotion_18Devices_6Persons_RR"
API.initialization(exp_name, dc_path, conn_path, exp_path)
# Out:
# [INFO][2024-08-06 12:40:55,596]
# Network components:
#                  Receiver's Address: http://10.0.0.11:8930
#                  Frequency: 5 [batches/sec]
#                  Batchsize: 10 [samples]
#                  devicesIp: ['10.0.0.11', '10.0.0.8', '10.0.0.12', '10.0.0.10', '10.0.0.32', '10.0.0.33', '10.0.0.34', '10.0.0.35', '10.0.0.47', '10.0.0.48', '10.0.0.49', '10.0.0.50', '10.0.0.51', '10.0.0.52', '10.0.0.53', '10.0.0.54', '10.0.0.55', '10.0.0.56']
#                  mainServerIp: 10.0.0.11
#                  mainServerPort: 8900
#                  apiServerIp: 10.0.0.11
#                  apiServerPort: 8930
#                  Clients: ['c1', 'c2', 'c3', 'c4', 'c5', 'c6', 'c7', 'c8', 'c9', 'c10', 'c11', 'c12']
#                  Workers: ['w1', 'w2', 'w3', 'w4', 'w5', 'w6', 'w7', 'w8', 'w9', 'w10', 'w11', 'w12']
#                  Sources: ['s1', 's2', 's3', 's4', 's5', 's6']
#                  Routers: ['r1', 'r2', 'r3', 'r4', 'r5', 'r6', 'r7', 'r8', 'r9', 'r10']
# [INFO][2024-08-06 12:40:55,597] Connections:
# [INFO][2024-08-06 12:40:55,598] 		 r1 : ['mainServer', 'c1', 'r2', 'r7']
# [INFO][2024-08-06 12:40:55,599] 		 r2 : ['c2', 's1', 'r3']
# [INFO][2024-08-06 12:40:55,599] 		 r3 : ['c3', 's2', 'r4', 'r1']
# [INFO][2024-08-06 12:40:55,600] 		 r4 : ['c4', 's3', 'r5', 'r2']
# [INFO][2024-08-06 12:40:55,600] 		 r5 : ['c5', 's4', 'c9', 'r6']
# [INFO][2024-08-06 12:40:55,601] 		 r6 : ['c6', 's5', 'r7', 'r3']
# [INFO][2024-08-06 12:40:55,601] 		 r7 : ['c7', 's6', 'r8', 'r1']
# [INFO][2024-08-06 12:40:55,602] 		 r8 : ['c8', 'c9', 'r9', 'r4']
# [INFO][2024-08-06 12:40:55,604] 		 r9 : ['c10', 'c11', 'r10', 'r5']
# [INFO][2024-08-06 12:40:55,604] 		 r10 : ['c12', 'r1', 'r6', 'r8']
# [INFO][2024-08-06 12:40:55,607] Experiment name: EEG_Valence_Recognition_DEAP
# [INFO][2024-08-06 12:40:55,608] Batch size: 10
# [INFO][2024-08-06 12:40:55,609] Number of features: 70
# [INFO][2024-08-06 12:40:55,609] Number of labels: 9
# [INFO][2024-08-06 12:40:55,610]
# [INFO][2024-08-06 12:40:55,611] Phases:
# [INFO][2024-08-06 12:40:55,611]    Phase name: training_phase1
# [INFO][2024-08-06 12:40:55,612]    Phase type: training
# [INFO][2024-08-06 12:40:55,612]    Sources: s1,s2,s3,s4,s5,s6
# [INFO][2024-08-06 12:40:55,613]
# [INFO][2024-08-06 12:40:55,613]     Source pieces:
# [INFO][2024-08-06 12:40:55,613]          Source name: s1
# [INFO][2024-08-06 12:40:55,614]          Batch size: 10
# [INFO][2024-08-06 12:40:55,614]          Phase: training
# [INFO][2024-08-06 12:40:55,615]          Starting offset: 10
# [INFO][2024-08-06 12:40:55,615]          Number of batches: 780
# [INFO][2024-08-06 12:40:55,616]          Workers target: w1,w2
# [INFO][2024-08-06 12:40:55,616]       ----------------------
# [INFO][2024-08-06 12:40:55,616]
# [INFO][2024-08-06 12:40:55,617]          Source name: s2
# [INFO][2024-08-06 12:40:55,617]          Batch size: 10
# [INFO][2024-08-06 12:40:55,618]          Phase: training
# [INFO][2024-08-06 12:40:55,618]          Starting offset: 19520
# [INFO][2024-08-06 12:40:55,619]          Number of batches: 780
# [INFO][2024-08-06 12:40:55,619]          Workers target: w3,w4
# [INFO][2024-08-06 12:40:55,619]       ----------------------
# [INFO][2024-08-06 12:40:55,620]
# [INFO][2024-08-06 12:40:55,623]          Source name: s3
# [INFO][2024-08-06 12:40:55,623]          Batch size: 10
# [INFO][2024-08-06 12:40:55,624]          Phase: training
# [INFO][2024-08-06 12:40:55,625]          Starting offset: 39040
# [INFO][2024-08-06 12:40:55,625]          Number of batches: 780
# [INFO][2024-08-06 12:40:55,626]          Workers target: w5,w6
# [INFO][2024-08-06 12:40:55,626]       ----------------------
# [INFO][2024-08-06 12:40:55,627]
# [INFO][2024-08-06 12:40:55,627]          Source name: s4
# [INFO][2024-08-06 12:40:55,628]          Batch size: 10
# [INFO][2024-08-06 12:40:55,628]          Phase: training
# [INFO][2024-08-06 12:40:55,628]          Starting offset: 58650
# [INFO][2024-08-06 12:40:55,629]          Number of batches: 780
# [INFO][2024-08-06 12:40:55,629]          Workers target: w7,w8
# [INFO][2024-08-06 12:40:55,631]       ----------------------
# [INFO][2024-08-06 12:40:55,631]
# [INFO][2024-08-06 12:40:55,631]          Source name: s5
# [INFO][2024-08-06 12:40:55,632]          Batch size: 10
# [INFO][2024-08-06 12:40:55,632]          Phase: training
# [INFO][2024-08-06 12:40:55,633]          Starting offset: 78170
# [INFO][2024-08-06 12:40:55,633]          Number of batches: 780
# [INFO][2024-08-06 12:40:55,634]          Workers target: w9,w10
# [INFO][2024-08-06 12:40:55,634]       ----------------------
# [INFO][2024-08-06 12:40:55,635]
# [INFO][2024-08-06 12:40:55,635]          Source name: s6
# [INFO][2024-08-06 12:40:55,636]          Batch size: 10
# [INFO][2024-08-06 12:40:55,636]          Phase: training
# [INFO][2024-08-06 12:40:55,637]          Starting offset: 97690
# [INFO][2024-08-06 12:40:55,637]          Number of batches: 780
# [INFO][2024-08-06 12:40:55,637]          Workers target: w11,w12
# [INFO][2024-08-06 12:40:55,638]       ----------------------
# [INFO][2024-08-06 12:40:55,640]
# [INFO][2024-08-06 12:40:55,640]    Phase name: training_phase2
# [INFO][2024-08-06 12:40:55,641]    Phase type: training
# [INFO][2024-08-06 12:40:55,641]    Sources: s1,s2,s3,s4,s5,s6
# [INFO][2024-08-06 12:40:55,642]
# [INFO][2024-08-06 12:40:55,643]     Source pieces:
# [INFO][2024-08-06 12:40:55,643]          Source name: s1
# [INFO][2024-08-06 12:40:55,643]          Batch size: 10
# [INFO][2024-08-06 12:40:55,644]          Phase: training
# [INFO][2024-08-06 12:40:55,644]          Starting offset: 7810
# [INFO][2024-08-06 12:40:55,645]          Number of batches: 780
# [INFO][2024-08-06 12:40:55,645]          Workers target: w1,w2
# [INFO][2024-08-06 12:40:55,646]       ----------------------
# [INFO][2024-08-06 12:40:55,646]
# [INFO][2024-08-06 12:40:55,647]          Source name: s2
# [INFO][2024-08-06 12:40:55,648]          Batch size: 10
# [INFO][2024-08-06 12:40:55,649]          Phase: training
# [INFO][2024-08-06 12:40:55,649]          Starting offset: 27325
# [INFO][2024-08-06 12:40:55,650]          Number of batches: 780
# [INFO][2024-08-06 12:40:55,650]          Workers target: w3,w4
# [INFO][2024-08-06 12:40:55,651]       ----------------------
# [INFO][2024-08-06 12:40:55,652]
# [INFO][2024-08-06 12:40:55,652]          Source name: s3
# [INFO][2024-08-06 12:40:55,653]          Batch size: 10
# [INFO][2024-08-06 12:40:55,654]          Phase: training
# [INFO][2024-08-06 12:40:55,654]          Starting offset: 46845
# [INFO][2024-08-06 12:40:55,655]          Number of batches: 780
# [INFO][2024-08-06 12:40:55,656]          Workers target: w5,w6
# [INFO][2024-08-06 12:40:55,658]       ----------------------
# [INFO][2024-08-06 12:40:55,658]
# [INFO][2024-08-06 12:40:55,659]          Source name: s4
# [INFO][2024-08-06 12:40:55,659]          Batch size: 10
# [INFO][2024-08-06 12:40:55,660]          Phase: training
# [INFO][2024-08-06 12:40:55,661]          Starting offset: 66455
# [INFO][2024-08-06 12:40:55,661]          Number of batches: 780
# [INFO][2024-08-06 12:40:55,662]          Workers target: w7,w8
# [INFO][2024-08-06 12:40:55,663]       ----------------------
# [INFO][2024-08-06 12:40:55,670]
# [INFO][2024-08-06 12:40:55,671]          Source name: s5
# [INFO][2024-08-06 12:40:55,671]          Batch size: 10
# [INFO][2024-08-06 12:40:55,672]          Phase: training
# [INFO][2024-08-06 12:40:55,672]          Starting offset: 85975
# [INFO][2024-08-06 12:40:55,673]          Number of batches: 780
# [INFO][2024-08-06 12:40:55,673]          Workers target: w9,w10
# [INFO][2024-08-06 12:40:55,674]       ----------------------
# [INFO][2024-08-06 12:40:55,674]
# [INFO][2024-08-06 12:40:55,675]          Source name: s6
# [INFO][2024-08-06 12:40:55,675]          Batch size: 10
# [INFO][2024-08-06 12:40:55,676]          Phase: training
# [INFO][2024-08-06 12:40:55,676]          Starting offset: 105495
# [INFO][2024-08-06 12:40:55,677]          Number of batches: 780
# [INFO][2024-08-06 12:40:55,682]          Workers target: w11,w12
# [INFO][2024-08-06 12:40:55,683]       ----------------------
# [INFO][2024-08-06 12:40:55,683]
# [INFO][2024-08-06 12:40:55,684]    Phase name: prediction_phase
# [INFO][2024-08-06 12:40:55,684]    Phase type: prediction
# [INFO][2024-08-06 12:40:55,687]    Sources: s1,s2,s3,s4,s5,s6
# [INFO][2024-08-06 12:40:55,688]
# [INFO][2024-08-06 12:40:55,690]     Source pieces:
# [INFO][2024-08-06 12:40:55,691]          Source name: s1
# [INFO][2024-08-06 12:40:55,691]          Batch size: 10
# [INFO][2024-08-06 12:40:55,692]          Phase: prediction
# [INFO][2024-08-06 12:40:55,692]          Starting offset: 15610
# [INFO][2024-08-06 12:40:55,693]          Number of batches: 391
# [INFO][2024-08-06 12:40:55,693]          Workers target: w1,w2
# [INFO][2024-08-06 12:40:55,694]       ----------------------
# [INFO][2024-08-06 12:40:55,694]
# [INFO][2024-08-06 12:40:55,695]          Source name: s2
# [INFO][2024-08-06 12:40:55,695]          Batch size: 10
# [INFO][2024-08-06 12:40:55,696]          Phase: prediction
# [INFO][2024-08-06 12:40:55,696]          Starting offset: 35130
# [INFO][2024-08-06 12:40:55,697]          Number of batches: 391
# [INFO][2024-08-06 12:40:55,697]          Workers target: w3,w4
# [INFO][2024-08-06 12:40:55,698]       ----------------------
# [INFO][2024-08-06 12:40:55,698]
# [INFO][2024-08-06 12:40:55,699]          Source name: s3
# [INFO][2024-08-06 12:40:55,699]          Batch size: 10
# [INFO][2024-08-06 12:40:55,700]          Phase: prediction
# [INFO][2024-08-06 12:40:55,700]          Starting offset: 54650
# [INFO][2024-08-06 12:40:55,701]          Number of batches: 391
# [INFO][2024-08-06 12:40:55,701]          Workers target: w5,w6
# [INFO][2024-08-06 12:40:55,702]       ----------------------
# [INFO][2024-08-06 12:40:55,702]
# [INFO][2024-08-06 12:40:55,703]          Source name: s4
# [INFO][2024-08-06 12:40:55,703]          Batch size: 10
# [INFO][2024-08-06 12:40:55,704]          Phase: prediction
# [INFO][2024-08-06 12:40:55,704]          Starting offset: 74260
# [INFO][2024-08-06 12:40:55,704]          Number of batches: 391
# [INFO][2024-08-06 12:40:55,705]          Workers target: w7,w8
# [INFO][2024-08-06 12:40:55,705]       ----------------------
# [INFO][2024-08-06 12:40:55,706]
# [INFO][2024-08-06 12:40:55,706]          Source name: s5
# [INFO][2024-08-06 12:40:55,707]          Batch size: 10
# [INFO][2024-08-06 12:40:55,707]          Phase: prediction
# [INFO][2024-08-06 12:40:55,707]          Starting offset: 93780
# [INFO][2024-08-06 12:40:55,708]          Number of batches: 391
# [INFO][2024-08-06 12:40:55,708]          Workers target: w9,w10
# [INFO][2024-08-06 12:40:55,709]       ----------------------
# [INFO][2024-08-06 12:40:55,709]
# [INFO][2024-08-06 12:40:55,710]          Source name: s6
# [INFO][2024-08-06 12:40:55,710]          Batch size: 10
# [INFO][2024-08-06 12:40:55,710]          Phase: prediction
# [INFO][2024-08-06 12:40:55,711]          Starting offset: 113300
# [INFO][2024-08-06 12:40:55,711]          Number of batches: 391
# [INFO][2024-08-06 12:40:55,712]          Workers target: w11,w12
# [INFO][2024-08-06 12:40:55,712]       ----------------------
# [INFO][2024-08-06 12:40:55,713]
# [INFO][2024-08-06 12:40:55,713] Initializing ApiServer receiver thread
#  * Serving Flask app 'receiver'
#  * Debug mode: off
# [INFO][2024-08-06 12:40:57,722] *** Remember to execute NerlnetRun.sh on each device before running the experiment! ***

# %%
# %pip install networkx pygraphviz
import networkx as nx
def visualize_nerlnet_graph(api_server_inst,  connections : dict , components): # connections is a dictionary with keys as routers and values as lists of their neighbors
    print("Connections: " , list(connections.items()))
    routers = list(connections.keys())
    print("Routers: " , routers)
    workers = list(components.map_worker_to_client.keys())
    print("Workers: " , workers)
    graph = nx.Graph()
    nodes = routers + components.sources + components.clients + workers + [API_SERVER_STR , MAIN_SERVER_STR]
    edges = [] # list of tuples
    for router , neighbors in list(connections.items()):
        for neighbor in neighbors:
            if (router,neighbor) not in edges:
                print(f"Adding edge ({router} , {neighbor}) to graph")
                edges.append((router , neighbor))
    edges.append((API_SERVER_STR , MAIN_SERVER_STR)) # Always connected
    for worker in workers:
        edges.append((worker , components.map_worker_to_client[worker]))
    graph.add_nodes_from(nodes)
    graph.add_edges_from(edges)
    
    my_labels = {'mainServer': 'mS' , 'apiServer': 'aS'}
    nx.relabel_nodes(graph, my_labels , copy=False)
    
    default_colors = {node:'#A90433' for node in graph.nodes()}
    node_colors = {node:default_colors[node] for node in graph.nodes()}
    nx.set_node_attributes(graph, node_colors, 'color')
    colors = nx.get_node_attributes(graph, 'color').values()

    pos = nx.nx_agraph.graphviz_layout(graph)
    angle = 100
    
    plt.figure(figsize=(8,6),dpi=150)
    nx.draw_networkx(graph, pos, with_labels=True, node_color=colors , node_size=200, font_size=8, font_color='white' , edge_color='black' , width=1.5)
    plt.show()
visualize_nerlnet_graph(API , API.json_dir_parser.json_from_path(conn_path)['connectionsMap'] , globe.components)
# Out:
# Requirement already satisfied: networkx in /tmp/nerlnet/virtualenv/lib/python3.8/site-packages (3.1)
# Requirement already satisfied: pygraphviz in /tmp/nerlnet/virtualenv/lib/python3.8/site-packages (1.11)
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Connections:  [('r1', ['mainServer', 'c1', 'r2', 'r7']), ('r2', ['c2', 's1', 'r3']), ('r3', ['c3', 's2', 'r4', 'r1']), ('r4', ['c4', 's3', 'r5', 'r2']), ('r5', ['c5', 's4', 'c9', 'r6']), ('r6', ['c6', 's5', 'r7', 'r3']), ('r7', ['c7', 's6', 'r8', 'r1']), ('r8', ['c8', 'c9', 'r9', 'r4']), ('r9', ['c10', 'c11', 'r10', 'r5']), ('r10', ['c12', 'r1', 'r6', 'r8'])]
# Routers:  ['r1', 'r2', 'r3', 'r4', 'r5', 'r6', 'r7', 'r8', 'r9', 'r10']
# Workers:  ['w1', 'w2', 'w3', 'w4', 'w5', 'w6', 'w7', 'w8', 'w9', 'w10', 'w11', 'w12']
# Adding edge (r1 , mainServer) to graph
# Adding edge (r1 , c1) to graph
# Adding edge (r1 , r2) to graph
# Adding edge (r1 , r7) to graph
# Adding edge (r2 , c2) to graph
# Adding edge (r2 , s1) to graph
# Adding edge (r2 , r3) to graph
# Adding edge (r3 , c3) to graph
# Adding edge (r3 , s2) to graph
# Adding edge (r3 , r4) to graph
# Adding edge (r3 , r1) to graph
# Adding edge (r4 , c4) to graph
# Adding edge (r4 , s3) to graph
# Adding edge (r4 , r5) to graph
# Adding edge (r4 , r2) to graph
# Adding edge (r5 , c5) to graph
# Adding edge (r5 , s4) to graph
# Adding edge (r5 , c9) to graph
# Adding edge (r5 , r6) to graph
# Adding edge (r6 , c6) to graph
# Adding edge (r6 , s5) to graph
# Adding edge (r6 , r7) to graph
# Adding edge (r6 , r3) to graph
# Adding edge (r7 , c7) to graph
# Adding edge (r7 , s6) to graph
# Adding edge (r7 , r8) to graph
# Adding edge (r7 , r1) to graph
# Adding edge (r8 , c8) to graph
# Adding edge (r8 , c9) to graph
# Adding edge (r8 , r9) to graph
# Adding edge (r8 , r4) to graph
# Adding edge (r9 , c10) to graph
# Adding edge (r9 , c11) to graph
# Adding edge (r9 , r10) to graph
# Adding edge (r9 , r5) to graph
# Adding edge (r10 , c12) to graph
# Adding edge (r10 , r1) to graph
# Adding edge (r10 , r6) to graph
# Adding edge (r10 , r8) to graph

# %%
API.send_jsons_to_devices()
# Out:
# [INFO][2024-08-06 12:41:01,720] Sending distributed configurations to devices is completed

# %%
API.run_current_experiment_phase()
# Out:
# [INFO][2024-08-06 12:41:01,726] Experiment phase: training_phase1 of type training starts running...
# [INFO][2024-08-06 12:41:01,727] Sending data to sources
# [INFO][2024-08-06 12:41:44,319] Data is ready in sources
# [INFO][2024-08-06 12:41:44,344] Phase training requested from Main Server
# [INFO][2024-08-06 12:44:26,902] Processing experiment phase data
# [INFO][2024-08-06 12:44:27,297] Processing experiment phase data completed
# [INFO][2024-08-06 12:44:27,299] Start generating communication statistics for training_phase1 of type training
# [INFO][2024-08-06 12:44:27,300] Statistics requested from Main Server
# [INFO][2024-08-06 12:44:27,405] Statistics received from Main Server
# [INFO][2024-08-06 12:44:27,406] Phase of training_phase1 training completed

# %%
stats_train1 = API.get_experiment_flow(exp_name).generate_stats()

# %%
stats_train1.get_loss_ts(plot=True)
# Out:
#            w1       w11       w12        w7        w6       w10        w3  \
# 0    0.511111  0.422222  0.444444  0.422222  0.511111  0.444444  0.477778
# 1    0.333333  0.444444  0.555556  0.444444  0.333333  0.555556  0.388889
# 2    0.555556  0.522222  0.655556  0.433333  0.522222  0.655556  0.511111
# 3    0.522222  0.422222  0.455556  0.511111  0.422222  0.455556  0.444444
# 4    0.422222  0.522222  0.511111  0.533333  0.433333  0.511111  0.444444
# ..        ...       ...       ...       ...       ...       ...       ...
# 383       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 384       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 385       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 386       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 387       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#            w2        w5        w9        w8        w4
# 0    0.388889  0.477778  0.422222  0.444444  0.511111
# 1    0.422222  0.388889  0.444444  0.555556  0.333333
# 2    0.511111  0.422222  0.522222  0.533333  0.555556
# 3    0.444444  0.511111  0.422222  0.344444  0.522222
# 4    0.444444  0.444444  0.522222  0.566667  0.422222
# ..        ...       ...       ...       ...       ...
# 383       NaN       NaN  0.000000       NaN       NaN
# 384       NaN       NaN  0.105140       NaN       NaN
# 385       NaN       NaN  0.017969       NaN       NaN
# 386       NaN       NaN  0.000000       NaN       NaN
# 387       NaN       NaN  0.000940       NaN       NaN
#
# [388 rows x 12 columns]

# %%
import pandas as pd
workers_comm_dict = stats_train1.get_communication_stats_workers()
df_train = pd.DataFrame.from_dict(workers_comm_dict)
plt.figure()
df_selected_train = df_train.iloc[[3,5]]
data_train = pd.melt(df_selected_train.reset_index(), id_vars=['index'], value_vars=df_train.columns)
batches_stats = sns.barplot(x='variable', y='value', hue='index', data=data_train)
plt.ylabel('Number Of Batches')
plt.xlabel('Worker')
plt.title("Received & Dropped Batches At Freq. 5B/s (Training Phase)")

batches_stats.legend(loc='upper right', bbox_to_anchor=(1.5, 0.2), shadow=True, ncol=1)
plt.show()

# %%
missed_dict = stats_train1.get_missed_batches()
print(missed_dict)
# Out:
# {'phase:training_phase1,s1->w1': [94, 110, 478, 524, 666, 674, 678, 686, 690, 700, 710, 712, 720, 722, 734, 736, 738, 750, 752, 754, 758, 766, 768, 772, 774], 'phase:training_phase1,s1->w2': [659, 663, 667, 673, 677, 683, 689, 693, 697, 703, 707, 713, 717, 721, 727, 731, 735, 739, 743, 747, 753, 755, 759, 763, 771, 773, 777], 'phase:training_phase1,s2->w3': [4, 18, 28, 34, 42, 50, 58, 62, 122, 142, 162, 172, 178, 186, 208, 220, 224, 228, 232, 236, 242, 248, 300, 308, 322, 686, 698, 702, 712, 718, 726, 736, 738, 742, 746, 750, 754, 758, 762, 766, 774, 776], 'phase:training_phase1,s2->w4': [735, 737, 739, 741, 743, 745, 747, 749, 751, 753, 755, 757, 759, 761, 763, 765, 769, 773, 775], 'phase:training_phase1,s3->w6': [5, 17, 27, 33, 37, 41, 51, 57, 61, 73, 123, 135, 141, 161, 171, 177, 199, 201, 217, 223, 227, 231, 235, 241, 277, 303, 339, 351, 357, 379, 405, 419, 427, 445, 453, 473, 497, 523, 551, 555, 565, 573, 579, 587, 611, 615, 675, 681, 691, 693, 707, 717, 719, 727, 729, 735, 737, 739, 741, 743, 745, 747, 749, 751, 753, 755, 757, 759, 761, 763, 767, 771, 773, 779], 'phase:training_phase1,s3->w5': [18, 58, 672, 680, 682, 690, 696, 708, 714, 716, 718, 734, 736, 738, 740, 742, 744, 746, 748, 750, 752, 754, 756, 758, 760, 762, 766, 768, 772, 774], 'phase:training_phase1,s4->w7': [4, 38, 252, 734, 750, 762, 772], 'phase:training_phase1,s4->w8': [5, 7, 13, 19, 23, 39, 49, 167, 737, 743, 745, 747, 749, 751, 753, 755, 757, 759, 761, 763, 765, 767, 769, 771, 773, 775, 777], 'phase:training_phase1,s5->w10': [575, 577, 579, 581, 583, 585, 587, 589, 591, 593, 595, 597, 599, 601], 'phase:training_phase1,s5->w9': [494, 506], 'phase:training_phase1,s6->w11': [294, 574, 596, 602, 606, 608, 610], 'phase:training_phase1,s6->w12': [563, 567, 581, 585, 591, 597, 601, 605, 609, 611, 613, 615, 617, 619, 621, 623, 625, 627, 629, 631, 633, 635, 637, 639, 641, 643]}

# %%
API.next_experiment_phase()
API.run_current_experiment_phase()
# Out:
# [INFO][2024-08-06 12:44:28,488] Experiment phase: training_phase2 of type training starts running...
# [INFO][2024-08-06 12:44:28,489] Sending data to sources
# [INFO][2024-08-06 12:45:00,882] Data is ready in sources
# [INFO][2024-08-06 12:45:00,893] Phase training requested from Main Server
# [INFO][2024-08-06 12:48:14,184] Processing experiment phase data
# [INFO][2024-08-06 12:48:14,242] Processing experiment phase data completed
# [INFO][2024-08-06 12:48:14,243] Start generating communication statistics for training_phase2 of type training
# [INFO][2024-08-06 12:48:14,244] Statistics requested from Main Server
# [INFO][2024-08-06 12:48:14,650] Statistics received from Main Server
# [INFO][2024-08-06 12:48:14,651] Phase of training_phase2 training completed

# %%
stats_train2 = API.get_experiment_flow(exp_name).generate_stats()

# %%
stats_train2.get_loss_ts(plot=True)
# Out:
#            w2       w11        w5        w3   w7        w9            w8  \
# 0    0.111111  0.024271  0.153017  0.111111  0.0  0.000000  1.094546e-01
# 1    0.000000  0.001005  0.122455  0.114017  0.0  0.000000  9.851325e-02
# 2    0.003958  0.000342  0.054379  0.111111  0.0  0.000130  5.572450e-07
# 3    0.006556  0.000206  0.000046  0.112786  0.0  0.000687  0.000000e+00
# 4    0.000000  0.000031  0.000000  0.111111  0.0  0.000000  0.000000e+00
# ..        ...       ...       ...       ...  ...       ...           ...
# 380       NaN       NaN       NaN       NaN  NaN       NaN  7.222946e-02
# 381       NaN       NaN       NaN       NaN  NaN       NaN  1.045277e-01
# 382       NaN       NaN       NaN       NaN  NaN       NaN  1.028372e-01
# 383       NaN       NaN       NaN       NaN  NaN       NaN  1.014348e-01
# 384       NaN       NaN       NaN       NaN  NaN       NaN  1.003028e-01
#
#            w4  w12        w6       w10        w1
# 0    0.100796  0.0  0.146361  0.000003  0.111111
# 1    0.006095  0.0  0.210634  0.009455  0.111111
# 2    0.000000  0.0  0.210008  0.006476  0.064091
# 3    0.000000  0.0  0.209377  0.010074  0.041736
# 4    0.000000  0.0  0.208740  0.000011  0.001920
# ..        ...  ...       ...       ...       ...
# 380       NaN  NaN       NaN       NaN       NaN
# 381       NaN  NaN       NaN       NaN       NaN
# 382       NaN  NaN       NaN       NaN       NaN
# 383       NaN  NaN       NaN       NaN       NaN
# 384       NaN  NaN       NaN       NaN       NaN
#
# [385 rows x 12 columns]

# %%
import pandas as pd
workers_comm_dict = stats_train2.get_communication_stats_workers()
df_train = pd.DataFrame.from_dict(workers_comm_dict)
plt.figure()
df_selected_train = df_train.iloc[[3,5]]
data_train = pd.melt(df_selected_train.reset_index(), id_vars=['index'], value_vars=df_train.columns)
batches_stats = sns.barplot(x='variable', y='value', hue='index', data=data_train)
plt.ylabel('Number Of Batches')
plt.xlabel('Worker')
plt.title("Received & Dropped Batches At Freq. 5B/s (Training Phase)")

batches_stats.legend(loc='upper right', bbox_to_anchor=(1.5, 0.2), shadow=True, ncol=1)
plt.show()

# %%
API.next_experiment_phase()
API.run_current_experiment_phase()
# Out:
# [INFO][2024-08-06 12:48:15,747] Experiment phase: prediction_phase of type prediction starts running...
# [INFO][2024-08-06 12:48:15,748] Sending data to sources
# [INFO][2024-08-06 12:48:24,906] Data is ready in sources
# [INFO][2024-08-06 12:48:24,908] Phase prediction requested from Main Server
# [INFO][2024-08-06 12:49:29,979] Processing experiment phase data
# [INFO][2024-08-06 12:49:30,010] Processing experiment phase data completed
# [INFO][2024-08-06 12:49:30,011] Start generating communication statistics for prediction_phase of type prediction
# [INFO][2024-08-06 12:49:30,012] Statistics requested from Main Server
# [INFO][2024-08-06 12:49:30,116] Statistics received from Main Server
# [INFO][2024-08-06 12:49:30,117] Phase of prediction_phase prediction completed

# %%
stats_pred = API.get_experiment_flow(exp_name).generate_stats()

# %%
import pandas as pd
workers_comm_dict = stats_pred.get_communication_stats_workers()
df_pred = pd.DataFrame.from_dict(workers_comm_dict)
plt.figure()
df_selected_pred = df_pred.iloc[[4,6]]
data_pred = pd.melt(df_selected_pred.reset_index(), id_vars=['index'], value_vars=df_pred.columns)
batches_stats = sns.barplot(x='variable', y='value', hue='index', data=data_pred)
plt.ylabel('Number Of Batches')
plt.xlabel('Worker')
plt.title("Received & Dropped Batches At Freq. 5B/s (Prediction Phase)")

batches_stats.legend(loc='upper right', bbox_to_anchor=(1.5, 0.2), shadow=True, ncol=1)
plt.show()

# %%
_ , conf_mats = stats_pred.get_confusion_matrices_new(plot=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 _ , conf_mats = stats_pred.get_confusion_matrices_new(plot=True)
#
# File /usr/local/lib/nerlnet-lib/NErlNet/src_py/apiServer/stats.py:188, in Stats.get_confusion_matrices_new(self, normalize, plot, saveToFile)
#     186     continue
#     187 worker_recived_batches_id = recived_batches_dict.get(f"phase:{self.experiment_phase.get_name()},{source_name}->{worker_name}")   # get a list of recived batches id for the worker
# --> 188 df_worker_labels = build_worker_label_df(df_actual_labels, worker_recived_batches_id, batch_size)
#     189 header_list = range(num_of_labels)
#     190 df_worker_labels.columns = header_list
#
# File /usr/local/lib/nerlnet-lib/NErlNet/src_py/apiServer/stats.py:153, in Stats.get_confusion_matrices_new.<locals>.build_worker_label_df(original_df, batch_ids, batch_size)
#     150 def build_worker_label_df(original_df, batch_ids, batch_size):
#     151     rows_list = []
# --> 153     for batch_id in batch_ids:
#     154         # Calculate the start and end indices for the rows to be copied
#     155         start_idx = batch_id * batch_size
#     156         end_idx = (batch_id + 1) * batch_size
#
# TypeError: 'NoneType' object is not iterable
