# %% [raw]
# This Experimnet is:
# 18 Devices
# 12 workers
# 12 people- each person send to 2 workers with RR policy
#
# There is 4 training phase, and 1 prediction phase.
# training phases 1-2 ->person 1-6
# training phases 3-4 ->person 7-12

# %%
import set_jupyter_env
from apiServer import *
import pandas as pd

# %%
API = ApiServer()

# %%
API.showJsons()
# Out:
# Distributed Configuration Files
# --------------------
#
# 0.	dc_10w_14d_8r_3s_10c_synt.json
# 1.	dc_12w_12c_13d_4s_4r_tiles_rr.json
# 2.	dc_5d_4c_4s_4r_12w.json
# 3.	dc_AEC_1d_2c_1s_4r_4w.json
# 4.	dc_EEG_18d_12c_6s_10r_12w_RR.json
# 5.	dc_EEG_18d_9c_3s_5r_9w_RR.json
# 6.	dc_EEG_1d_1c_3s_2r_3w_RR.json
# 7.	dc_EEG_4d_3c_3s_2r_3w.json
# 8.	dc_EEG_8d_1c_3s_2r_3w_RR.json
# 9.	dc_EEG_8d_3c_3s_2r_3w.json
# 10.	dc_EEG_8d_3c_3s_2r_3w_RR.json
# 11.	dc_EEG_8d_3c_3s_2r_3w_demo_RR.json
# 12.	dc_EEG_8d_3c_3s_5r_3w_RR.json
# 13.	dc_EEG_8d_8c_3s_5r_8w_RR.json
# 14.	dc_FedTorchTest_5d_2s_2r_4c_4w.json
# 15.	dc_dist_14d.json
# 16.	dc_dist_2d_3c_2s_3r_6w.json
# 17.	dc_fed_dist_14d.json
# 18.	dc_fed_dist_2d_3c_2s_3r_6w.json
# 19.	dc_fed_synt_1d_2c_2r_1s_4w_1ws.json
# 20.	dc_mnist_13d_12w_4r_3s_3tokens.json
# 21.	dc_mnist_4w_5d_4r_4s_rr.json
# 22.	dc_synt_8d_8w_2c_4s_4r.json
# 23.	dc_synt_8d_8w_4c_6r_4s.json
# 24.	dc_synt_distributed_w5_c3_6r_3s_3d.json
# 25.	dc_test_synt_1d_2c_1s_4r_4w.json
# 26.	dc_test_synt_1d_2c_2s_4r_4w.json
#
# Connection Map Files
# --------------------
#
# 0.	conn_1Router1Client1S.json
# 1.	conn_1Router1Client2S.json
# 2.	conn_1Router2Clients1S.json
# 3.	conn_1Router3Clients1S.json
# 4.	conn_1Router4Clients1S.json
# 5.	conn_1Router4Clients1fed.json
# 6.	conn_1Router4Clients2Sources.json
# 7.	conn_1Router4Clients2Sources1fed.json
# 8.	conn_2R4C1S_health_david.json
# 9.	conn_2Router2Clients1Source.json
# 10.	conn_2Router2Clients1Source_david.json
# 11.	conn_2Router2Clients2Source.json
# 12.	conn_2Router2ClientsGUI.json
# 13.	conn_2Router3Clients.json
# 14.	conn_3Router3Clients.json
# 15.	conn_4Router12Client4S.json
# 16.	conn_4Router4Client4S.json
# 17.	conn_4Router4Clients4S_mnist.json
# 18.	conn_6RouterCycle6Clients1Source.json
# 19.	conn_6RouterCycle8Clients1Source.json
# 20.	conn_6RouterLine6Clients1Source.json
# 21.	conn_8RouterCycle8Clients1Source.json
# 22.	conn_8Routers10Clients3S.json
# 23.	conn_EEG_10Router12Clients6Source_EEG.json
# 24.	conn_EEG_2Router1Clients3Source_EEG.json
# 25.	conn_EEG_2Router3Clients3Source_EEG.json
# 26.	conn_EEG_5Router3Clients3Source_EEG.json
# 27.	conn_EEG_5Router8Clients3Source_EEG.json
# 28.	conn_EEG_5Router9Clients3Source_EEG.json
# 29.	conn_fed_dist_14d.json
# 30.	conn_fed_dist_2d_3c_2s_3r_6w.json
# 31.	conn_fed_synt_1d_2c_2r_1s_4w_1ws.json
# 32.	conn_synt_8d_8w_4c_6r_4s.json
# 33.	conn_synt_dc_8d_8w_2c_4s_4r.json
# 34.	conn_synt_distributed_w5_c3_6r_3s_3d.json
# 35.	conn_test_synt_1d_2c_1s_4r_4w.json
# 36.	conn_test_synt_1d_2c_2s_4r_4w.json
#
# Experiments Flow Files
# --------------------
#
# 0.	exp_AEC_1d_2c_1s_4r_4w.json
# 1.	exp_EEG_3c_3s_2r_3w_3people.json
# 2.	exp_EEG_3c_3s_2r_3w_half3_people.json
# 3.	exp_EEG_3c_3s_2r_3w_half3_people_3exp_tr_phase.json
# 4.	exp_EEG_3c_3s_2r_3w_small_sample_RR.json
# 5.	exp_EEG_3s_3w_half3_people_RR.json
# 6.	exp_EEG_3s_8w_3_people_RR.json
# 7.	exp_EEG_3s_8w_3people_RR.json
# 8.	exp_EEG_3s_8w_half3_people_RR.json
# 9.	exp_EEG_3s_9w_3people_RR.json
# 10.	exp_EEG_6s_12w_12people_RR_4Tp.json
# 11.	exp_EEG_6s_12w_6people_RR_1Tp.json
# 12.	exp_EEG_6s_12w_6people_RR_2Tp.json
# 13.	exp_EEG_6s_12w_6people_RR_2Tp_CMTest.json
# 14.	exp_FedTorchTest_5d_2s_2r_4c_4w.json
# 15.	exp_dist_14d.json
# 16.	exp_dist_14d_10c_3s_8r_10w.json
# 17.	exp_dist_2d_3c_2s_3r_6w.json
# 18.	exp_fed_dist_14d.json
# 19.	exp_fed_dist_2d_3c_2s_3r_6w.json
# 20.	exp_fed_synt_1d_2c_2r_1s_4w_1ws.json
# 21.	exp_mnist_5d_4c_4s_4w_4r.json
# 22.	exp_new_arc.json
# 23.	exp_synt_8d_8w_2c_4s_4r.json
# 24.	exp_synt_8d_8w_4c_6r_4s.json
# 25.	exp_synt_distributed_w5_c3_6r_3s_3d.json
# 26.	exp_test_synt_1d_2c_1s_4r_4w new.json
# 27.	exp_tiles_13d_12c_4s_4r_12w_rr.json
# 28.	exp_tiles_4d_4c_4s_4r_12w.json

# %%
dc = 4
conn = 23
exp = 10
API.setJsons(dc , conn , exp)

# %%
dc_path , conn_path , exp_path = API.getUserJsons()

# %%
exp_name = "EEG_Emotion_18Devices_12Persons_RR"
API.initialization(exp_name, dc_path, conn_path, exp_path)
# Out:
# [INFO][2024-08-06 15:31:54,355]
# Network components:
#                  Receiver's Address: http://10.0.0.11:8930
#                  Frequency: 5 [batches/sec]
#                  Batchsize: 10 [samples]
#                  devicesIp: ['10.0.0.11', '10.0.0.8', '10.0.0.12', '10.0.0.10', '10.0.0.32', '10.0.0.33', '10.0.0.34', '10.0.0.35', '10.0.0.47', '10.0.0.48', '10.0.0.49', '10.0.0.50', '10.0.0.51', '10.0.0.52', '10.0.0.53', '10.0.0.54', '10.0.0.55', '10.0.0.56']
#                  mainServerIp: 10.0.0.11
#                  mainServerPort: 8900
#                  apiServerIp: 10.0.0.11
#                  apiServerPort: 8930
#                  Clients: ['c1', 'c2', 'c3', 'c4', 'c5', 'c6', 'c7', 'c8', 'c9', 'c10', 'c11', 'c12']
#                  Workers: ['w1', 'w2', 'w3', 'w4', 'w5', 'w6', 'w7', 'w8', 'w9', 'w10', 'w11', 'w12']
#                  Sources: ['s1', 's2', 's3', 's4', 's5', 's6']
#                  Routers: ['r1', 'r2', 'r3', 'r4', 'r5', 'r6', 'r7', 'r8', 'r9', 'r10']
# [INFO][2024-08-06 15:31:54,356] Connections:
# [INFO][2024-08-06 15:31:54,356] 		 r1 : ['mainServer', 'c1', 'r2', 'r7']
# [INFO][2024-08-06 15:31:54,357] 		 r2 : ['c2', 's1', 'r3']
# [INFO][2024-08-06 15:31:54,357] 		 r3 : ['c3', 's2', 'r4', 'r1']
# [INFO][2024-08-06 15:31:54,358] 		 r4 : ['c4', 's3', 'r5', 'r2']
# [INFO][2024-08-06 15:31:54,358] 		 r5 : ['c5', 's4', 'c9', 'r6']
# [INFO][2024-08-06 15:31:54,359] 		 r6 : ['c6', 's5', 'r7', 'r3']
# [INFO][2024-08-06 15:31:54,359] 		 r7 : ['c7', 's6', 'r8', 'r1']
# [INFO][2024-08-06 15:31:54,360] 		 r8 : ['c8', 'c9', 'r9', 'r4']
# [INFO][2024-08-06 15:31:54,361] 		 r9 : ['c10', 'c11', 'r10', 'r5']
# [INFO][2024-08-06 15:31:54,361] 		 r10 : ['c12', 'r1', 'r6', 'r8']
# [INFO][2024-08-06 15:31:54,363] Experiment name: EEG_Valence_Recognition_DEAP
# [INFO][2024-08-06 15:31:54,363] Batch size: 10
# [INFO][2024-08-06 15:31:54,364] Number of features: 70
# [INFO][2024-08-06 15:31:54,365] Number of labels: 9
# [INFO][2024-08-06 15:31:54,366]
# [INFO][2024-08-06 15:31:54,367] Phases:
# [INFO][2024-08-06 15:31:54,368]    Phase name: training_phase1
# [INFO][2024-08-06 15:31:54,368]    Phase type: training
# [INFO][2024-08-06 15:31:54,369]    Sources: s1,s2,s3,s4,s5,s6
# [INFO][2024-08-06 15:31:54,370]
# [INFO][2024-08-06 15:31:54,371]     Source pieces:
# [INFO][2024-08-06 15:31:54,372]          Source name: s1
# [INFO][2024-08-06 15:31:54,376]          Batch size: 10
# [INFO][2024-08-06 15:31:54,377]          Phase: training
# [INFO][2024-08-06 15:31:54,377]          Starting offset: 10
# [INFO][2024-08-06 15:31:54,378]          Number of batches: 780
# [INFO][2024-08-06 15:31:54,378]          Workers target: w1,w2
# [INFO][2024-08-06 15:31:54,379]       ----------------------
# [INFO][2024-08-06 15:31:54,379]
# [INFO][2024-08-06 15:31:54,380]          Source name: s2
# [INFO][2024-08-06 15:31:54,380]          Batch size: 10
# [INFO][2024-08-06 15:31:54,381]          Phase: training
# [INFO][2024-08-06 15:31:54,381]          Starting offset: 19520
# [INFO][2024-08-06 15:31:54,382]          Number of batches: 780
# [INFO][2024-08-06 15:31:54,382]          Workers target: w3,w4
# [INFO][2024-08-06 15:31:54,382]       ----------------------
# [INFO][2024-08-06 15:31:54,383]
# [INFO][2024-08-06 15:31:54,383]          Source name: s3
# [INFO][2024-08-06 15:31:54,384]          Batch size: 10
# [INFO][2024-08-06 15:31:54,384]          Phase: training
# [INFO][2024-08-06 15:31:54,385]          Starting offset: 39040
# [INFO][2024-08-06 15:31:54,385]          Number of batches: 780
# [INFO][2024-08-06 15:31:54,386]          Workers target: w5,w6
# [INFO][2024-08-06 15:31:54,386]       ----------------------
# [INFO][2024-08-06 15:31:54,386]
# [INFO][2024-08-06 15:31:54,387]          Source name: s4
# [INFO][2024-08-06 15:31:54,387]          Batch size: 10
# [INFO][2024-08-06 15:31:54,388]          Phase: training
# [INFO][2024-08-06 15:31:54,388]          Starting offset: 58650
# [INFO][2024-08-06 15:31:54,389]          Number of batches: 780
# [INFO][2024-08-06 15:31:54,389]          Workers target: w7,w8
# [INFO][2024-08-06 15:31:54,390]       ----------------------
# [INFO][2024-08-06 15:31:54,390]
# [INFO][2024-08-06 15:31:54,391]          Source name: s5
# [INFO][2024-08-06 15:31:54,391]          Batch size: 10
# [INFO][2024-08-06 15:31:54,391]          Phase: training
# [INFO][2024-08-06 15:31:54,392]          Starting offset: 78170
# [INFO][2024-08-06 15:31:54,392]          Number of batches: 780
# [INFO][2024-08-06 15:31:54,393]          Workers target: w9,w10
# [INFO][2024-08-06 15:31:54,393]       ----------------------
# [INFO][2024-08-06 15:31:54,394]
# [INFO][2024-08-06 15:31:54,394]          Source name: s6
# [INFO][2024-08-06 15:31:54,395]          Batch size: 10
# [INFO][2024-08-06 15:31:54,395]          Phase: training
# [INFO][2024-08-06 15:31:54,396]          Starting offset: 97690
# [INFO][2024-08-06 15:31:54,396]          Number of batches: 780
# [INFO][2024-08-06 15:31:54,397]          Workers target: w11,w12
# [INFO][2024-08-06 15:31:54,397]       ----------------------
# [INFO][2024-08-06 15:31:54,398]
# [INFO][2024-08-06 15:31:54,398]    Phase name: training_phase2
# [INFO][2024-08-06 15:31:54,399]    Phase type: training
# [INFO][2024-08-06 15:31:54,399]    Sources: s1,s2,s3,s4,s5,s6
# [INFO][2024-08-06 15:31:54,400]
# [INFO][2024-08-06 15:31:54,400]     Source pieces:
# [INFO][2024-08-06 15:31:54,401]          Source name: s1
# [INFO][2024-08-06 15:31:54,401]          Batch size: 10
# [INFO][2024-08-06 15:31:54,401]          Phase: training
# [INFO][2024-08-06 15:31:54,402]          Starting offset: 7810
# [INFO][2024-08-06 15:31:54,403]          Number of batches: 780
# [INFO][2024-08-06 15:31:54,403]          Workers target: w1,w2
# [INFO][2024-08-06 15:31:54,403]       ----------------------
# [INFO][2024-08-06 15:31:54,404]
# [INFO][2024-08-06 15:31:54,404]          Source name: s2
# [INFO][2024-08-06 15:31:54,405]          Batch size: 10
# [INFO][2024-08-06 15:31:54,405]          Phase: training
# [INFO][2024-08-06 15:31:54,406]          Starting offset: 27325
# [INFO][2024-08-06 15:31:54,406]          Number of batches: 780
# [INFO][2024-08-06 15:31:54,407]          Workers target: w3,w4
# [INFO][2024-08-06 15:31:54,407]       ----------------------
# [INFO][2024-08-06 15:31:54,408]
# [INFO][2024-08-06 15:31:54,409]          Source name: s3
# [INFO][2024-08-06 15:31:54,409]          Batch size: 10
# [INFO][2024-08-06 15:31:54,410]          Phase: training
# [INFO][2024-08-06 15:31:54,410]          Starting offset: 46845
# [INFO][2024-08-06 15:31:54,411]          Number of batches: 780
# [INFO][2024-08-06 15:31:54,411]          Workers target: w5,w6
# [INFO][2024-08-06 15:31:54,412]       ----------------------
# [INFO][2024-08-06 15:31:54,412]
# [INFO][2024-08-06 15:31:54,413]          Source name: s4
# [INFO][2024-08-06 15:31:54,413]          Batch size: 10
# [INFO][2024-08-06 15:31:54,414]          Phase: training
# [INFO][2024-08-06 15:31:54,414]          Starting offset: 66455
# [INFO][2024-08-06 15:31:54,415]          Number of batches: 780
# [INFO][2024-08-06 15:31:54,415]          Workers target: w7,w8
# [INFO][2024-08-06 15:31:54,416]       ----------------------
# [INFO][2024-08-06 15:31:54,416]
# [INFO][2024-08-06 15:31:54,417]          Source name: s5
# [INFO][2024-08-06 15:31:54,417]          Batch size: 10
# [INFO][2024-08-06 15:31:54,418]          Phase: training
# [INFO][2024-08-06 15:31:54,418]          Starting offset: 85975
# [INFO][2024-08-06 15:31:54,419]          Number of batches: 780
# [INFO][2024-08-06 15:31:54,419]          Workers target: w9,w10
# [INFO][2024-08-06 15:31:54,420]       ----------------------
# [INFO][2024-08-06 15:31:54,420]
# [INFO][2024-08-06 15:31:54,421]          Source name: s6
# [INFO][2024-08-06 15:31:54,421]          Batch size: 10
# [INFO][2024-08-06 15:31:54,421]          Phase: training
# [INFO][2024-08-06 15:31:54,422]          Starting offset: 105495
# [INFO][2024-08-06 15:31:54,422]          Number of batches: 780
# [INFO][2024-08-06 15:31:54,423]          Workers target: w11,w12
# [INFO][2024-08-06 15:31:54,423]       ----------------------
# [INFO][2024-08-06 15:31:54,424]
# [INFO][2024-08-06 15:31:54,424]    Phase name: training_phase3
# [INFO][2024-08-06 15:31:54,425]    Phase type: training
# [INFO][2024-08-06 15:31:54,425]    Sources: s1,s2,s3,s4,s5,s6
# [INFO][2024-08-06 15:31:54,426]
# [INFO][2024-08-06 15:31:54,426]     Source pieces:
# [INFO][2024-08-06 15:31:54,427]          Source name: s1
# [INFO][2024-08-06 15:31:54,427]          Batch size: 10
# [INFO][2024-08-06 15:31:54,428]          Phase: training
# [INFO][2024-08-06 15:31:54,428]          Starting offset: 17120
# [INFO][2024-08-06 15:31:54,429]          Number of batches: 780
# [INFO][2024-08-06 15:31:54,429]          Workers target: w1,w2
# [INFO][2024-08-06 15:31:54,430]       ----------------------
# [INFO][2024-08-06 15:31:54,430]
# [INFO][2024-08-06 15:31:54,431]          Source name: s2
# [INFO][2024-08-06 15:31:54,431]          Batch size: 10
# [INFO][2024-08-06 15:31:54,432]          Phase: training
# [INFO][2024-08-06 15:31:54,432]          Starting offset: 136640
# [INFO][2024-08-06 15:31:54,433]          Number of batches: 780
# [INFO][2024-08-06 15:31:54,433]          Workers target: w3,w4
# [INFO][2024-08-06 15:31:54,434]       ----------------------
# [INFO][2024-08-06 15:31:54,434]
# [INFO][2024-08-06 15:31:54,435]          Source name: s3
# [INFO][2024-08-06 15:31:54,435]          Batch size: 10
# [INFO][2024-08-06 15:31:54,436]          Phase: training
# [INFO][2024-08-06 15:31:54,436]          Starting offset: 145160
# [INFO][2024-08-06 15:31:54,436]          Number of batches: 780
# [INFO][2024-08-06 15:31:54,437]          Workers target: w5,w6
# [INFO][2024-08-06 15:31:54,437]       ----------------------
# [INFO][2024-08-06 15:31:54,438]
# [INFO][2024-08-06 15:31:54,438]          Source name: s4
# [INFO][2024-08-06 15:31:54,439]          Batch size: 10
# [INFO][2024-08-06 15:31:54,439]          Phase: training
# [INFO][2024-08-06 15:31:54,440]          Starting offset: 175680
# [INFO][2024-08-06 15:31:54,440]          Number of batches: 780
# [INFO][2024-08-06 15:31:54,441]          Workers target: w7,w8
# [INFO][2024-08-06 15:31:54,441]       ----------------------
# [INFO][2024-08-06 15:31:54,442]
# [INFO][2024-08-06 15:31:54,442]          Source name: s5
# [INFO][2024-08-06 15:31:54,443]          Batch size: 10
# [INFO][2024-08-06 15:31:54,443]          Phase: training
# [INFO][2024-08-06 15:31:54,444]          Starting offset: 195200
# [INFO][2024-08-06 15:31:54,444]          Number of batches: 780
# [INFO][2024-08-06 15:31:54,445]          Workers target: w9,w10
# [INFO][2024-08-06 15:31:54,445]       ----------------------
# [INFO][2024-08-06 15:31:54,446]
# [INFO][2024-08-06 15:31:54,446]          Source name: s6
# [INFO][2024-08-06 15:31:54,447]          Batch size: 10
# [INFO][2024-08-06 15:31:54,447]          Phase: training
# [INFO][2024-08-06 15:31:54,448]          Starting offset: 214720
# [INFO][2024-08-06 15:31:54,448]          Number of batches: 780
# [INFO][2024-08-06 15:31:54,449]          Workers target: w11,w12
# [INFO][2024-08-06 15:31:54,449]       ----------------------
# [INFO][2024-08-06 15:31:54,450]
# [INFO][2024-08-06 15:31:54,450]    Phase name: training_phase4
# [INFO][2024-08-06 15:31:54,451]    Phase type: training
# [INFO][2024-08-06 15:31:54,451]    Sources: s1,s2,s3,s4,s5,s6
# [INFO][2024-08-06 15:31:54,452]
# [INFO][2024-08-06 15:31:54,452]     Source pieces:
# [INFO][2024-08-06 15:31:54,453]          Source name: s1
# [INFO][2024-08-06 15:31:54,453]          Batch size: 10
# [INFO][2024-08-06 15:31:54,454]          Phase: training
# [INFO][2024-08-06 15:31:54,454]          Starting offset: 124925
# [INFO][2024-08-06 15:31:54,455]          Number of batches: 780
# [INFO][2024-08-06 15:31:54,456]          Workers target: w1,w2
# [INFO][2024-08-06 15:31:54,456]       ----------------------
# [INFO][2024-08-06 15:31:54,456]
# [INFO][2024-08-06 15:31:54,457]          Source name: s2
# [INFO][2024-08-06 15:31:54,457]          Batch size: 10
# [INFO][2024-08-06 15:31:54,458]          Phase: training
# [INFO][2024-08-06 15:31:54,458]          Starting offset: 144445
# [INFO][2024-08-06 15:31:54,459]          Number of batches: 780
# [INFO][2024-08-06 15:31:54,459]          Workers target: w3,w4
# [INFO][2024-08-06 15:31:54,460]       ----------------------
# [INFO][2024-08-06 15:31:54,460]
# [INFO][2024-08-06 15:31:54,461]          Source name: s3
# [INFO][2024-08-06 15:31:54,461]          Batch size: 10
# [INFO][2024-08-06 15:31:54,462]          Phase: training
# [INFO][2024-08-06 15:31:54,462]          Starting offset: 163965
# [INFO][2024-08-06 15:31:54,462]          Number of batches: 780
# [INFO][2024-08-06 15:31:54,463]          Workers target: w5,w6
# [INFO][2024-08-06 15:31:54,463]       ----------------------
# [INFO][2024-08-06 15:31:54,464]
# [INFO][2024-08-06 15:31:54,464]          Source name: s4
# [INFO][2024-08-06 15:31:54,465]          Batch size: 10
# [INFO][2024-08-06 15:31:54,465]          Phase: training
# [INFO][2024-08-06 15:31:54,466]          Starting offset: 183485
# [INFO][2024-08-06 15:31:54,466]          Number of batches: 780
# [INFO][2024-08-06 15:31:54,467]          Workers target: w7,w8
# [INFO][2024-08-06 15:31:54,467]       ----------------------
# [INFO][2024-08-06 15:31:54,468]
# [INFO][2024-08-06 15:31:54,468]          Source name: s5
# [INFO][2024-08-06 15:31:54,469]          Batch size: 10
# [INFO][2024-08-06 15:31:54,469]          Phase: training
# [INFO][2024-08-06 15:31:54,469]          Starting offset: 203005
# [INFO][2024-08-06 15:31:54,470]          Number of batches: 780
# [INFO][2024-08-06 15:31:54,470]          Workers target: w9,w10
# [INFO][2024-08-06 15:31:54,471]       ----------------------
# [INFO][2024-08-06 15:31:54,471]
# [INFO][2024-08-06 15:31:54,472]          Source name: s6
# [INFO][2024-08-06 15:31:54,472]          Batch size: 10
# [INFO][2024-08-06 15:31:54,473]          Phase: training
# [INFO][2024-08-06 15:31:54,473]          Starting offset: 222525
# [INFO][2024-08-06 15:31:54,474]          Number of batches: 780
# [INFO][2024-08-06 15:31:54,474]          Workers target: w11,w12
# [INFO][2024-08-06 15:31:54,475]       ----------------------
# [INFO][2024-08-06 15:31:54,475]
# [INFO][2024-08-06 15:31:54,476]    Phase name: prediction_phase
# [INFO][2024-08-06 15:31:54,476]    Phase type: prediction
# [INFO][2024-08-06 15:31:54,476]    Sources: s1,s2,s3,s4,s5,s6
# [INFO][2024-08-06 15:31:54,477]
# [INFO][2024-08-06 15:31:54,477]     Source pieces:
# [INFO][2024-08-06 15:31:54,478]          Source name: s1
# [INFO][2024-08-06 15:31:54,478]          Batch size: 10
# [INFO][2024-08-06 15:31:54,479]          Phase: prediction
# [INFO][2024-08-06 15:31:54,479]          Starting offset: 15610
# [INFO][2024-08-06 15:31:54,480]          Number of batches: 391
# [INFO][2024-08-06 15:31:54,480]          Workers target: w1,w2
# [INFO][2024-08-06 15:31:54,481]       ----------------------
# [INFO][2024-08-06 15:31:54,481]
# [INFO][2024-08-06 15:31:54,481]          Source name: s2
# [INFO][2024-08-06 15:31:54,482]          Batch size: 10
# [INFO][2024-08-06 15:31:54,482]          Phase: prediction
# [INFO][2024-08-06 15:31:54,483]          Starting offset: 35130
# [INFO][2024-08-06 15:31:54,483]          Number of batches: 391
# [INFO][2024-08-06 15:31:54,484]          Workers target: w3,w4
# [INFO][2024-08-06 15:31:54,484]       ----------------------
# [INFO][2024-08-06 15:31:54,485]
# [INFO][2024-08-06 15:31:54,485]          Source name: s3
# [INFO][2024-08-06 15:31:54,486]          Batch size: 10
# [INFO][2024-08-06 15:31:54,486]          Phase: prediction
# [INFO][2024-08-06 15:31:54,487]          Starting offset: 54650
# [INFO][2024-08-06 15:31:54,487]          Number of batches: 391
# [INFO][2024-08-06 15:31:54,487]          Workers target: w5,w6
# [INFO][2024-08-06 15:31:54,488]       ----------------------
# [INFO][2024-08-06 15:31:54,488]
# [INFO][2024-08-06 15:31:54,489]          Source name: s4
# [INFO][2024-08-06 15:31:54,489]          Batch size: 10
# [INFO][2024-08-06 15:31:54,490]          Phase: prediction
# [INFO][2024-08-06 15:31:54,490]          Starting offset: 74260
# [INFO][2024-08-06 15:31:54,491]          Number of batches: 391
# [INFO][2024-08-06 15:31:54,491]          Workers target: w7,w8
# [INFO][2024-08-06 15:31:54,492]       ----------------------
# [INFO][2024-08-06 15:31:54,492]
# [INFO][2024-08-06 15:31:54,493]          Source name: s5
# [INFO][2024-08-06 15:31:54,494]          Batch size: 10
# [INFO][2024-08-06 15:31:54,494]          Phase: prediction
# [INFO][2024-08-06 15:31:54,495]          Starting offset: 93780
# [INFO][2024-08-06 15:31:54,495]          Number of batches: 391
# [INFO][2024-08-06 15:31:54,496]          Workers target: w9,w10
# [INFO][2024-08-06 15:31:54,496]       ----------------------
# [INFO][2024-08-06 15:31:54,497]
# [INFO][2024-08-06 15:31:54,497]          Source name: s6
# [INFO][2024-08-06 15:31:54,498]          Batch size: 10
# [INFO][2024-08-06 15:31:54,498]          Phase: prediction
# [INFO][2024-08-06 15:31:54,499]          Starting offset: 113300
# [INFO][2024-08-06 15:31:54,499]          Number of batches: 391
# [INFO][2024-08-06 15:31:54,500]          Workers target: w11,w12
# [INFO][2024-08-06 15:31:54,501]       ----------------------
# [INFO][2024-08-06 15:31:54,501]
# [INFO][2024-08-06 15:31:54,502] Initializing ApiServer receiver thread
#  * Serving Flask app 'receiver'
#  * Debug mode: off
# [INFO][2024-08-06 15:31:56,537] *** Remember to execute NerlnetRun.sh on each device before running the experiment! ***

# %%
# %pip install networkx pygraphviz
import networkx as nx
def visualize_nerlnet_graph(api_server_inst,  connections : dict , components): # connections is a dictionary with keys as routers and values as lists of their neighbors
    print("Connections: " , list(connections.items()))
    routers = list(connections.keys())
    print("Routers: " , routers)
    workers = list(components.map_worker_to_client.keys())
    print("Workers: " , workers)
    graph = nx.Graph()
    nodes = routers + components.sources + components.clients + workers + [API_SERVER_STR , MAIN_SERVER_STR]
    edges = [] # list of tuples
    for router , neighbors in list(connections.items()):
        for neighbor in neighbors:
            if (router,neighbor) not in edges:
                print(f"Adding edge ({router} , {neighbor}) to graph")
                edges.append((router , neighbor))
    edges.append((API_SERVER_STR , MAIN_SERVER_STR)) # Always connected
    for worker in workers:
        edges.append((worker , components.map_worker_to_client[worker]))
    graph.add_nodes_from(nodes)
    graph.add_edges_from(edges)
    
    my_labels = {'mainServer': 'mS' , 'apiServer': 'aS'}
    nx.relabel_nodes(graph, my_labels , copy=False)
    
    default_colors = {node:'#A90433' for node in graph.nodes()}
    node_colors = {node:default_colors[node] for node in graph.nodes()}
    nx.set_node_attributes(graph, node_colors, 'color')
    colors = nx.get_node_attributes(graph, 'color').values()

    pos = nx.nx_agraph.graphviz_layout(graph)
    angle = 100
    
    plt.figure(figsize=(8,6),dpi=150)
    nx.draw_networkx(graph, pos, with_labels=True, node_color=colors , node_size=200, font_size=8, font_color='white' , edge_color='black' , width=1.5)
    plt.show()
visualize_nerlnet_graph(API , API.json_dir_parser.json_from_path(conn_path)['connectionsMap'] , globe.components)
# Out:
# Requirement already satisfied: networkx in /tmp/nerlnet/virtualenv/lib/python3.8/site-packages (3.1)
# Requirement already satisfied: pygraphviz in /tmp/nerlnet/virtualenv/lib/python3.8/site-packages (1.11)
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Connections:  [('r1', ['mainServer', 'c1', 'r2', 'r7']), ('r2', ['c2', 's1', 'r3']), ('r3', ['c3', 's2', 'r4', 'r1']), ('r4', ['c4', 's3', 'r5', 'r2']), ('r5', ['c5', 's4', 'c9', 'r6']), ('r6', ['c6', 's5', 'r7', 'r3']), ('r7', ['c7', 's6', 'r8', 'r1']), ('r8', ['c8', 'c9', 'r9', 'r4']), ('r9', ['c10', 'c11', 'r10', 'r5']), ('r10', ['c12', 'r1', 'r6', 'r8'])]
# Routers:  ['r1', 'r2', 'r3', 'r4', 'r5', 'r6', 'r7', 'r8', 'r9', 'r10']
# Workers:  ['w1', 'w2', 'w3', 'w4', 'w5', 'w6', 'w7', 'w8', 'w9', 'w10', 'w11', 'w12']
# Adding edge (r1 , mainServer) to graph
# Adding edge (r1 , c1) to graph
# Adding edge (r1 , r2) to graph
# Adding edge (r1 , r7) to graph
# Adding edge (r2 , c2) to graph
# Adding edge (r2 , s1) to graph
# Adding edge (r2 , r3) to graph
# Adding edge (r3 , c3) to graph
# Adding edge (r3 , s2) to graph
# Adding edge (r3 , r4) to graph
# Adding edge (r3 , r1) to graph
# Adding edge (r4 , c4) to graph
# Adding edge (r4 , s3) to graph
# Adding edge (r4 , r5) to graph
# Adding edge (r4 , r2) to graph
# Adding edge (r5 , c5) to graph
# Adding edge (r5 , s4) to graph
# Adding edge (r5 , c9) to graph
# Adding edge (r5 , r6) to graph
# Adding edge (r6 , c6) to graph
# Adding edge (r6 , s5) to graph
# Adding edge (r6 , r7) to graph
# Adding edge (r6 , r3) to graph
# Adding edge (r7 , c7) to graph
# Adding edge (r7 , s6) to graph
# Adding edge (r7 , r8) to graph
# Adding edge (r7 , r1) to graph
# Adding edge (r8 , c8) to graph
# Adding edge (r8 , c9) to graph
# Adding edge (r8 , r9) to graph
# Adding edge (r8 , r4) to graph
# Adding edge (r9 , c10) to graph
# Adding edge (r9 , c11) to graph
# Adding edge (r9 , r10) to graph
# Adding edge (r9 , r5) to graph
# Adding edge (r10 , c12) to graph
# Adding edge (r10 , r1) to graph
# Adding edge (r10 , r6) to graph
# Adding edge (r10 , r8) to graph

# %%
API.send_jsons_to_devices()
# Out:
# [INFO][2024-08-06 15:32:00,544] Sending distributed configurations to devices is completed

# %%
API.run_current_experiment_phase()
# Out:
# [INFO][2024-08-06 15:32:00,552] Experiment phase: training_phase1 of type training starts running...
# [INFO][2024-08-06 15:32:00,554] Sending data to sources
# [INFO][2024-08-06 15:32:33,367] Data is ready in sources
# [INFO][2024-08-06 15:32:33,378] Phase training requested from Main Server
# [INFO][2024-08-06 15:35:07,982] Processing experiment phase data
# [INFO][2024-08-06 15:35:08,312] Processing experiment phase data completed
# [INFO][2024-08-06 15:35:08,315] Start generating communication statistics for training_phase1 of type training
# [INFO][2024-08-06 15:35:08,316] Statistics requested from Main Server
# [INFO][2024-08-06 15:35:08,420] Statistics received from Main Server
# [INFO][2024-08-06 15:35:08,422] Phase of training_phase1 training completed

# %%
stats_train1 = API.get_experiment_flow(exp_name).generate_stats()

# %%
stats_train1.get_loss_ts(plot=True)
# Out:
#           w12        w3        w7        w2        w9       w10        w1  \
# 0    0.444444  0.477778  0.422222  0.388889  0.422222  0.444444  0.511111
# 1    0.555556  0.388889  0.444444  0.422222  0.444444  0.555556  0.333333
# 2    0.655556  0.422222  0.522222  0.511111  0.522222  0.655556  0.555556
# 3    0.455556  0.511111  0.422222  0.444444  0.422222  0.455556  0.522222
# 4    0.511111  0.444444  0.522222  0.444444  0.522222  0.511111  0.422222
# ..        ...       ...       ...       ...       ...       ...       ...
# 385  0.099517       NaN       NaN       NaN       NaN  0.044444       NaN
# 386  0.000427       NaN       NaN       NaN       NaN  0.113769       NaN
# 387  0.026515       NaN       NaN       NaN       NaN  0.043256       NaN
# 388  0.000000       NaN       NaN       NaN       NaN  0.000000       NaN
# 389       NaN       NaN       NaN       NaN       NaN  0.000003       NaN
#
#            w4        w8        w5       w11        w6
# 0    0.511111  0.444444  0.477778  0.422222  0.511111
# 1    0.333333  0.555556  0.388889  0.444444  0.333333
# 2    0.522222  0.655556  0.422222  0.522222  0.555556
# 3    0.422222  0.455556  0.511111  0.422222  0.522222
# 4    0.433333  0.511111  0.444444  0.522222  0.422222
# ..        ...       ...       ...       ...       ...
# 385  0.111112  0.093046       NaN       NaN       NaN
# 386  0.111111  0.000107       NaN       NaN       NaN
# 387  0.111265  0.022334       NaN       NaN       NaN
# 388       NaN  0.000000       NaN       NaN       NaN
# 389       NaN       NaN       NaN       NaN       NaN
#
# [390 rows x 12 columns]

# %%
import pandas as pd
workers_comm_dict = stats_train1.get_communication_stats_workers()
df_train = pd.DataFrame.from_dict(workers_comm_dict)
plt.figure()
df_selected_train = df_train.iloc[[3,5]]
data_train = pd.melt(df_selected_train.reset_index(), id_vars=['index'], value_vars=df_train.columns)
batches_stats = sns.barplot(x='variable', y='value', hue='index', data=data_train)
plt.ylabel('Number Of Batches')
plt.xlabel('Worker')
plt.title("Received & Dropped Batches At Freq. 5B/s (Training1 Phase)")

batches_stats.legend(loc='upper right', bbox_to_anchor=(1.5, 0.2), shadow=True, ncol=1)
plt.show()

# %%
missed_dict = stats_train1.get_missed_batches()
print(missed_dict)
# Out:
# {'phase:training_phase1,s1->w2': [659, 663, 669, 673, 677, 683, 687, 691, 695, 707, 709, 713, 717, 727, 729, 733, 737, 741, 745, 751, 753, 757, 761, 765, 769, 775, 777], 'phase:training_phase1,s1->w1': [156, 176, 230, 520, 530, 536, 676, 686, 690, 694, 698, 702, 708, 710, 718, 722, 730, 732, 736, 740, 744, 748, 758, 760, 762, 766, 770, 774, 778], 'phase:training_phase1,s2->w3': [204, 228, 244, 256, 264, 302, 320, 574, 676, 680, 684, 688, 692, 696, 716, 718, 720, 726, 732, 738, 746, 750, 758, 760, 766, 768, 774], 'phase:training_phase1,s2->w4': [5, 15], 'phase:training_phase1,s3->w5': [22, 72, 140, 184, 272, 322, 460, 576, 684, 686, 702, 708, 710, 714, 720, 732, 734, 746, 754, 766, 768, 772, 778], 'phase:training_phase1,s3->w6': [21, 23, 43, 55, 71, 101, 121, 143, 147, 157, 173, 175, 193, 203, 231, 243, 261, 265, 267, 269, 281, 285, 291, 295, 301, 323, 361, 379, 381, 389, 393, 401, 435, 437, 439, 443, 453, 479, 485, 489, 497, 503, 565, 567, 569, 573, 579, 587, 599, 675, 677, 679, 685, 701, 707, 709, 717, 719, 731, 733, 755], 'phase:training_phase1,s4->w7': [268, 278, 440, 490, 712], 'phase:training_phase1,s4->w8': [721], 'phase:training_phase1,s5->w9': [194, 526, 528, 562, 572], 'phase:training_phase1,s6->w12': [627], 'phase:training_phase1,s6->w11': [38, 128, 138, 152, 162, 172, 188, 238, 240, 250, 268, 310, 312, 374, 378, 400, 404, 424, 444, 450, 452, 462, 472, 482, 512, 520, 528, 532, 542, 546, 548, 552, 558, 562, 568, 570, 572, 574, 576, 578, 580, 582, 584, 586, 588, 590, 592, 594, 596, 598, 600, 602, 604, 606, 608, 610, 612, 614, 616, 618, 620, 622, 624, 626, 628, 630, 632, 634, 636, 638, 640, 642, 644]}

# %%
API.next_experiment_phase()
API.run_current_experiment_phase()
# Out:
# [INFO][2024-08-06 15:35:09,555] Experiment phase: training_phase2 of type training starts running...
# [INFO][2024-08-06 15:35:09,556] Sending data to sources
# [INFO][2024-08-06 15:35:42,483] Data is ready in sources
# [INFO][2024-08-06 15:35:42,530] Phase training requested from Main Server
# [INFO][2024-08-06 15:38:25,350] Processing experiment phase data
# [INFO][2024-08-06 15:38:25,418] Processing experiment phase data completed
# [INFO][2024-08-06 15:38:25,419] Start generating communication statistics for training_phase2 of type training
# [INFO][2024-08-06 15:38:25,420] Statistics requested from Main Server
# [INFO][2024-08-06 15:38:25,826] Statistics received from Main Server
# [INFO][2024-08-06 15:38:25,827] Phase of training_phase2 training completed

# %%
stats_train2 = API.get_experiment_flow(exp_name).generate_stats()

# %%
stats_train2.get_loss_ts(plot=True)
# Out:
#           w10        w3        w4           w12   w2        w9        w6  \
# 0    0.000231  0.113573  0.080907  0.000000e+00  0.0  0.009381  0.222222
# 1    0.000408  0.152087  0.019795  4.009545e-07  0.0  0.000791  0.122489
# 2    0.000000  0.087413  0.000000  5.264285e-04  0.0  0.019462  0.000000
# 3    0.000000  0.075018  0.002216  0.000000e+00  0.0  0.000000  0.000000
# 4    0.000100  0.000478  0.000043  4.915942e-03  0.0  0.000000  0.000000
# ..        ...       ...       ...           ...  ...       ...       ...
# 373  0.072630       NaN       NaN           NaN  NaN  0.099525       NaN
# 374  0.111579       NaN       NaN           NaN  NaN       NaN       NaN
# 375  0.109371       NaN       NaN           NaN  NaN       NaN       NaN
# 376  0.107506       NaN       NaN           NaN  NaN       NaN       NaN
# 377  0.106026       NaN       NaN           NaN  NaN       NaN       NaN
#
#            w1        w7        w8       w11        w5
# 0    0.111111  0.000003  0.000000  0.111111  0.111111
# 1    0.040980  0.000000  0.000000  0.111111  0.111111
# 2    0.001910  0.024769  0.000000  0.111752  0.111111
# 3    0.000000  0.000118  0.000683  0.111111  0.111111
# 4    0.000000  0.000000  0.000000  0.111725  0.111111
# ..        ...       ...       ...       ...       ...
# 373       NaN       NaN       NaN       NaN       NaN
# 374       NaN       NaN       NaN       NaN       NaN
# 375       NaN       NaN       NaN       NaN       NaN
# 376       NaN       NaN       NaN       NaN       NaN
# 377       NaN       NaN       NaN       NaN       NaN
#
# [378 rows x 12 columns]

# %%
import pandas as pd
workers_comm_dict = stats_train2.get_communication_stats_workers()
df_train = pd.DataFrame.from_dict(workers_comm_dict)
plt.figure()
df_selected_train = df_train.iloc[[3,5]]
data_train = pd.melt(df_selected_train.reset_index(), id_vars=['index'], value_vars=df_train.columns)
batches_stats = sns.barplot(x='variable', y='value', hue='index', data=data_train)
plt.ylabel('Number Of Batches')
plt.xlabel('Worker')
plt.title("Received & Dropped Batches At Freq. 5B/s (Training2 Phase)")

batches_stats.legend(loc='upper right', bbox_to_anchor=(1.5, 0.2), shadow=True, ncol=1)
plt.show()

# %%
API.next_experiment_phase()
API.run_current_experiment_phase()
# Out:
# [INFO][2024-08-06 15:38:27,177] Experiment phase: training_phase3 of type training starts running...
# [INFO][2024-08-06 15:38:27,178] Sending data to sources
# [INFO][2024-08-06 15:38:59,601] Data is ready in sources
# [INFO][2024-08-06 15:38:59,603] Phase training requested from Main Server
# [INFO][2024-08-06 15:41:37,265] Processing experiment phase data
# [INFO][2024-08-06 15:41:37,297] Processing experiment phase data completed
# [INFO][2024-08-06 15:41:37,298] Start generating communication statistics for training_phase3 of type training
# [INFO][2024-08-06 15:41:37,299] Statistics requested from Main Server
# [INFO][2024-08-06 15:41:37,755] Statistics received from Main Server
# [INFO][2024-08-06 15:41:37,757] Phase of training_phase3 training completed

# %%
stats_train3 = API.get_experiment_flow(exp_name).generate_stats()

# %%
stats_train3.get_loss_ts(plot=True)
# Out:
#            w1        w5       w10        w2        w8        w9        w3  \
# 0    0.106514  0.082712  0.114436  0.105863  0.111278  0.112843  0.120793
# 1    0.104744  0.081206  0.112718  0.104137  0.109946  0.111200  0.118837
# 2    0.103321  0.079588  0.111031  0.102752  0.108651  0.109583  0.117198
# 3    0.101733  0.078001  0.109370  0.101255  0.107374  0.107993  0.115838
# 4    0.100261  0.076456  0.107736  0.099932  0.106117  0.106428  0.114366
# ..        ...       ...       ...       ...       ...       ...       ...
# 383       NaN       NaN       NaN       NaN  0.086445       NaN       NaN
# 384       NaN       NaN       NaN       NaN  0.085227       NaN       NaN
# 385       NaN       NaN       NaN       NaN  0.084021       NaN       NaN
# 386       NaN       NaN       NaN       NaN  0.082820       NaN       NaN
# 387       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#           w11       w12        w4        w6        w7
# 0    0.109816  0.112545  0.113465  0.070207  0.115446
# 1    0.108338  0.110962  0.111258  0.068573  0.113412
# 2    0.106906  0.109408  0.109436  0.066995  0.111420
# 3    0.105441  0.107843  0.107751  0.065615  0.109539
# 4    0.103998  0.106323  0.106117  0.064111  0.107757
# ..        ...       ...       ...       ...       ...
# 383       NaN       NaN  0.081051       NaN       NaN
# 384       NaN       NaN  0.079404       NaN       NaN
# 385       NaN       NaN  0.077752       NaN       NaN
# 386       NaN       NaN  0.076121       NaN       NaN
# 387       NaN       NaN  0.074422       NaN       NaN
#
# [388 rows x 12 columns]

# %%
import pandas as pd
workers_comm_dict = stats_train3.get_communication_stats_workers()
df_train = pd.DataFrame.from_dict(workers_comm_dict)
plt.figure()
df_selected_train = df_train.iloc[[3,5]]
data_train = pd.melt(df_selected_train.reset_index(), id_vars=['index'], value_vars=df_train.columns)
batches_stats = sns.barplot(x='variable', y='value', hue='index', data=data_train)
plt.ylabel('Number Of Batches')
plt.xlabel('Worker')
plt.title("Received & Dropped Batches At Freq. 5B/s (Training3 Phase)")

batches_stats.legend(loc='upper right', bbox_to_anchor=(1.5, 0.2), shadow=True, ncol=1)
plt.show()

# %%
API.next_experiment_phase()
API.run_current_experiment_phase()
# Out:
# [INFO][2024-08-06 15:41:40,098] Experiment phase: training_phase4 of type training starts running...
# [INFO][2024-08-06 15:41:40,099] Sending data to sources
# [INFO][2024-08-06 15:42:13,392] Data is ready in sources
# [INFO][2024-08-06 15:42:13,403] Phase training requested from Main Server
# [INFO][2024-08-06 15:44:52,282] Processing experiment phase data
# [INFO][2024-08-06 15:44:52,356] Processing experiment phase data completed
# [INFO][2024-08-06 15:44:52,357] Start generating communication statistics for training_phase4 of type training
# [INFO][2024-08-06 15:44:52,358] Statistics requested from Main Server
# [INFO][2024-08-06 15:44:52,713] Statistics received from Main Server
# [INFO][2024-08-06 15:44:52,714] Phase of training_phase4 training completed

# %%
stats_train4 = API.get_experiment_flow(exp_name).generate_stats()

# %%
stats_train4.get_loss_ts(plot=True)
# Out:
#            w1       w12        w2       w11        w4        w3        w9  \
# 0    0.089694  0.111760  0.090557  0.097623  0.103549  0.094616  0.097112
# 1    0.094166  0.109604  0.089610  0.106355  0.101713  0.103204  0.105131
# 2    0.093305  0.107688  0.088780  0.104902  0.100017  0.101487  0.103427
# 3    0.092461  0.106014  0.087864  0.103669  0.098347  0.099878  0.101960
# 4    0.091624  0.104492  0.086970  0.102615  0.096754  0.098376  0.100528
# ..        ...       ...       ...       ...       ...       ...       ...
# 384       NaN       NaN       NaN       NaN  0.068526       NaN  0.060832
# 385       NaN       NaN       NaN       NaN  0.067746       NaN       NaN
# 386       NaN       NaN       NaN       NaN  0.066930       NaN       NaN
# 387       NaN       NaN       NaN       NaN  0.066149       NaN       NaN
# 388       NaN       NaN       NaN       NaN  0.065332       NaN       NaN
#
#            w8        w6        w5       w10        w7
# 0    0.099566  0.081438  0.076064  0.105175  0.093798
# 1    0.098129  0.080562  0.065970  0.103131  0.098295
# 2    0.096831  0.079698  0.064589  0.101314  0.097373
# 3    0.095650  0.078828  0.063432  0.099631  0.096492
# 4    0.094561  0.077969  0.062342  0.098093  0.095631
# ..        ...       ...       ...       ...       ...
# 384       NaN       NaN       NaN       NaN       NaN
# 385       NaN       NaN       NaN       NaN       NaN
# 386       NaN       NaN       NaN       NaN       NaN
# 387       NaN       NaN       NaN       NaN       NaN
# 388       NaN       NaN       NaN       NaN       NaN
#
# [389 rows x 12 columns]

# %%
import pandas as pd
workers_comm_dict = stats_train4.get_communication_stats_workers()
df_train = pd.DataFrame.from_dict(workers_comm_dict)
plt.figure()
df_selected_train = df_train.iloc[[3,5]]
data_train = pd.melt(df_selected_train.reset_index(), id_vars=['index'], value_vars=df_train.columns)
batches_stats = sns.barplot(x='variable', y='value', hue='index', data=data_train)
plt.ylabel('Number Of Batches')
plt.xlabel('Worker')
plt.title("Received & Dropped Batches At Freq. 5B/s (Training4 Phase)")

batches_stats.legend(loc='upper right', bbox_to_anchor=(1.5, 0.2), shadow=True, ncol=1)
plt.show()

# %%
API.next_experiment_phase()
API.run_current_experiment_phase()
# Out:
# [INFO][2024-08-06 15:44:53,865] Experiment phase: prediction_phase of type prediction starts running...
# [INFO][2024-08-06 15:44:53,865] Sending data to sources
# [INFO][2024-08-06 15:45:03,540] Data is ready in sources
# [INFO][2024-08-06 15:45:03,541] Phase prediction requested from Main Server
# [INFO][2024-08-06 15:46:08,384] Processing experiment phase data
# [INFO][2024-08-06 15:46:08,428] Processing experiment phase data completed
# [INFO][2024-08-06 15:46:08,430] Start generating communication statistics for prediction_phase of type prediction
# [INFO][2024-08-06 15:46:08,433] Statistics requested from Main Server
# [INFO][2024-08-06 15:46:08,537] Statistics received from Main Server
# [INFO][2024-08-06 15:46:08,539] Phase of prediction_phase prediction completed

# %%
stats_pred = API.get_experiment_flow(exp_name).generate_stats()

# %%
import pandas as pd
workers_comm_dict = stats_pred.get_communication_stats_workers()
df_pred = pd.DataFrame.from_dict(workers_comm_dict)
plt.figure()
df_selected_pred = df_pred.iloc[[4,6]]
data_pred = pd.melt(df_selected_pred.reset_index(), id_vars=['index'], value_vars=df_pred.columns)
batches_stats = sns.barplot(x='variable', y='value', hue='index', data=data_pred)
plt.ylabel('Number Of Batches')
plt.xlabel('Worker')
plt.title("Received & Dropped Batches At Freq. 5B/s (Prediction Phase)")

batches_stats.legend(loc='upper right', bbox_to_anchor=(1.5, 0.2), shadow=True, ncol=1)
plt.show()

# %%
_ , conf_mats = stats_pred.get_confusion_matrices_new(plot=True)
