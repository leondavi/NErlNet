# %% [raw]
# This Experimnet is:
# 18 Devices
# 12 workers
# 6 people- each person send to 2 workers with RR policy
#
# There is 2 training phase, and 1 prediction phase.

# %%
import set_jupyter_env
from apiServer import *
import pandas as pd

# %%
API = ApiServer()

# %%
API.showJsons()
# Out:
# Distributed Configuration Files
# --------------------
#
# 0.	dc_10w_14d_8r_3s_10c_synt.json
# 1.	dc_12w_12c_13d_4s_4r_tiles_rr.json
# 2.	dc_5d_4c_4s_4r_12w.json
# 3.	dc_AEC_1d_2c_1s_4r_4w.json
# 4.	dc_EEG_18d_12c_6s_10r_12w_RR.json
# 5.	dc_EEG_18d_9c_3s_5r_9w_RR.json
# 6.	dc_EEG_1d_1c_3s_2r_3w_RR.json
# 7.	dc_EEG_4d_3c_3s_2r_3w.json
# 8.	dc_EEG_8d_1c_3s_2r_3w_RR.json
# 9.	dc_EEG_8d_3c_3s_2r_3w.json
# 10.	dc_EEG_8d_3c_3s_2r_3w_RR.json
# 11.	dc_EEG_8d_3c_3s_2r_3w_demo_RR.json
# 12.	dc_EEG_8d_3c_3s_5r_3w_RR.json
# 13.	dc_EEG_8d_8c_3s_5r_8w_RR.json
# 14.	dc_FedTorchTest_5d_2s_2r_4c_4w.json
# 15.	dc_dist_14d.json
# 16.	dc_dist_2d_3c_2s_3r_6w.json
# 17.	dc_fed_dist_14d.json
# 18.	dc_fed_dist_2d_3c_2s_3r_6w.json
# 19.	dc_fed_synt_1d_2c_2r_1s_4w_1ws.json
# 20.	dc_mnist_13d_12w_4r_3s_3tokens.json
# 21.	dc_mnist_4w_5d_4r_4s_rr.json
# 22.	dc_synt_8d_8w_2c_4s_4r.json
# 23.	dc_synt_8d_8w_4c_6r_4s.json
# 24.	dc_synt_distributed_w5_c3_6r_3s_3d.json
# 25.	dc_test_synt_1d_2c_1s_4r_4w.json
# 26.	dc_test_synt_1d_2c_2s_4r_4w.json
#
# Connection Map Files
# --------------------
#
# 0.	conn_1Router1Client1S.json
# 1.	conn_1Router1Client2S.json
# 2.	conn_1Router2Clients1S.json
# 3.	conn_1Router3Clients1S.json
# 4.	conn_1Router4Clients1S.json
# 5.	conn_1Router4Clients1fed.json
# 6.	conn_1Router4Clients2Sources.json
# 7.	conn_1Router4Clients2Sources1fed.json
# 8.	conn_2R4C1S_health_david.json
# 9.	conn_2Router2Clients1Source.json
# 10.	conn_2Router2Clients1Source_david.json
# 11.	conn_2Router2Clients2Source.json
# 12.	conn_2Router2ClientsGUI.json
# 13.	conn_2Router3Clients.json
# 14.	conn_3Router3Clients.json
# 15.	conn_4Router12Client4S.json
# 16.	conn_4Router4Client4S.json
# 17.	conn_4Router4Clients4S_mnist.json
# 18.	conn_6RouterCycle6Clients1Source.json
# 19.	conn_6RouterCycle8Clients1Source.json
# 20.	conn_6RouterLine6Clients1Source.json
# 21.	conn_8RouterCycle8Clients1Source.json
# 22.	conn_8Routers10Clients3S.json
# 23.	conn_EEG_10Router12Clients6Source_EEG.json
# 24.	conn_EEG_2Router1Clients3Source_EEG.json
# 25.	conn_EEG_2Router3Clients3Source_EEG.json
# 26.	conn_EEG_5Router3Clients3Source_EEG.json
# 27.	conn_EEG_5Router8Clients3Source_EEG.json
# 28.	conn_EEG_5Router9Clients3Source_EEG.json
# 29.	conn_fed_dist_14d.json
# 30.	conn_fed_dist_2d_3c_2s_3r_6w.json
# 31.	conn_fed_synt_1d_2c_2r_1s_4w_1ws.json
# 32.	conn_synt_8d_8w_4c_6r_4s.json
# 33.	conn_synt_dc_8d_8w_2c_4s_4r.json
# 34.	conn_synt_distributed_w5_c3_6r_3s_3d.json
# 35.	conn_test_synt_1d_2c_1s_4r_4w.json
# 36.	conn_test_synt_1d_2c_2s_4r_4w.json
#
# Experiments Flow Files
# --------------------
#
# 0.	exp_AEC_1d_2c_1s_4r_4w.json
# 1.	exp_EEG_3c_3s_2r_3w_3people.json
# 2.	exp_EEG_3c_3s_2r_3w_half3_people.json
# 3.	exp_EEG_3c_3s_2r_3w_half3_people_3exp_tr_phase.json
# 4.	exp_EEG_3c_3s_2r_3w_small_sample_RR.json
# 5.	exp_EEG_3s_3w_half3_people_RR.json
# 6.	exp_EEG_3s_8w_3_people_RR.json
# 7.	exp_EEG_3s_8w_3people_RR.json
# 8.	exp_EEG_3s_8w_half3_people_RR.json
# 9.	exp_EEG_3s_9w_3people_RR.json
# 10.	exp_EEG_6s_12w_6people_RR_1Tp.json
# 11.	exp_EEG_6s_12w_6people_RR_2Tp.json
# 12.	exp_EEG_6s_12w_6people_RR_2Tp_CMTest.json
# 13.	exp_FedTorchTest_5d_2s_2r_4c_4w.json
# 14.	exp_dist_14d.json
# 15.	exp_dist_14d_10c_3s_8r_10w.json
# 16.	exp_dist_2d_3c_2s_3r_6w.json
# 17.	exp_fed_dist_14d.json
# 18.	exp_fed_dist_2d_3c_2s_3r_6w.json
# 19.	exp_fed_synt_1d_2c_2r_1s_4w_1ws.json
# 20.	exp_mnist_5d_4c_4s_4w_4r.json
# 21.	exp_new_arc.json
# 22.	exp_synt_8d_8w_2c_4s_4r.json
# 23.	exp_synt_8d_8w_4c_6r_4s.json
# 24.	exp_synt_distributed_w5_c3_6r_3s_3d.json
# 25.	exp_test_synt_1d_2c_1s_4r_4w new.json
# 26.	exp_tiles_13d_12c_4s_4r_12w_rr.json
# 27.	exp_tiles_4d_4c_4s_4r_12w.json

# %%
dc = 4
conn = 23
exp = 12
API.setJsons(dc , conn , exp)

# %%
dc_path , conn_path , exp_path = API.getUserJsons()

# %%
exp_name = "EEG_Emotion_18Devices_6Persons_RR"
API.initialization(exp_name, dc_path, conn_path, exp_path)
# Out:
# [INFO][2024-08-06 13:58:41,259]
# Network components:
#                  Receiver's Address: http://10.0.0.11:8930
#                  Frequency: 5 [batches/sec]
#                  Batchsize: 10 [samples]
#                  devicesIp: ['10.0.0.11', '10.0.0.8', '10.0.0.12', '10.0.0.10', '10.0.0.32', '10.0.0.33', '10.0.0.34', '10.0.0.35', '10.0.0.47', '10.0.0.48', '10.0.0.49', '10.0.0.50', '10.0.0.51', '10.0.0.52', '10.0.0.53', '10.0.0.54', '10.0.0.55', '10.0.0.56']
#                  mainServerIp: 10.0.0.11
#                  mainServerPort: 8900
#                  apiServerIp: 10.0.0.11
#                  apiServerPort: 8930
#                  Clients: ['c1', 'c2', 'c3', 'c4', 'c5', 'c6', 'c7', 'c8', 'c9', 'c10', 'c11', 'c12']
#                  Workers: ['w1', 'w2', 'w3', 'w4', 'w5', 'w6', 'w7', 'w8', 'w9', 'w10', 'w11', 'w12']
#                  Sources: ['s1', 's2', 's3', 's4', 's5', 's6']
#                  Routers: ['r1', 'r2', 'r3', 'r4', 'r5', 'r6', 'r7', 'r8', 'r9', 'r10']
# [INFO][2024-08-06 13:58:41,261] Connections:
# [INFO][2024-08-06 13:58:41,261] 		 r1 : ['mainServer', 'c1', 'r2', 'r7']
# [INFO][2024-08-06 13:58:41,262] 		 r2 : ['c2', 's1', 'r3']
# [INFO][2024-08-06 13:58:41,262] 		 r3 : ['c3', 's2', 'r4', 'r1']
# [INFO][2024-08-06 13:58:41,263] 		 r4 : ['c4', 's3', 'r5', 'r2']
# [INFO][2024-08-06 13:58:41,264] 		 r5 : ['c5', 's4', 'c9', 'r6']
# [INFO][2024-08-06 13:58:41,264] 		 r6 : ['c6', 's5', 'r7', 'r3']
# [INFO][2024-08-06 13:58:41,265] 		 r7 : ['c7', 's6', 'r8', 'r1']
# [INFO][2024-08-06 13:58:41,265] 		 r8 : ['c8', 'c9', 'r9', 'r4']
# [INFO][2024-08-06 13:58:41,266] 		 r9 : ['c10', 'c11', 'r10', 'r5']
# [INFO][2024-08-06 13:58:41,266] 		 r10 : ['c12', 'r1', 'r6', 'r8']
# [INFO][2024-08-06 13:58:41,268] Experiment name: EEG_Valence_Recognition_DEAP
# [INFO][2024-08-06 13:58:41,268] Batch size: 10
# [INFO][2024-08-06 13:58:41,269] Number of features: 70
# [INFO][2024-08-06 13:58:41,270] Number of labels: 9
# [INFO][2024-08-06 13:58:41,270]
# [INFO][2024-08-06 13:58:41,271] Phases:
# [INFO][2024-08-06 13:58:41,272]    Phase name: training_phase1
# [INFO][2024-08-06 13:58:41,276]    Phase type: training
# [INFO][2024-08-06 13:58:41,276]    Sources: s1,s2,s3,s4,s5,s6
# [INFO][2024-08-06 13:58:41,277]
# [INFO][2024-08-06 13:58:41,277]     Source pieces:
# [INFO][2024-08-06 13:58:41,278]          Source name: s1
# [INFO][2024-08-06 13:58:41,278]          Batch size: 10
# [INFO][2024-08-06 13:58:41,279]          Phase: training
# [INFO][2024-08-06 13:58:41,280]          Starting offset: 10
# [INFO][2024-08-06 13:58:41,280]          Number of batches: 100
# [INFO][2024-08-06 13:58:41,281]          Workers target: w1,w2
# [INFO][2024-08-06 13:58:41,281]       ----------------------
# [INFO][2024-08-06 13:58:41,282]
# [INFO][2024-08-06 13:58:41,283]          Source name: s2
# [INFO][2024-08-06 13:58:41,283]          Batch size: 10
# [INFO][2024-08-06 13:58:41,283]          Phase: training
# [INFO][2024-08-06 13:58:41,284]          Starting offset: 19520
# [INFO][2024-08-06 13:58:41,285]          Number of batches: 100
# [INFO][2024-08-06 13:58:41,286]          Workers target: w3,w4
# [INFO][2024-08-06 13:58:41,287]       ----------------------
# [INFO][2024-08-06 13:58:41,287]
# [INFO][2024-08-06 13:58:41,289]          Source name: s3
# [INFO][2024-08-06 13:58:41,289]          Batch size: 10
# [INFO][2024-08-06 13:58:41,290]          Phase: training
# [INFO][2024-08-06 13:58:41,290]          Starting offset: 39040
# [INFO][2024-08-06 13:58:41,291]          Number of batches: 100
# [INFO][2024-08-06 13:58:41,292]          Workers target: w5,w6
# [INFO][2024-08-06 13:58:41,292]       ----------------------
# [INFO][2024-08-06 13:58:41,293]
# [INFO][2024-08-06 13:58:41,293]          Source name: s4
# [INFO][2024-08-06 13:58:41,294]          Batch size: 10
# [INFO][2024-08-06 13:58:41,294]          Phase: training
# [INFO][2024-08-06 13:58:41,295]          Starting offset: 58650
# [INFO][2024-08-06 13:58:41,296]          Number of batches: 100
# [INFO][2024-08-06 13:58:41,297]          Workers target: w7,w8
# [INFO][2024-08-06 13:58:41,298]       ----------------------
# [INFO][2024-08-06 13:58:41,298]
# [INFO][2024-08-06 13:58:41,299]          Source name: s5
# [INFO][2024-08-06 13:58:41,299]          Batch size: 10
# [INFO][2024-08-06 13:58:41,300]          Phase: training
# [INFO][2024-08-06 13:58:41,300]          Starting offset: 78170
# [INFO][2024-08-06 13:58:41,302]          Number of batches: 100
# [INFO][2024-08-06 13:58:41,302]          Workers target: w9,w10
# [INFO][2024-08-06 13:58:41,303]       ----------------------
# [INFO][2024-08-06 13:58:41,304]
# [INFO][2024-08-06 13:58:41,304]          Source name: s6
# [INFO][2024-08-06 13:58:41,305]          Batch size: 10
# [INFO][2024-08-06 13:58:41,305]          Phase: training
# [INFO][2024-08-06 13:58:41,306]          Starting offset: 97690
# [INFO][2024-08-06 13:58:41,307]          Number of batches: 100
# [INFO][2024-08-06 13:58:41,307]          Workers target: w11,w12
# [INFO][2024-08-06 13:58:41,308]       ----------------------
# [INFO][2024-08-06 13:58:41,308]
# [INFO][2024-08-06 13:58:41,309]    Phase name: training_phase2
# [INFO][2024-08-06 13:58:41,309]    Phase type: training
# [INFO][2024-08-06 13:58:41,310]    Sources: s1,s2,s3,s4,s5,s6
# [INFO][2024-08-06 13:58:41,311]
# [INFO][2024-08-06 13:58:41,311]     Source pieces:
# [INFO][2024-08-06 13:58:41,312]          Source name: s1
# [INFO][2024-08-06 13:58:41,312]          Batch size: 10
# [INFO][2024-08-06 13:58:41,313]          Phase: training
# [INFO][2024-08-06 13:58:41,314]          Starting offset: 7810
# [INFO][2024-08-06 13:58:41,315]          Number of batches: 100
# [INFO][2024-08-06 13:58:41,315]          Workers target: w1,w2
# [INFO][2024-08-06 13:58:41,316]       ----------------------
# [INFO][2024-08-06 13:58:41,316]
# [INFO][2024-08-06 13:58:41,317]          Source name: s2
# [INFO][2024-08-06 13:58:41,318]          Batch size: 10
# [INFO][2024-08-06 13:58:41,318]          Phase: training
# [INFO][2024-08-06 13:58:41,319]          Starting offset: 27325
# [INFO][2024-08-06 13:58:41,319]          Number of batches: 100
# [INFO][2024-08-06 13:58:41,320]          Workers target: w3,w4
# [INFO][2024-08-06 13:58:41,320]       ----------------------
# [INFO][2024-08-06 13:58:41,321]
# [INFO][2024-08-06 13:58:41,321]          Source name: s3
# [INFO][2024-08-06 13:58:41,322]          Batch size: 10
# [INFO][2024-08-06 13:58:41,322]          Phase: training
# [INFO][2024-08-06 13:58:41,323]          Starting offset: 46845
# [INFO][2024-08-06 13:58:41,323]          Number of batches: 100
# [INFO][2024-08-06 13:58:41,324]          Workers target: w5,w6
# [INFO][2024-08-06 13:58:41,324]       ----------------------
# [INFO][2024-08-06 13:58:41,325]
# [INFO][2024-08-06 13:58:41,325]          Source name: s4
# [INFO][2024-08-06 13:58:41,326]          Batch size: 10
# [INFO][2024-08-06 13:58:41,326]          Phase: training
# [INFO][2024-08-06 13:58:41,327]          Starting offset: 66455
# [INFO][2024-08-06 13:58:41,327]          Number of batches: 100
# [INFO][2024-08-06 13:58:41,328]          Workers target: w7,w8
# [INFO][2024-08-06 13:58:41,328]       ----------------------
# [INFO][2024-08-06 13:58:41,329]
# [INFO][2024-08-06 13:58:41,329]          Source name: s5
# [INFO][2024-08-06 13:58:41,330]          Batch size: 10
# [INFO][2024-08-06 13:58:41,331]          Phase: training
# [INFO][2024-08-06 13:58:41,331]          Starting offset: 85975
# [INFO][2024-08-06 13:58:41,332]          Number of batches: 100
# [INFO][2024-08-06 13:58:41,332]          Workers target: w9,w10
# [INFO][2024-08-06 13:58:41,333]       ----------------------
# [INFO][2024-08-06 13:58:41,333]
# [INFO][2024-08-06 13:58:41,334]          Source name: s6
# [INFO][2024-08-06 13:58:41,334]          Batch size: 10
# [INFO][2024-08-06 13:58:41,335]          Phase: training
# [INFO][2024-08-06 13:58:41,335]          Starting offset: 105495
# [INFO][2024-08-06 13:58:41,336]          Number of batches: 100
# [INFO][2024-08-06 13:58:41,336]          Workers target: w11,w12
# [INFO][2024-08-06 13:58:41,337]       ----------------------
# [INFO][2024-08-06 13:58:41,337]
# [INFO][2024-08-06 13:58:41,338]    Phase name: prediction_phase
# [INFO][2024-08-06 13:58:41,339]    Phase type: prediction
# [INFO][2024-08-06 13:58:41,341]    Sources: s1,s2,s3,s4,s5,s6
# [INFO][2024-08-06 13:58:41,342]
# [INFO][2024-08-06 13:58:41,342]     Source pieces:
# [INFO][2024-08-06 13:58:41,343]          Source name: s1
# [INFO][2024-08-06 13:58:41,344]          Batch size: 10
# [INFO][2024-08-06 13:58:41,344]          Phase: prediction
# [INFO][2024-08-06 13:58:41,345]          Starting offset: 15610
# [INFO][2024-08-06 13:58:41,345]          Number of batches: 50
# [INFO][2024-08-06 13:58:41,346]          Workers target: w1,w2
# [INFO][2024-08-06 13:58:41,346]       ----------------------
# [INFO][2024-08-06 13:58:41,347]
# [INFO][2024-08-06 13:58:41,347]          Source name: s2
# [INFO][2024-08-06 13:58:41,348]          Batch size: 10
# [INFO][2024-08-06 13:58:41,348]          Phase: prediction
# [INFO][2024-08-06 13:58:41,349]          Starting offset: 35130
# [INFO][2024-08-06 13:58:41,349]          Number of batches: 50
# [INFO][2024-08-06 13:58:41,350]          Workers target: w3,w4
# [INFO][2024-08-06 13:58:41,350]       ----------------------
# [INFO][2024-08-06 13:58:41,351]
# [INFO][2024-08-06 13:58:41,351]          Source name: s3
# [INFO][2024-08-06 13:58:41,352]          Batch size: 10
# [INFO][2024-08-06 13:58:41,352]          Phase: prediction
# [INFO][2024-08-06 13:58:41,353]          Starting offset: 54650
# [INFO][2024-08-06 13:58:41,354]          Number of batches: 50
# [INFO][2024-08-06 13:58:41,354]          Workers target: w5,w6
# [INFO][2024-08-06 13:58:41,355]       ----------------------
# [INFO][2024-08-06 13:58:41,355]
# [INFO][2024-08-06 13:58:41,356]          Source name: s4
# [INFO][2024-08-06 13:58:41,356]          Batch size: 10
# [INFO][2024-08-06 13:58:41,357]          Phase: prediction
# [INFO][2024-08-06 13:58:41,357]          Starting offset: 74260
# [INFO][2024-08-06 13:58:41,358]          Number of batches: 50
# [INFO][2024-08-06 13:58:41,361]          Workers target: w7,w8
# [INFO][2024-08-06 13:58:41,361]       ----------------------
# [INFO][2024-08-06 13:58:41,362]
# [INFO][2024-08-06 13:58:41,368]          Source name: s5
# [INFO][2024-08-06 13:58:41,368]          Batch size: 10
# [INFO][2024-08-06 13:58:41,369]          Phase: prediction
# [INFO][2024-08-06 13:58:41,369]          Starting offset: 93780
# [INFO][2024-08-06 13:58:41,370]          Number of batches: 50
# [INFO][2024-08-06 13:58:41,371]          Workers target: w9,w10
# [INFO][2024-08-06 13:58:41,371]       ----------------------
# [INFO][2024-08-06 13:58:41,372]
# [INFO][2024-08-06 13:58:41,372]          Source name: s6
# [INFO][2024-08-06 13:58:41,373]          Batch size: 10
# [INFO][2024-08-06 13:58:41,373]          Phase: prediction
# [INFO][2024-08-06 13:58:41,374]          Starting offset: 113300
# [INFO][2024-08-06 13:58:41,375]          Number of batches: 50
# [INFO][2024-08-06 13:58:41,376]          Workers target: w11,w12
# [INFO][2024-08-06 13:58:41,377]       ----------------------
# [INFO][2024-08-06 13:58:41,377]
# [INFO][2024-08-06 13:58:41,378] Initializing ApiServer receiver thread
#  * Serving Flask app 'receiver'
#  * Debug mode: off
# [INFO][2024-08-06 13:58:43,380] *** Remember to execute NerlnetRun.sh on each device before running the experiment! ***

# %%
# %pip install networkx pygraphviz
import networkx as nx
def visualize_nerlnet_graph(api_server_inst,  connections : dict , components): # connections is a dictionary with keys as routers and values as lists of their neighbors
    print("Connections: " , list(connections.items()))
    routers = list(connections.keys())
    print("Routers: " , routers)
    workers = list(components.map_worker_to_client.keys())
    print("Workers: " , workers)
    graph = nx.Graph()
    nodes = routers + components.sources + components.clients + workers + [API_SERVER_STR , MAIN_SERVER_STR]
    edges = [] # list of tuples
    for router , neighbors in list(connections.items()):
        for neighbor in neighbors:
            if (router,neighbor) not in edges:
                print(f"Adding edge ({router} , {neighbor}) to graph")
                edges.append((router , neighbor))
    edges.append((API_SERVER_STR , MAIN_SERVER_STR)) # Always connected
    for worker in workers:
        edges.append((worker , components.map_worker_to_client[worker]))
    graph.add_nodes_from(nodes)
    graph.add_edges_from(edges)
    
    my_labels = {'mainServer': 'mS' , 'apiServer': 'aS'}
    nx.relabel_nodes(graph, my_labels , copy=False)
    
    default_colors = {node:'#A90433' for node in graph.nodes()}
    node_colors = {node:default_colors[node] for node in graph.nodes()}
    nx.set_node_attributes(graph, node_colors, 'color')
    colors = nx.get_node_attributes(graph, 'color').values()

    pos = nx.nx_agraph.graphviz_layout(graph)
    angle = 100
    
    plt.figure(figsize=(8,6),dpi=150)
    nx.draw_networkx(graph, pos, with_labels=True, node_color=colors , node_size=200, font_size=8, font_color='white' , edge_color='black' , width=1.5)
    plt.show()
visualize_nerlnet_graph(API , API.json_dir_parser.json_from_path(conn_path)['connectionsMap'] , globe.components)
# Out:
# Requirement already satisfied: networkx in /tmp/nerlnet/virtualenv/lib/python3.8/site-packages (3.1)
# Requirement already satisfied: pygraphviz in /tmp/nerlnet/virtualenv/lib/python3.8/site-packages (1.11)
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Connections:  [('r1', ['mainServer', 'c1', 'r2', 'r7']), ('r2', ['c2', 's1', 'r3']), ('r3', ['c3', 's2', 'r4', 'r1']), ('r4', ['c4', 's3', 'r5', 'r2']), ('r5', ['c5', 's4', 'c9', 'r6']), ('r6', ['c6', 's5', 'r7', 'r3']), ('r7', ['c7', 's6', 'r8', 'r1']), ('r8', ['c8', 'c9', 'r9', 'r4']), ('r9', ['c10', 'c11', 'r10', 'r5']), ('r10', ['c12', 'r1', 'r6', 'r8'])]
# Routers:  ['r1', 'r2', 'r3', 'r4', 'r5', 'r6', 'r7', 'r8', 'r9', 'r10']
# Workers:  ['w1', 'w2', 'w3', 'w4', 'w5', 'w6', 'w7', 'w8', 'w9', 'w10', 'w11', 'w12']
# Adding edge (r1 , mainServer) to graph
# Adding edge (r1 , c1) to graph
# Adding edge (r1 , r2) to graph
# Adding edge (r1 , r7) to graph
# Adding edge (r2 , c2) to graph
# Adding edge (r2 , s1) to graph
# Adding edge (r2 , r3) to graph
# Adding edge (r3 , c3) to graph
# Adding edge (r3 , s2) to graph
# Adding edge (r3 , r4) to graph
# Adding edge (r3 , r1) to graph
# Adding edge (r4 , c4) to graph
# Adding edge (r4 , s3) to graph
# Adding edge (r4 , r5) to graph
# Adding edge (r4 , r2) to graph
# Adding edge (r5 , c5) to graph
# Adding edge (r5 , s4) to graph
# Adding edge (r5 , c9) to graph
# Adding edge (r5 , r6) to graph
# Adding edge (r6 , c6) to graph
# Adding edge (r6 , s5) to graph
# Adding edge (r6 , r7) to graph
# Adding edge (r6 , r3) to graph
# Adding edge (r7 , c7) to graph
# Adding edge (r7 , s6) to graph
# Adding edge (r7 , r8) to graph
# Adding edge (r7 , r1) to graph
# Adding edge (r8 , c8) to graph
# Adding edge (r8 , c9) to graph
# Adding edge (r8 , r9) to graph
# Adding edge (r8 , r4) to graph
# Adding edge (r9 , c10) to graph
# Adding edge (r9 , c11) to graph
# Adding edge (r9 , r10) to graph
# Adding edge (r9 , r5) to graph
# Adding edge (r10 , c12) to graph
# Adding edge (r10 , r1) to graph
# Adding edge (r10 , r6) to graph
# Adding edge (r10 , r8) to graph

# %%
API.send_jsons_to_devices()
# Out:
# [INFO][2024-08-06 13:58:47,426] Sending distributed configurations to devices is completed

# %%
API.run_current_experiment_phase()
# Out:
# [INFO][2024-08-06 13:58:47,434] Experiment phase: training_phase1 of type training starts running...
# [INFO][2024-08-06 13:58:47,438] Sending data to sources
# [INFO][2024-08-06 13:58:51,530] Data is ready in sources
# [INFO][2024-08-06 13:58:51,531] Phase training requested from Main Server
# [INFO][2024-08-06 13:59:11,845] Processing experiment phase data
# [INFO][2024-08-06 13:59:11,852] Processing experiment phase data completed
# [INFO][2024-08-06 13:59:11,853] Start generating communication statistics for training_phase1 of type training
# [INFO][2024-08-06 13:59:11,854] Statistics requested from Main Server
# [INFO][2024-08-06 13:59:12,259] Statistics received from Main Server
# [INFO][2024-08-06 13:59:12,261] Phase of training_phase1 training completed

# %%
stats_train1 = API.get_experiment_flow(exp_name).generate_stats()

# %%
stats_train1.get_loss_ts(plot=True)
# Out:
#           w9       w11        w1       w12        w4        w8        w5  \
# 0   0.422222  0.422222  0.511111  0.444444  0.511111  0.444444  0.477778
# 1   0.444444  0.444444  0.333333  0.555556  0.333333  0.555556  0.388889
# 2   0.522222  0.522222  0.555556  0.655556  0.555556  0.655556  0.511111
# 3   0.422222  0.422222  0.422222  0.455556  0.522222  0.455556  0.444444
# 4   0.522222  0.522222  0.433333  0.511111  0.422222  0.511111  0.444444
# 5   0.544444  0.544444  0.522222  0.344444  0.433333  0.344444  0.555556
# 6   0.344444  0.344444  0.411111  0.344444  0.522222  0.344444  0.644444
# 7   0.344444  0.344444  0.500000  0.566667  0.411111  0.566667  0.433333
# 8   0.644444  0.644444  0.544444  0.500000  0.500000  0.500000  0.500000
# 9   0.555556  0.555556  0.344444  0.488889  0.544444  0.488889  0.344444
# 10  0.533333  0.533333  0.333333  0.411111  0.344444  0.411111  0.344444
# 11  0.411111  0.411111  0.611111  0.333333  0.333333  0.333333  0.566667
# 12  0.488889  0.488889  0.533333  0.533333  0.611111  0.533333  0.477778
# 13  0.400000  0.400000  0.533333  0.366667  0.533333  0.366667  0.444444
# 14  0.422222  0.422222  0.500000  0.488889  0.544444  0.488889  0.422222
# 15  0.388889  0.388889  0.400000  0.411111  0.400000  0.411111  0.333333
# 16  0.511111  0.511111  0.411111  0.355556  0.511111  0.355556  0.533333
# 17  0.444444  0.444444  0.377778  0.444444  0.388889  0.444444  0.366667
# 18  0.433333  0.433333  0.488889  0.411111  0.388889  0.411111  0.455556
# 19  0.422222  0.422222  0.466667  0.433333  0.366667  0.433333  0.422222
# 20  0.355556  0.355556  0.422222  0.388889  0.488889  0.388889  0.377778
# 21  0.555556  0.555556  0.444444  0.455556  0.477778  0.455556  0.444444
# 22  0.444444  0.444444  0.355556  0.444444  0.400000  0.444444  0.400000
# 23  0.411111  0.411111  0.555556  0.433333  0.444444  0.433333  0.422222
# 24  0.444444  0.444444  0.455556  0.455556  0.355556  0.455556  0.466667
# 25  0.455556  0.455556  0.422222  0.544444  0.555556  0.544444  0.444444
# 21  0.388889  0.444444  0.444444  0.555556  0.455556
# 22  0.444444  0.400000  0.422222  0.444444  0.444444
# 23  0.400000  0.422222  0.444444  0.411111  0.433333
# 24  0.422222  0.411111  0.455556  0.444444  0.455556
# 25  0.411111  0.466667  0.555556  0.455556  0.544444
# 26  0.466667  0.444444  0.522222  0.555556  0.544444
# 27  0.444444  0.444444  0.411111  0.522222  0.355556
# 28  0.444444  0.444444  0.455556  0.411111  0.555556
# 29  0.444444  0.555556  0.333333  0.455556  0.488889
# 30  0.555556  0.544444  0.400000  0.511111  0.455556
# 31  0.544444  0.355556  0.433333  0.355556  0.388889
# 32  0.355556  0.566667  0.422222  0.400000  0.411111
# 33  0.577778  0.488889  0.444444  0.433333  0.333333
# 34  0.488889  0.455556  0.355556  0.422222  0.377778
# 35  0.455556  0.388889  0.511111  0.444444  0.455556
# 36  0.388889  0.444444  0.511111  0.355556  0.555556
# 37  0.444444  0.333333  0.522222  0.533333  0.455556
# 38  0.333333  0.388889  0.644444  0.511111  0.477778
# 39  0.388889  0.477778  0.533333  0.522222  0.544444
# 40  0.466667  0.566667  0.444444  0.455556  0.622222
# 41  0.566667  0.444444  0.555556  0.644444  0.400000
# 42  0.433333  0.466667  0.500000  0.533333  0.566667
# 43  0.500000  0.544444       NaN  0.466667  0.477778
# 44  0.555556  0.633333       NaN  0.566667  0.533333
# 45  0.633333  0.422222       NaN  0.500000  0.555556
# 46  0.422222  0.622222       NaN  0.555556  0.466667
# 47  0.622222  0.522222       NaN  0.488889  0.500000
# 48  0.544444  0.533333       NaN  0.422222  0.488889
# 49  0.533333  0.555556       NaN  0.544444  0.511111

# %%
import pandas as pd
workers_comm_dict = stats_train1.get_communication_stats_workers()
df_train = pd.DataFrame.from_dict(workers_comm_dict)
plt.figure()
df_selected_train = df_train.iloc[[3,5]]
data_train = pd.melt(df_selected_train.reset_index(), id_vars=['index'], value_vars=df_train.columns)
batches_stats = sns.barplot(x='variable', y='value', hue='index', data=data_train)
plt.ylabel('Number Of Batches')
plt.xlabel('Worker')
plt.title("Received & Dropped Batches At Freq. 5B/s (Training Phase)")

batches_stats.legend(loc='upper right', bbox_to_anchor=(1.5, 0.2), shadow=True, ncol=1)
plt.show()

# %%
missed_dict = stats_train1.get_missed_batches()
print(missed_dict)
# Out:
# {'phase:training_phase1,s1->w1': [6, 30], 'phase:training_phase1,s3->w5': [4, 50], 'phase:training_phase1,s3->w6': [7, 15, 19, 29, 51, 69, 89]}

# %%
API.next_experiment_phase()
API.run_current_experiment_phase()
# Out:
# [INFO][2024-08-06 13:59:13,382] Experiment phase: training_phase2 of type training starts running...
# [INFO][2024-08-06 13:59:13,383] Sending data to sources
# [INFO][2024-08-06 13:59:16,874] Data is ready in sources
# [INFO][2024-08-06 13:59:16,875] Phase training requested from Main Server
# [INFO][2024-08-06 13:59:37,990] Processing experiment phase data
# [INFO][2024-08-06 13:59:37,998] Processing experiment phase data completed
# [INFO][2024-08-06 13:59:37,999] Start generating communication statistics for training_phase2 of type training
# 33  0.666667  0.666667  0.666667  0.555556  0.666667
# 34  0.666667  0.666667  0.666667  0.588889  0.666667
# 35  0.666667  0.666667  0.666667  0.677778  0.666667
# 36  0.655556  0.666667  0.666667  0.577778  0.666667
# 37  0.633333  0.666667  0.666667  0.777778  0.666667
# 38  0.577778  0.666667  0.666667  0.777778  0.666667
# 39  0.666667  0.666667  0.666667  0.777778  0.666667
# 40  0.633333  0.666667  0.666667  0.777778  0.666667
# 41  0.666667  0.666667  0.666667  0.777778  0.666667
# 42  0.611111  0.666667  0.666667  0.777778  0.666667
# 43  0.666667  0.666667  0.666667  0.777778  0.666667
# 44  0.655556  0.666667  0.588889  0.777778  0.666667
# 45  0.600000  0.666667  0.666667  0.777778  0.666667
# 46  0.666667  0.666667  0.666667  0.777778  0.666667
# 47       NaN  0.666667  0.666667  0.677778  0.666667
# 48       NaN  0.666667  0.666667  0.711111  0.666667
# 49       NaN  0.666667  0.555556  0.666667  0.666667

# %%
import pandas as pd
workers_comm_dict = stats_train2.get_communication_stats_workers()
df_train = pd.DataFrame.from_dict(workers_comm_dict)
plt.figure()
df_selected_train = df_train.iloc[[3,5]]
data_train = pd.melt(df_selected_train.reset_index(), id_vars=['index'], value_vars=df_train.columns)
batches_stats = sns.barplot(x='variable', y='value', hue='index', data=data_train)
plt.ylabel('Number Of Batches')
plt.xlabel('Worker')
plt.title("Received & Dropped Batches At Freq. 5B/s (Training Phase)")

batches_stats.legend(loc='upper right', bbox_to_anchor=(1.5, 0.2), shadow=True, ncol=1)
plt.show()

# %%
API.next_experiment_phase()
API.run_current_experiment_phase()
# Out:
# [INFO][2024-08-06 13:59:39,380] Experiment phase: prediction_phase of type prediction starts running...
# [INFO][2024-08-06 13:59:39,381] Sending data to sources
# [INFO][2024-08-06 13:59:41,593] Data is ready in sources
# [INFO][2024-08-06 13:59:41,594] Phase prediction requested from Main Server
# [INFO][2024-08-06 13:59:50,429] Processing experiment phase data
# [INFO][2024-08-06 13:59:50,437] Processing experiment phase data completed
# [INFO][2024-08-06 13:59:50,438] Start generating communication statistics for prediction_phase of type prediction
# [INFO][2024-08-06 13:59:50,438] Statistics requested from Main Server
# [INFO][2024-08-06 13:59:50,894] Statistics received from Main Server
# [INFO][2024-08-06 13:59:50,896] Phase of prediction_phase prediction completed

# %%
stats_pred = API.get_experiment_flow(exp_name).generate_stats()

# %%
import pandas as pd
workers_comm_dict = stats_pred.get_communication_stats_workers()
df_pred = pd.DataFrame.from_dict(workers_comm_dict)
plt.figure()
df_selected_pred = df_pred.iloc[[4,6]]
data_pred = pd.melt(df_selected_pred.reset_index(), id_vars=['index'], value_vars=df_pred.columns)
batches_stats = sns.barplot(x='variable', y='value', hue='index', data=data_pred)
plt.ylabel('Number Of Batches')
plt.xlabel('Worker')
plt.title("Received & Dropped Batches At Freq. 5B/s (Prediction Phase)")

batches_stats.legend(loc='upper right', bbox_to_anchor=(1.5, 0.2), shadow=True, ncol=1)
plt.show()

# %%
_ , conf_mats = stats_pred.get_confusion_matrices_new(plot=True)
