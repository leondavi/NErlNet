# %% [raw]
# This Experimnet is:
# 18 Devices
# 12 workers
# 6 people- each person send to 2 workers with RR policy
#
# There is one training phase, and one prediction phase

# %%
import set_jupyter_env
from apiServer import *
import pandas as pd

# %%
API = ApiServer()

# %%
API.showJsons()
# Out:
# Distributed Configuration Files
# --------------------
#
# 0.	dc_10w_14d_8r_3s_10c_synt.json
# 1.	dc_AEC_1d_2c_1s_4r_4w.json
# 2.	dc_EEG_18d_12c_6s_10r_12w_RR.json
# 3.	dc_EEG_18d_9c_3s_5r_9w_RR.json
# 4.	dc_EEG_1d_1c_3s_2r_3w_RR.json
# 5.	dc_EEG_4d_3c_3s_2r_3w.json
# 6.	dc_EEG_8d_1c_3s_2r_3w_RR.json
# 7.	dc_EEG_8d_3c_3s_2r_3w.json
# 8.	dc_EEG_8d_3c_3s_2r_3w_RR.json
# 9.	dc_EEG_8d_3c_3s_2r_3w_demo_RR.json
# 10.	dc_EEG_8d_3c_3s_5r_3w_RR.json
# 11.	dc_EEG_8d_8c_3s_5r_8w_RR.json
# 12.	dc_FedTorchTest_5d_2s_2r_4c_4w.json
# 13.	dc_dist_14d.json
# 14.	dc_dist_2d_3c_2s_3r_6w.json
# 15.	dc_fed_dist_14d.json
# 16.	dc_fed_dist_2d_3c_2s_3r_6w.json
# 17.	dc_fed_synt_1d_2c_2r_1s_4w_1ws.json
# 18.	dc_synt_8d_8w_2c_4s_4r.json
# 19.	dc_synt_8d_8w_4c_6r_4s.json
# 20.	dc_synt_distributed_w5_c3_6r_3s_3d.json
# 21.	dc_test_synt_1d_2c_1s_4r_4w.json
# 22.	dc_test_synt_1d_2c_2s_4r_4w.json
#
# Connection Map Files
# --------------------
#
# 0.	conn_1Router1Client1S.json
# 1.	conn_1Router1Client2S.json
# 2.	conn_1Router2Clients1S.json
# 3.	conn_1Router3Clients1S.json
# 4.	conn_1Router4Clients1S.json
# 5.	conn_1Router4Clients1fed.json
# 6.	conn_1Router4Clients2Sources.json
# 7.	conn_1Router4Clients2Sources1fed.json
# 8.	conn_2R4C1S_health_david.json
# 9.	conn_2Router2Clients1Source.json
# 10.	conn_2Router2Clients1Source_david.json
# 11.	conn_2Router2Clients2Source.json
# 12.	conn_2Router2ClientsGUI.json
# 13.	conn_2Router3Clients.json
# 14.	conn_3Router3Clients.json
# 15.	conn_6RouterCycle6Clients1Source.json
# 16.	conn_6RouterCycle8Clients1Source.json
# 17.	conn_6RouterLine6Clients1Source.json
# 18.	conn_8RouterCycle8Clients1Source.json
# 19.	conn_8Routers10Clients3S.json
# 20.	conn_EEG_10Router12Clients6Source_EEG.json
# 21.	conn_EEG_2Router1Clients3Source_EEG.json
# 22.	conn_EEG_2Router3Clients3Source_EEG.json
# 23.	conn_EEG_5Router3Clients3Source_EEG.json
# 24.	conn_EEG_5Router8Clients3Source_EEG.json
# 25.	conn_EEG_5Router9Clients3Source_EEG.json
# 26.	conn_fed_dist_14d.json
# 27.	conn_fed_dist_2d_3c_2s_3r_6w.json
# 28.	conn_fed_synt_1d_2c_2r_1s_4w_1ws.json
# 29.	conn_synt_8d_8w_4c_6r_4s.json
# 30.	conn_synt_dc_8d_8w_2c_4s_4r.json
# 31.	conn_synt_distributed_w5_c3_6r_3s_3d.json
# 32.	conn_test_synt_1d_2c_1s_4r_4w.json
# 33.	conn_test_synt_1d_2c_2s_4r_4w.json
#
# Experiments Flow Files
# --------------------
#
# 0.	exp_AEC_1d_2c_1s_4r_4w.json
# 1.	exp_EEG_3c_3s_2r_3w_3people.json
# 2.	exp_EEG_3c_3s_2r_3w_half3_people.json
# 3.	exp_EEG_3c_3s_2r_3w_half3_people_3exp_tr_phase.json
# 4.	exp_EEG_3c_3s_2r_3w_small_sample_RR.json
# 5.	exp_EEG_3s_3w_half3_people_RR.json
# 6.	exp_EEG_3s_8w_3people_RR.json
# 7.	exp_EEG_3s_8w_half3_people_RR.json
# 8.	exp_EEG_3s_9w_3people_RR.json
# 9.	exp_EEG_6s_12w_12people_RR.json
# 10.	exp_FedTorchTest_5d_2s_2r_4c_4w.json
# 11.	exp_dist_14d.json
# 12.	exp_dist_14d_10c_3s_8r_10w.json
# 13.	exp_dist_2d_3c_2s_3r_6w.json
# 14.	exp_fed_dist_14d.json
# 15.	exp_fed_dist_2d_3c_2s_3r_6w.json
# 16.	exp_fed_synt_1d_2c_2r_1s_4w_1ws.json
# 17.	exp_new_arc.json
# 18.	exp_synt_8d_8w_2c_4s_4r.json
# 19.	exp_synt_8d_8w_4c_6r_4s.json
# 20.	exp_synt_distributed_w5_c3_6r_3s_3d.json
# 21.	exp_test_synt_1d_2c_1s_4r_4w new.json

# %%
dc = 2
conn = 20
exp = 9
API.setJsons(dc , conn , exp)

# %%
dc_path , conn_path , exp_path = API.getUserJsons()

# %%
exp_name = "EEG_Emotion_18Devices_12Persons_RR"
API.initialization(exp_name, dc_path, conn_path, exp_path)
# Out:
# [INFO][2024-08-05 20:37:51,595]
# Network components:
#                  Receiver's Address: http://10.0.0.11:8901
#                  Frequency: 5 [batches/sec]
#                  Batchsize: 10 [samples]
#                  devicesIp: ['10.0.0.11', '10.0.0.8', '10.0.0.12', '10.0.0.10', '10.0.0.32', '10.0.0.33', '10.0.0.34', '10.0.0.35', '10.0.0.47', '10.0.0.48', '10.0.0.49', '10.0.0.50', '10.0.0.51', '10.0.0.52', '10.0.0.53', '10.0.0.54', '10.0.0.55', '10.0.0.56']
#                  mainServerIp: 10.0.0.11
#                  mainServerPort: 8900
#                  apiServerIp: 10.0.0.11
#                  apiServerPort: 8901
#                  Clients: ['c1', 'c2', 'c3', 'c4', 'c5', 'c6', 'c7', 'c8', 'c9', 'c10', 'c11', 'c12']
#                  Workers: ['w1', 'w2', 'w3', 'w4', 'w5', 'w6', 'w7', 'w8', 'w9', 'w10', 'w11', 'w12']
#                  Sources: ['s1', 's2', 's3', 's4', 's5', 's6']
#                  Routers: ['r1', 'r2', 'r3', 'r4', 'r5', 'r6', 'r7', 'r8', 'r9', 'r10']
# [INFO][2024-08-05 20:37:51,596] Connections:
# [INFO][2024-08-05 20:37:51,597] 		 r1 : ['mainServer', 'c1', 'r2', 'r7']
# [INFO][2024-08-05 20:37:51,598] 		 r2 : ['c2', 's1', 'r3']
# [INFO][2024-08-05 20:37:51,599] 		 r3 : ['c3', 's2', 'r4', 'r1']
# [INFO][2024-08-05 20:37:51,600] 		 r4 : ['c4', 's3', 'r5', 'r2']
# [INFO][2024-08-05 20:37:51,600] 		 r5 : ['c5', 's4', 'c9', 'r6']
# [INFO][2024-08-05 20:37:51,601] 		 r6 : ['c6', 's5', 'r7', 'r3']
# [INFO][2024-08-05 20:37:51,601] 		 r7 : ['c7', 's6', 'r8', 'r1']
# [INFO][2024-08-05 20:37:51,602] 		 r8 : ['c8', 'c9', 'r9', 'r4']
# [INFO][2024-08-05 20:37:51,603] 		 r9 : ['c10', 'c11', 'r10', 'r5']
# [INFO][2024-08-05 20:37:51,603] 		 r10 : ['c12', 'r1', 'r6', 'r8']
# [INFO][2024-08-05 20:37:51,604] Experiment name: EEG_Valence_Recognition_DEAP
# [INFO][2024-08-05 20:37:51,604] Batch size: 10
# [INFO][2024-08-05 20:37:51,605] Number of features: 70
# [INFO][2024-08-05 20:37:51,605] Number of labels: 9
# [INFO][2024-08-05 20:37:51,606]
# [INFO][2024-08-05 20:37:51,606] Phases:
# [INFO][2024-08-05 20:37:51,607]    Phase name: training_phase1
# [INFO][2024-08-05 20:37:51,607]    Phase type: training
# [INFO][2024-08-05 20:37:51,608]    Sources: s1,s2,s3,s4,s5,s6
# [INFO][2024-08-05 20:37:51,608]
# [INFO][2024-08-05 20:37:51,610]     Source pieces:
# [INFO][2024-08-05 20:37:51,611]          Source name: s1
# [INFO][2024-08-05 20:37:51,611]          Batch size: 10
# [INFO][2024-08-05 20:37:51,611]          Phase: training
# [INFO][2024-08-05 20:37:51,612]          Starting offset: 10
# [INFO][2024-08-05 20:37:51,612]          Number of batches: 1560
# [INFO][2024-08-05 20:37:51,612]          Workers target: w1,w2
# [INFO][2024-08-05 20:37:51,613]       ----------------------
# [INFO][2024-08-05 20:37:51,613]
# [INFO][2024-08-05 20:37:51,613]          Source name: s2
# [INFO][2024-08-05 20:37:51,614]          Batch size: 10
# [INFO][2024-08-05 20:37:51,614]          Phase: training
# [INFO][2024-08-05 20:37:51,615]          Starting offset: 19520
# [INFO][2024-08-05 20:37:51,615]          Number of batches: 1561
# [INFO][2024-08-05 20:37:51,615]          Workers target: w3,w4
# [INFO][2024-08-05 20:37:51,616]       ----------------------
# [INFO][2024-08-05 20:37:51,616]
# [INFO][2024-08-05 20:37:51,616]          Source name: s3
# [INFO][2024-08-05 20:37:51,617]          Batch size: 10
# [INFO][2024-08-05 20:37:51,617]          Phase: training
# [INFO][2024-08-05 20:37:51,617]          Starting offset: 39040
# [INFO][2024-08-05 20:37:51,618]          Number of batches: 1561
# [INFO][2024-08-05 20:37:51,618]          Workers target: w5,w6
# [INFO][2024-08-05 20:37:51,618]       ----------------------
# [INFO][2024-08-05 20:37:51,619]
# [INFO][2024-08-05 20:37:51,619]          Source name: s4
# [INFO][2024-08-05 20:37:51,620]          Batch size: 10
# [INFO][2024-08-05 20:37:51,620]          Phase: training
# [INFO][2024-08-05 20:37:51,620]          Starting offset: 58650
# [INFO][2024-08-05 20:37:51,621]          Number of batches: 1561
# [INFO][2024-08-05 20:37:51,621]          Workers target: w7,w8
# [INFO][2024-08-05 20:37:51,621]       ----------------------
# [INFO][2024-08-05 20:37:51,622]
# [INFO][2024-08-05 20:37:51,622]          Source name: s5
# [INFO][2024-08-05 20:37:51,622]          Batch size: 10
# [INFO][2024-08-05 20:37:51,623]          Phase: training
# [INFO][2024-08-05 20:37:51,623]          Starting offset: 78170
# [INFO][2024-08-05 20:37:51,624]          Number of batches: 1561
# [INFO][2024-08-05 20:37:51,624]          Workers target: w9,w10
# [INFO][2024-08-05 20:37:51,624]       ----------------------
# [INFO][2024-08-05 20:37:51,625]
# [INFO][2024-08-05 20:37:51,625]          Source name: s6
# [INFO][2024-08-05 20:37:51,625]          Batch size: 10
# [INFO][2024-08-05 20:37:51,626]          Phase: training
# [INFO][2024-08-05 20:37:51,626]          Starting offset: 97690
# [INFO][2024-08-05 20:37:51,626]          Number of batches: 1561
# [INFO][2024-08-05 20:37:51,627]          Workers target: w11,w12
# [INFO][2024-08-05 20:37:51,627]       ----------------------
# [INFO][2024-08-05 20:37:51,628]
# [INFO][2024-08-05 20:37:51,628]    Phase name: prediction_phase
# [INFO][2024-08-05 20:37:51,628]    Phase type: prediction
# [INFO][2024-08-05 20:37:51,629]    Sources: s1,s2,s3,s4,s5,s6
# [INFO][2024-08-05 20:37:51,629]
# [INFO][2024-08-05 20:37:51,629]     Source pieces:
# [INFO][2024-08-05 20:37:51,630]          Source name: s1
# [INFO][2024-08-05 20:37:51,630]          Batch size: 10
# [INFO][2024-08-05 20:37:51,631]          Phase: prediction
# [INFO][2024-08-05 20:37:51,631]          Starting offset: 15610
# [INFO][2024-08-05 20:37:51,631]          Number of batches: 391
# [INFO][2024-08-05 20:37:51,632]          Workers target: w1,w2
# [INFO][2024-08-05 20:37:51,632]       ----------------------
# [INFO][2024-08-05 20:37:51,633]
# [INFO][2024-08-05 20:37:51,633]          Source name: s2
# [INFO][2024-08-05 20:37:51,633]          Batch size: 10
# [INFO][2024-08-05 20:37:51,634]          Phase: prediction
# [INFO][2024-08-05 20:37:51,634]          Starting offset: 35130
# [INFO][2024-08-05 20:37:51,634]          Number of batches: 391
# [INFO][2024-08-05 20:37:51,635]          Workers target: w3,w4
# [INFO][2024-08-05 20:37:51,635]       ----------------------
# [INFO][2024-08-05 20:37:51,635]
# [INFO][2024-08-05 20:37:51,636]          Source name: s3
# [INFO][2024-08-05 20:37:51,636]          Batch size: 10
# [INFO][2024-08-05 20:37:51,637]          Phase: prediction
# [INFO][2024-08-05 20:37:51,637]          Starting offset: 54650
# [INFO][2024-08-05 20:37:51,637]          Number of batches: 391
# [INFO][2024-08-05 20:37:51,638]          Workers target: w5,w6
# [INFO][2024-08-05 20:37:51,638]       ----------------------
# [INFO][2024-08-05 20:37:51,639]
# [INFO][2024-08-05 20:37:51,639]          Source name: s4
# [INFO][2024-08-05 20:37:51,639]          Batch size: 10
# [INFO][2024-08-05 20:37:51,640]          Phase: prediction
# [INFO][2024-08-05 20:37:51,640]          Starting offset: 74260
# [INFO][2024-08-05 20:37:51,640]          Number of batches: 391
# [INFO][2024-08-05 20:37:51,641]          Workers target: w7,w8
# [INFO][2024-08-05 20:37:51,641]       ----------------------
# [INFO][2024-08-05 20:37:51,641]
# [INFO][2024-08-05 20:37:51,642]          Source name: s5
# [INFO][2024-08-05 20:37:51,642]          Batch size: 10
# [INFO][2024-08-05 20:37:51,642]          Phase: prediction
# [INFO][2024-08-05 20:37:51,643]          Starting offset: 93780
# [INFO][2024-08-05 20:37:51,643]          Number of batches: 391
# [INFO][2024-08-05 20:37:51,644]          Workers target: w9,w10
# [INFO][2024-08-05 20:37:51,644]       ----------------------
# [INFO][2024-08-05 20:37:51,644]
# [INFO][2024-08-05 20:37:51,645]          Source name: s6
# [INFO][2024-08-05 20:37:51,645]          Batch size: 10
# [INFO][2024-08-05 20:37:51,645]          Phase: prediction
# [INFO][2024-08-05 20:37:51,646]          Starting offset: 113300
# [INFO][2024-08-05 20:37:51,646]          Number of batches: 391
# [INFO][2024-08-05 20:37:51,647]          Workers target: w11,w12
# [INFO][2024-08-05 20:37:51,647]       ----------------------
# [INFO][2024-08-05 20:37:51,647]
# [INFO][2024-08-05 20:37:51,648] Initializing ApiServer receiver thread
#  * Serving Flask app 'receiver'
#  * Debug mode: off
# [INFO][2024-08-05 20:37:53,656] *** Remember to execute NerlnetRun.sh on each device before running the experiment! ***

# %%
# %pip install networkx pygraphviz
import networkx as nx
def visualize_nerlnet_graph(api_server_inst,  connections : dict , components): # connections is a dictionary with keys as routers and values as lists of their neighbors
    print("Connections: " , list(connections.items()))
    routers = list(connections.keys())
    print("Routers: " , routers)
    workers = list(components.map_worker_to_client.keys())
    print("Workers: " , workers)
    graph = nx.Graph()
    nodes = routers + components.sources + components.clients + workers + [API_SERVER_STR , MAIN_SERVER_STR]
    edges = [] # list of tuples
    for router , neighbors in list(connections.items()):
        for neighbor in neighbors:
            if (router,neighbor) not in edges:
                print(f"Adding edge ({router} , {neighbor}) to graph")
                edges.append((router , neighbor))
    edges.append((API_SERVER_STR , MAIN_SERVER_STR)) # Always connected
    for worker in workers:
        edges.append((worker , components.map_worker_to_client[worker]))
    graph.add_nodes_from(nodes)
    graph.add_edges_from(edges)
    
    my_labels = {'mainServer': 'mS' , 'apiServer': 'aS'}
    nx.relabel_nodes(graph, my_labels , copy=False)
    
    default_colors = {node:'#A90433' for node in graph.nodes()}
    node_colors = {node:default_colors[node] for node in graph.nodes()}
    nx.set_node_attributes(graph, node_colors, 'color')
    colors = nx.get_node_attributes(graph, 'color').values()

    pos = nx.nx_agraph.graphviz_layout(graph)
    angle = 100
    
    plt.figure(figsize=(8,6),dpi=150)
    nx.draw_networkx(graph, pos, with_labels=True, node_color=colors , node_size=200, font_size=8, font_color='white' , edge_color='black' , width=1.5)
    plt.show()
visualize_nerlnet_graph(API , API.json_dir_parser.json_from_path(conn_path)['connectionsMap'] , globe.components)
# Out:
# Requirement already satisfied: networkx in /tmp/nerlnet/virtualenv/lib/python3.8/site-packages (3.1)
# Requirement already satisfied: pygraphviz in /tmp/nerlnet/virtualenv/lib/python3.8/site-packages (1.11)
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Connections:  [('r1', ['mainServer', 'c1', 'r2', 'r7']), ('r2', ['c2', 's1', 'r3']), ('r3', ['c3', 's2', 'r4', 'r1']), ('r4', ['c4', 's3', 'r5', 'r2']), ('r5', ['c5', 's4', 'c9', 'r6']), ('r6', ['c6', 's5', 'r7', 'r3']), ('r7', ['c7', 's6', 'r8', 'r1']), ('r8', ['c8', 'c9', 'r9', 'r4']), ('r9', ['c10', 'c11', 'r10', 'r5']), ('r10', ['c12', 'r1', 'r6', 'r8'])]
# Routers:  ['r1', 'r2', 'r3', 'r4', 'r5', 'r6', 'r7', 'r8', 'r9', 'r10']
# Workers:  ['w1', 'w2', 'w3', 'w4', 'w5', 'w6', 'w7', 'w8', 'w9', 'w10', 'w11', 'w12']
# Adding edge (r1 , mainServer) to graph
# Adding edge (r1 , c1) to graph
# Adding edge (r1 , r2) to graph
# Adding edge (r1 , r7) to graph
# Adding edge (r2 , c2) to graph
# Adding edge (r2 , s1) to graph
# Adding edge (r2 , r3) to graph
# Adding edge (r3 , c3) to graph
# Adding edge (r3 , s2) to graph
# Adding edge (r3 , r4) to graph
# Adding edge (r3 , r1) to graph
# Adding edge (r4 , c4) to graph
# Adding edge (r4 , s3) to graph
# Adding edge (r4 , r5) to graph
# Adding edge (r4 , r2) to graph
# Adding edge (r5 , c5) to graph
# Adding edge (r5 , s4) to graph
# Adding edge (r5 , c9) to graph
# Adding edge (r5 , r6) to graph
# Adding edge (r6 , c6) to graph
# Adding edge (r6 , s5) to graph
# Adding edge (r6 , r7) to graph
# Adding edge (r6 , r3) to graph
# Adding edge (r7 , c7) to graph
# Adding edge (r7 , s6) to graph
# Adding edge (r7 , r8) to graph
# Adding edge (r7 , r1) to graph
# Adding edge (r8 , c8) to graph
# Adding edge (r8 , c9) to graph
# Adding edge (r8 , r9) to graph
# Adding edge (r8 , r4) to graph
# Adding edge (r9 , c10) to graph
# Adding edge (r9 , c11) to graph
# Adding edge (r9 , r10) to graph
# Adding edge (r9 , r5) to graph
# Adding edge (r10 , c12) to graph
# Adding edge (r10 , r1) to graph
# Adding edge (r10 , r6) to graph
# Adding edge (r10 , r8) to graph

# %%
API.send_jsons_to_devices()
# Out:
# [INFO][2024-08-05 20:37:57,587] Sending distributed configurations to devices is completed

# %%
API.run_current_experiment_phase()
# Out:
# [INFO][2024-08-05 20:37:57,593] Experiment phase: training_phase1 of type training starts running...
# [INFO][2024-08-05 20:37:57,595] Sending data to sources
# [INFO][2024-08-05 20:40:09,831] Data is ready in sources
# [INFO][2024-08-05 20:40:09,998] Phase training requested from Main Server
# [INFO][2024-08-05 20:45:21,294] Processing experiment phase data
# [INFO][2024-08-05 20:45:28,940] Processing experiment phase data completed
# [INFO][2024-08-05 20:45:28,941] Start generating communication statistics for training_phase1 of type training
# [INFO][2024-08-05 20:45:28,943] Statistics requested from Main Server
# [INFO][2024-08-05 20:45:29,049] Statistics received from Main Server
# [INFO][2024-08-05 20:45:29,050] Phase of training_phase1 training completed

# %%
stats_train1 = API.get_experiment_flow(exp_name).generate_stats()

# %%
stats_train1.get_loss_ts(plot=True)
# Out:
#            w8        w9        w6       w12       w11        w2        w5  \
# 0    0.444444  0.422222  0.522222  0.444444  0.422222  0.400000  0.477778
# 1    0.555556  0.433333  0.333333  0.555556  0.433333  0.400000  0.400000
# 2    0.644444  0.522222  0.555556  0.644444  0.522222  0.511111  0.400000
# 3    0.355556  0.455556  0.533333  0.433333  0.455556  0.444444  0.511111
# 4    0.344444  0.522222  0.422222  0.511111  0.522222  0.444444  0.444444
# ..        ...       ...       ...       ...       ...       ...       ...
# 772       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 773       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 774       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 775       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 776       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#            w3        w4        w1       w10        w7
# 0    0.477778  0.522222  0.522222  0.444444  0.422222
# 1    0.400000  0.333333  0.333333  0.555556  0.433333
# 2    0.400000  0.555556  0.555556  0.644444  0.522222
# 3    0.511111  0.422222  0.533333  0.433333  0.455556
# 4    0.444444  0.422222  0.422222  0.511111  0.522222
# ..        ...       ...       ...       ...       ...
# 772       NaN  0.077380       NaN       NaN       NaN
# 773       NaN  0.076343       NaN       NaN       NaN
# 774       NaN  0.075485       NaN       NaN       NaN
# 775       NaN  0.074433       NaN       NaN       NaN
# 776       NaN  0.073446       NaN       NaN       NaN
#
# [777 rows x 12 columns]

# %%
import pandas as pd
workers_comm_dict = stats_train1.get_communication_stats_workers()
df_train = pd.DataFrame.from_dict(workers_comm_dict)
plt.figure()
df_selected_train = df_train.iloc[[3,5]]
data_train = pd.melt(df_selected_train.reset_index(), id_vars=['index'], value_vars=df_train.columns)
batches_stats = sns.barplot(x='variable', y='value', hue='index', data=data_train)
plt.ylabel('Number Of Batches')
plt.xlabel('Worker')
plt.title("Received & Dropped Batches At Freq. 5B/s (Training Phase)")

batches_stats.legend(loc='upper right', bbox_to_anchor=(1.5, 0.2), shadow=True, ncol=1)
plt.show()

# %%
missed_dict = stats_train1.get_missed_batches()
print(missed_dict)
# Out:
# {'phase:training_phase1,s1->w2': [663, 673, 679, 687, 693, 697, 701, 713, 715, 717, 721, 727, 733, 735, 743, 745, 749, 755, 757, 761, 765, 769, 773, 777, 781, 787, 789, 793, 797, 801, 805, 809, 813, 817, 821, 825, 831, 833, 837, 845, 847, 853, 855, 859, 863, 867, 871, 875, 881, 883, 891, 893, 899, 901, 907, 909, 913, 917, 923, 925, 929, 933, 945, 947, 951, 957, 961, 967, 969, 975, 979, 983, 987, 991, 995, 999, 1003, 1007, 1011, 1017, 1019, 1023, 1029, 1031, 1035, 1039, 1043, 1047, 1051, 1055, 1059, 1063, 1067, 1071, 1075, 1079, 1083, 1087, 1091, 1099, 1101, 1105, 1109, 1115, 1117, 1121, 1125, 1129, 1133, 1137, 1141, 1145, 1149, 1153, 1157, 1161, 1167, 1171, 1181, 1183, 1191, 1193, 1197, 1201, 1205, 1211, 1215, 1221, 1223, 1227, 1231, 1237, 1241, 1245, 1249, 1253, 1257, 1261, 1265, 1271, 1275, 1283, 1287, 1293, 1297, 1305, 1309, 1313, 1317, 1323, 1327, 1331, 1335, 1339, 1343, 1351, 1365, 1375, 1379, 1385, 1395, 1399, 1403, 1411, 1415, 1419, 1423, 1427, 1431, 1435, 1439, 1443, 1447, 1451, 1455, 1463, 1467, 1471, 1475, 1479, 1485, 1489, 1495, 1499, 1503, 1511, 1515, 1521, 1527, 1531, 1535, 1539, 1543, 1547, 1551, 1555, 1559], 'phase:training_phase1,s1->w1': [12, 24, 240, 290, 320, 396, 414, 426, 458, 514, 552, 590, 636, 660, 676, 690, 696, 704, 716, 720, 722, 726, 732, 738, 744, 746, 750, 756, 760, 764, 768, 772, 776, 778, 782, 792, 794, 796, 800, 808, 810, 814, 818, 826, 828, 832, 836, 840, 858, 860, 862, 864, 866, 868, 872, 878, 884, 886, 890, 894, 898, 902, 906, 912, 914, 920, 922, 930, 932, 934, 938, 942, 946, 948, 950, 954, 960, 962, 968, 970, 976, 978, 982, 988, 992, 996, 1000, 1004, 1008, 1010, 1026, 1028, 1030, 1034, 1042, 1044, 1046, 1050, 1054, 1066, 1068, 1070, 1074, 1078, 1082, 1086, 1090, 1094, 1106, 1124, 1126, 1132, 1136, 1146, 1150, 1152, 1156, 1162, 1164, 1170, 1172, 1178, 1182, 1184, 1190, 1192, 1196, 1200, 1206, 1210, 1214, 1218, 1222, 1226, 1230, 1234, 1238, 1242, 1246, 1250, 1254, 1260, 1264, 1268, 1280, 1284, 1288, 1290, 1294, 1300, 1302, 1306, 1310, 1314, 1318, 1322, 1326, 1330, 1334, 1338, 1342, 1346, 1350, 1354, 1358, 1362, 1366, 1372, 1376, 1382, 1386, 1396, 1402, 1406, 1412, 1416, 1418, 1422, 1436, 1438, 1452, 1458, 1464, 1468, 1472, 1476, 1482, 1486, 1492, 1496, 1516, 1520, 1526, 1530, 1534, 1538, 1558], 'phase:training_phase1,s2->w3': [90, 166, 172, 234, 246, 264, 290, 548, 690, 696, 702, 706, 710, 714, 718, 722, 726, 730, 734, 740, 742, 746, 750, 754, 758, 764, 766, 770, 774, 778, 782, 786, 790, 794, 798, 804, 814, 816, 818, 820, 824, 830, 834, 836, 840, 844, 856, 858, 862, 866, 868, 870, 876, 878, 884, 888, 890, 894, 898, 902, 908, 910, 918, 920, 922, 924, 932, 934, 938, 942, 946, 950, 964, 968, 970, 972, 982, 984, 990, 992, 996, 1000, 1004, 1008, 1014, 1016, 1022, 1030, 1034, 1036, 1046, 1048, 1050, 1054, 1058, 1062, 1066, 1070, 1074, 1078, 1082, 1086, 1090, 1094, 1098, 1102, 1108, 1110, 1114, 1118, 1120, 1124, 1128, 1132, 1136, 1142, 1144, 1148, 1152, 1156, 1164, 1166, 1170, 1174, 1182, 1184, 1186, 1190, 1194, 1198, 1202, 1206, 1210, 1214, 1218, 1222, 1228, 1232, 1236, 1242, 1246, 1250, 1254, 1262, 1264, 1268, 1272, 1276, 1280, 1282, 1288, 1290, 1294, 1298, 1304, 1306, 1312, 1314, 1324, 1326, 1334, 1340, 1344, 1356, 1358, 1362, 1366, 1370, 1374, 1376, 1380, 1392, 1396, 1400, 1406, 1412, 1416, 1420, 1424, 1432, 1436, 1440, 1446, 1454, 1458, 1462, 1470, 1486, 1488, 1492, 1498, 1504, 1508, 1512, 1516, 1520, 1524, 1528, 1532, 1536, 1540, 1546, 1550, 1554, 1560], 'phase:training_phase1,s2->w4': [7, 15, 911], 'phase:training_phase1,s3->w6': [9, 69, 73, 79, 87, 91, 95, 117, 135, 141, 149, 153, 161, 173, 177, 187, 199, 205, 219, 241, 243, 277, 279, 293, 359, 381, 429, 467, 543, 553, 555, 567, 569, 647, 653, 655, 657, 659, 669, 689, 691, 699, 705, 721, 757, 759, 767, 775, 785, 795, 797, 799, 801, 803, 805, 811, 819, 821, 827, 831, 841, 853, 855, 857, 859, 861, 863, 867, 873, 877, 883, 887, 891, 903, 909, 911, 913, 915, 917, 919, 921, 923, 927, 935, 937, 943, 947, 951, 961, 963, 979, 983, 989, 991, 995, 100 ...

# %%
API.next_experiment_phase()
API.run_current_experiment_phase()
# Out:
# [INFO][2024-08-05 20:45:30,340] Experiment phase: prediction_phase of type prediction starts running...
# [INFO][2024-08-05 20:45:30,341] Sending data to sources
# [INFO][2024-08-05 20:45:39,523] Data is ready in sources
# [INFO][2024-08-05 20:45:39,524] Phase prediction requested from Main Server
# [INFO][2024-08-05 20:46:44,127] Processing experiment phase data
# [INFO][2024-08-05 20:46:44,161] Processing experiment phase data completed
# [INFO][2024-08-05 20:46:44,163] Start generating communication statistics for prediction_phase of type prediction
# [INFO][2024-08-05 20:46:44,164] Statistics requested from Main Server
# [INFO][2024-08-05 20:46:44,268] Statistics received from Main Server
# [INFO][2024-08-05 20:46:44,269] Phase of prediction_phase prediction completed

# %%
stats_pred = API.get_experiment_flow(exp_name).generate_stats()

# %%
import pandas as pd
workers_comm_dict = stats_pred.get_communication_stats_workers()
df_pred = pd.DataFrame.from_dict(workers_comm_dict)
plt.figure()
df_selected_pred = df_pred.iloc[[4,6]]
data_pred = pd.melt(df_selected_pred.reset_index(), id_vars=['index'], value_vars=df_pred.columns)
batches_stats = sns.barplot(x='variable', y='value', hue='index', data=data_pred)
plt.ylabel('Number Of Batches')
plt.xlabel('Worker')
plt.title("Received & Dropped Batches At Freq. 5B/s (Prediction Phase)")

batches_stats.legend(loc='upper right', bbox_to_anchor=(1.5, 0.2), shadow=True, ncol=1)
plt.show()

# %%
conf_mats_sources_workers , conf_mats_workers = stats_pred.get_confusion_matrices(plot=True)
# Out:
# [WARNING][2024-08-05 20:46:46,133] missed batches
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 conf_mats_sources_workers , conf_mats_workers = stats_pred.get_confusion_matrices(plot=True)
#
# File /usr/local/lib/nerlnet-lib/NErlNet/src_py/apiServer/stats.py:233, in Stats.get_confusion_matrices(self, normalize, plot, saveToFile)
#     231                     confusion_matrix_worker_dict[(worker_name, class_name)] = confusion_matrix
#     232                 else:
# --> 233                     confusion_matrix_worker_dict[(worker_name, class_name)] += confusion_matrix
#     236 if plot:
#     237     workers = sorted(list({tup[0] for tup in confusion_matrix_worker_dict.keys()}))
#
# ValueError: non-broadcastable output operand with shape (1,1) doesn't match the broadcast shape (2,2)
