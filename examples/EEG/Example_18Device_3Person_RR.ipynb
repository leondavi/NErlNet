# %%
import set_jupyter_env
from apiServer import *
import pandas as pd

# %%
API = ApiServer()

# %%
API.help()
# Out:
# __________NERLNET CHECKLIST__________
# Nerlnet configuration files are located at config directory.
# Make sure data and jsons in correct folder, and jsons include the correct paths
# * Data includes: a single csv that includes all the data for the experiment (training and prediction phases)
# * Jsons include: - distributed configuration (dc_<name>.json)
#                  - connection map (conn_<name>.json)
#                  - experiment flow (exp_<name>.json)
# * Jsons directory: can be defined by changing the config file: config/jsonsDir.nerlconfig
#
# ____________API COMMANDS_____________
# ==========Setting experiment========
#
# -showJsons():                                           lists available json files in jsons directory (dc, conn, exp) to be used with setJsons and getUserJsons
# -list_datasets():                                       reads `hf_repo_ids.json` and list of datasets and files of Nerlnet organizaion on https://huggingface.co/Nerlnet
# -download_dataset(idx, dir):                            downloads dataset files from Huggingface to the specified directory (default is /tmp/nerlnet/data/NerlnetData-master/nerlnet)
# -add_repo_to_datasets_list(repo, name , description):   adds a repository to the datasets list in `hf_repo_ids.json`
# -printArchParams(Num)                                   print description of selected arch file
#
# -selectJsons():                                         get input from user for arch / conn / exp selection
# -setJsons(arch, conn, exp):                             set selected jsons to get their path by getUserJsons
# -getUserJsons():                                        return a tuple of 3 paths to dc, conn, exp jsons that is used for initialization
#
# -initialization(experiment_name, dc, conn, exp_flow, custom_csv_path):
#                                                         setting up the api-server to communicate with main-server of Nerlnet cluster
#                                                         dc - path to distributed configuration file (can be generated by Nerlplanner)
#                                                         conn - path to connection map file, graph of connections between entities
#                                                         exp - path to experiment flow file, defines the flow of the experiment demonstrated as experiment phases of training and prediction
#                                                         custom_csv_path - optional, path to custom csv file for the experiment, overrides the one in experiment flow file
#
# -send_jsons_to_devices():                               send each NerlNet device the dc and conn jsons to init entities on it
# -sendDataToSources(phase(,split)):                      phase := "training" | "prediction". split := 1 default (split) | 2 (whole file). send the experiment data to sources (currently happens in beggining of train/predict)
#
# ======== Running experiment ==========
# -experiment_phase_is_valid()        returns True if there are more experiment phases to run
# -run_current_experiment_phase()     runs the current experiment phase
# -next_experiment_phase()            moves to the next experiment phase
#
# ======== Retrieving statistics ======
# -get_experiment_flow(experiment_name).generate_stats()   returns statistics object (E.g., assigned to StatsInst) class for the current experiment phase
# -StatsInst.get_communication_stats_workers()         returns communication statistics for workers
# -StatsInst.get_communication_stats_sources()         returns communication statistics for sources
# -StatsInst.get_communication_stats_clients()         returns communication statistics for clients
# -StatsInst.get_communication_stats_routers()         returns communication statistics for routers
# -StatsInst.get_communication_stats_main_server()     returns communication statistics for main server
# -StatsInst.get_loss_ts()                             returns the loss over time
# -StatsInst.get_min_loss()                            returns the minimum loss
# -StatsInst.get_missed_batches()                      returns the missed batches
#
# ======== Workers Model Metrics and Performance ========
# -StatsInst.get_confusion_matrices()                  returns tuple of two types of confusion matrices ordered by sources and ordered by workers
# -StatsInst.get_model_performence_stats(confusion_matrix_worker_dict, saveToFile) returns the model performance statistics for the workers

# %%
API.showJsons()
# Out:
# Distributed Configuration Files
# --------------------
#
# 0.	dc_10w_14d_8r_3s_10c_synt.json
# 1.	dc_AEC_1d_2c_1s_4r_4w.json
# 2.	dc_EEG_18d_8c_3s_5r_9w_RR.json
# 3.	dc_EEG_1d_1c_3s_2r_3w_RR.json
# 4.	dc_EEG_4d_3c_3s_2r_3w.json
# 5.	dc_EEG_8d_1c_3s_2r_3w_RR.json
# 6.	dc_EEG_8d_3c_3s_2r_3w.json
# 7.	dc_EEG_8d_3c_3s_2r_3w_RR.json
# 8.	dc_EEG_8d_3c_3s_2r_3w_demo_RR.json
# 9.	dc_EEG_8d_3c_3s_5r_3w_RR.json
# 10.	dc_EEG_8d_8c_3s_5r_8w_RR.json
# 11.	dc_dist_14d.json
# 12.	dc_dist_2d_3c_2s_3r_6w.json
# 13.	dc_fed_dist_14d.json
# 14.	dc_fed_dist_2d_3c_2s_3r_6w.json
# 15.	dc_fed_synt_1d_2c_2r_1s_4w_1ws.json
# 16.	dc_synt_8d_8w_2c_4s_4r.json
# 17.	dc_synt_8d_8w_4c_6r_4s.json
# 18.	dc_synt_distributed_w5_c3_6r_3s_3d.json
# 19.	dc_test_synt_1d_2c_1s_4r_4w.json
# 20.	dc_test_synt_1d_2c_2s_4r_4w.json
#
# Connection Map Files
# --------------------
#
# 0.	conn_1Router1Client1S.json
# 1.	conn_1Router1Client2S.json
# 2.	conn_1Router2Clients1S.json
# 3.	conn_1Router3Clients1S.json
# 4.	conn_1Router4Clients1S.json
# 5.	conn_1Router4Clients1fed.json
# 6.	conn_1Router4Clients2Sources.json
# 7.	conn_1Router4Clients2Sources1fed.json
# 8.	conn_2R4C1S_health_david.json
# 9.	conn_2Router2Clients1Source.json
# 10.	conn_2Router2Clients1Source_david.json
# 11.	conn_2Router2Clients2Source.json
# 12.	conn_2Router2ClientsGUI.json
# 13.	conn_2Router3Clients.json
# 14.	conn_3Router3Clients.json
# 15.	conn_6RouterCycle6Clients1Source.json
# 16.	conn_6RouterCycle8Clients1Source.json
# 17.	conn_6RouterLine6Clients1Source.json
# 18.	conn_8RouterCycle8Clients1Source.json
# 19.	conn_8Routers10Clients3S.json
# 20.	conn_EEG_2Router1Clients3Source_EEG.json
# 21.	conn_EEG_2Router3Clients3Source_EEG.json
# 22.	conn_EEG_5Router3Clients3Source_EEG.json
# 23.	conn_EEG_5Router8Clients3Source_EEG.json
# 24.	conn_EEG_5Router9Clients3Source_EEG.json
# 25.	conn_fed_dist_14d.json
# 26.	conn_fed_dist_2d_3c_2s_3r_6w.json
# 27.	conn_fed_synt_1d_2c_2r_1s_4w_1ws.json
# 28.	conn_synt_8d_8w_4c_6r_4s.json
# 29.	conn_synt_dc_8d_8w_2c_4s_4r.json
# 30.	conn_synt_distributed_w5_c3_6r_3s_3d.json
# 31.	conn_test_synt_1d_2c_1s_4r_4w.json
# 32.	conn_test_synt_1d_2c_2s_4r_4w.json
#
# Experiments Flow Files
# --------------------
#
# 0.	exp_AEC_1d_2c_1s_4r_4w.json
# 1.	exp_EEG_3c_3s_2r_3w_3people.json
# 2.	exp_EEG_3c_3s_2r_3w_half3_people.json
# 3.	exp_EEG_3c_3s_2r_3w_half3_people_3exp_tr_phase.json
# 4.	exp_EEG_3c_3s_2r_3w_small_sample_RR.json
# 5.	exp_EEG_3s_3w_half3_people_RR.json
# 6.	exp_EEG_3s_8w_3people_RR.json
# 7.	exp_EEG_3s_8w_half3_people_RR.json
# 8.	exp_EEG_3s_9w_3people_RR.json
# 9.	exp_dist_14d.json
# 10.	exp_dist_14d_10c_3s_8r_10w.json
# 11.	exp_dist_2d_3c_2s_3r_6w.json
# 12.	exp_fed_dist_14d.json
# 13.	exp_fed_dist_2d_3c_2s_3r_6w.json
# 14.	exp_fed_synt_1d_2c_2r_1s_4w_1ws.json
# 15.	exp_new_arc.json
# 16.	exp_synt_8d_8w_2c_4s_4r.json
# 17.	exp_synt_8d_8w_4c_6r_4s.json
# 18.	exp_synt_distributed_w5_c3_6r_3s_3d.json
# 19.	exp_test_synt_1d_2c_1s_4r_4w new.json

# %%
dc = 2
conn = 24
exp = 8
API.setJsons(dc , conn , exp)

# %%
dc_path , conn_path , exp_path = API.getUserJsons()

# %%
exp_name = "EEG_Emotion_8Devices_3Persons_RR_full"
API.initialization(exp_name, dc_path, conn_path, exp_path)
# Out:
# [INFO][2024-08-03 15:30:54,236]
# Network components:
#                  Receiver's Address: http://10.0.0.11:8901
#                  Frequency: 5 [batches/sec]
#                  Batchsize: 10 [samples]
#                  devicesIp: ['10.0.0.11', '10.0.0.8', '10.0.0.12', '10.0.0.10', '10.0.0.32', '10.0.0.33', '10.0.0.34', '10.0.0.35', '10.0.0.47', '10.0.0.48', '10.0.0.49', '10.0.0.50', '10.0.0.51', '10.0.0.52', '10.0.0.53', '10.0.0.54', '10.0.0.55', '10.0.0.56']
#                  mainServerIp: 10.0.0.11
#                  mainServerPort: 8900
#                  apiServerIp: 10.0.0.11
#                  apiServerPort: 8901
#                  Clients: ['c1', 'c2', 'c3', 'c4', 'c5', 'c6', 'c7', 'c8', 'c9']
#                  Workers: ['w1', 'w2', 'w3', 'w4', 'w5', 'w6', 'w7', 'w8', 'w9']
#                  Sources: ['s1', 's2', 's3']
#                  Routers: ['r1', 'r2', 'r3', 'r4', 'r5']
# [INFO][2024-08-03 15:30:54,237] Connections:
# [INFO][2024-08-03 15:30:54,238] 		 r1 : ['mainServer', 'c1', 'c2', 'r2']
# [INFO][2024-08-03 15:30:54,239] 		 r2 : ['c3', 'c4', 's1', 'r3']
# [INFO][2024-08-03 15:30:54,240] 		 r3 : ['c5', 'c6', 'r4', 'r1']
# [INFO][2024-08-03 15:30:54,240] 		 r4 : ['s2', 'c7', 'r5', 'r2']
# [INFO][2024-08-03 15:30:54,241] 		 r5 : ['s3', 'c8', 'c9', 'r1']
# [INFO][2024-08-03 15:30:54,242] Experiment name: EEG_Valence_Recognition_DEAP
# [INFO][2024-08-03 15:30:54,242] Batch size: 10
# [INFO][2024-08-03 15:30:54,243] Number of features: 70
# [INFO][2024-08-03 15:30:54,243] Number of labels: 9
# [INFO][2024-08-03 15:30:54,244]
# [INFO][2024-08-03 15:30:54,245] Phases:
# [INFO][2024-08-03 15:30:54,245]    Phase name: training_phase
# [INFO][2024-08-03 15:30:54,246]    Phase type: training
# [INFO][2024-08-03 15:30:54,246]    Sources: s1,s2,s3
# [INFO][2024-08-03 15:30:54,247]
# [INFO][2024-08-03 15:30:54,247]     Source pieces:
# [INFO][2024-08-03 15:30:54,252]          Source name: s1
# [INFO][2024-08-03 15:30:54,252]          Batch size: 10
# [INFO][2024-08-03 15:30:54,253]          Phase: training
# [INFO][2024-08-03 15:30:54,253]          Starting offset: 0
# [INFO][2024-08-03 15:30:54,254]          Number of batches: 1561
# [INFO][2024-08-03 15:30:54,257]          Workers target: w1,w4,w7
# [INFO][2024-08-03 15:30:54,258]       ----------------------
# [INFO][2024-08-03 15:30:54,259]
# [INFO][2024-08-03 15:30:54,260]          Source name: s2
# [INFO][2024-08-03 15:30:54,260]          Batch size: 10
# [INFO][2024-08-03 15:30:54,260]          Phase: training
# [INFO][2024-08-03 15:30:54,261]          Starting offset: 19520
# [INFO][2024-08-03 15:30:54,261]          Number of batches: 1561
# [INFO][2024-08-03 15:30:54,262]          Workers target: w2,w5,w8
# [INFO][2024-08-03 15:30:54,267]       ----------------------
# [INFO][2024-08-03 15:30:54,268]
# [INFO][2024-08-03 15:30:54,268]          Source name: s3
# [INFO][2024-08-03 15:30:54,269]          Batch size: 10
# [INFO][2024-08-03 15:30:54,269]          Phase: training
# [INFO][2024-08-03 15:30:54,270]          Starting offset: 39040
# [INFO][2024-08-03 15:30:54,270]          Number of batches: 1561
# [INFO][2024-08-03 15:30:54,271]          Workers target: w3,w6,w9
# [INFO][2024-08-03 15:30:54,271]       ----------------------
# [INFO][2024-08-03 15:30:54,272]
# [INFO][2024-08-03 15:30:54,272]    Phase name: prediction_phase
# [INFO][2024-08-03 15:30:54,273]    Phase type: prediction
# [INFO][2024-08-03 15:30:54,273]    Sources: s1,s2,s3
# [INFO][2024-08-03 15:30:54,274]
# [INFO][2024-08-03 15:30:54,274]     Source pieces:
# [INFO][2024-08-03 15:30:54,275]          Source name: s1
# [INFO][2024-08-03 15:30:54,275]          Batch size: 10
# [INFO][2024-08-03 15:30:54,276]          Phase: prediction
# [INFO][2024-08-03 15:30:54,276]          Starting offset: 15610
# [INFO][2024-08-03 15:30:54,277]          Number of batches: 391
# [INFO][2024-08-03 15:30:54,277]          Workers target: w1,w4,w7
# [INFO][2024-08-03 15:30:54,277]       ----------------------
# [INFO][2024-08-03 15:30:54,278]
# [INFO][2024-08-03 15:30:54,278]          Source name: s2
# [INFO][2024-08-03 15:30:54,279]          Batch size: 10
# [INFO][2024-08-03 15:30:54,279]          Phase: prediction
# [INFO][2024-08-03 15:30:54,280]          Starting offset: 35130
# [INFO][2024-08-03 15:30:54,280]          Number of batches: 391
# [INFO][2024-08-03 15:30:54,281]          Workers target: w2,w5,w8
# [INFO][2024-08-03 15:30:54,281]       ----------------------
# [INFO][2024-08-03 15:30:54,282]
# [INFO][2024-08-03 15:30:54,282]          Source name: s3
# [INFO][2024-08-03 15:30:54,283]          Batch size: 10
# [INFO][2024-08-03 15:30:54,283]          Phase: prediction
# [INFO][2024-08-03 15:30:54,283]          Starting offset: 54650
# [INFO][2024-08-03 15:30:54,284]          Number of batches: 391
# [INFO][2024-08-03 15:30:54,284]          Workers target: w3,w6,w9
# [INFO][2024-08-03 15:30:54,285]       ----------------------
# [INFO][2024-08-03 15:30:54,285]
# [INFO][2024-08-03 15:30:54,286] Initializing ApiServer receiver thread
#  * Serving Flask app 'receiver'
#  * Debug mode: off
# [INFO][2024-08-03 15:30:56,287] *** Remember to execute NerlnetRun.sh on each device before running the experiment! ***

# %%
# %pip install networkx pygraphviz
import networkx as nx
def visualize_nerlnet_graph(api_server_inst,  connections : dict , components): # connections is a dictionary with keys as routers and values as lists of their neighbors
    print("Connections: " , list(connections.items()))
    routers = list(connections.keys())
    print("Routers: " , routers)
    workers = list(components.map_worker_to_client.keys())
    print("Workers: " , workers)
    graph = nx.Graph()
    nodes = routers + components.sources + components.clients + workers + [API_SERVER_STR , MAIN_SERVER_STR]
    edges = [] # list of tuples
    for router , neighbors in list(connections.items()):
        for neighbor in neighbors:
            if (router,neighbor) not in edges:
                print(f"Adding edge ({router} , {neighbor}) to graph")
                edges.append((router , neighbor))
    edges.append((API_SERVER_STR , MAIN_SERVER_STR)) # Always connected
    for worker in workers:
        edges.append((worker , components.map_worker_to_client[worker]))
    graph.add_nodes_from(nodes)
    graph.add_edges_from(edges)
    
    my_labels = {'mainServer': 'mS' , 'apiServer': 'aS'}
    nx.relabel_nodes(graph, my_labels , copy=False)
    
    default_colors = {node:'#A90433' for node in graph.nodes()}
    node_colors = {node:default_colors[node] for node in graph.nodes()}
    nx.set_node_attributes(graph, node_colors, 'color')
    colors = nx.get_node_attributes(graph, 'color').values()

    pos = nx.nx_agraph.graphviz_layout(graph)
    angle = 100
    
    plt.figure(figsize=(8,6),dpi=150)
    nx.draw_networkx(graph, pos, with_labels=True, node_color=colors , node_size=200, font_size=8, font_color='white' , edge_color='black' , width=1.5)
    plt.show()
visualize_nerlnet_graph(API , API.json_dir_parser.json_from_path(conn_path)['connectionsMap'] , globe.components)
# Out:
# Requirement already satisfied: networkx in /tmp/nerlnet/virtualenv/lib/python3.8/site-packages (3.1)
# Requirement already satisfied: pygraphviz in /tmp/nerlnet/virtualenv/lib/python3.8/site-packages (1.11)
#
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Connections:  [('r1', ['mainServer', 'c1', 'c2', 'r2']), ('r2', ['c3', 'c4', 's1', 'r3']), ('r3', ['c5', 'c6', 'r4', 'r1']), ('r4', ['s2', 'c7', 'r5', 'r2']), ('r5', ['s3', 'c8', 'c9', 'r1'])]
# Routers:  ['r1', 'r2', 'r3', 'r4', 'r5']
# Workers:  ['w1', 'w2', 'w3', 'w4', 'w5', 'w6', 'w7', 'w8', 'w9']
# Adding edge (r1 , mainServer) to graph
# Adding edge (r1 , c1) to graph
# Adding edge (r1 , c2) to graph
# Adding edge (r1 , r2) to graph
# Adding edge (r2 , c3) to graph
# Adding edge (r2 , c4) to graph
# Adding edge (r2 , s1) to graph
# Adding edge (r2 , r3) to graph
# Adding edge (r3 , c5) to graph
# Adding edge (r3 , c6) to graph
# Adding edge (r3 , r4) to graph
# Adding edge (r3 , r1) to graph
# Adding edge (r4 , s2) to graph
# Adding edge (r4 , c7) to graph
# Adding edge (r4 , r5) to graph
# Adding edge (r4 , r2) to graph
# Adding edge (r5 , s3) to graph
# Adding edge (r5 , c8) to graph
# Adding edge (r5 , c9) to graph
# Adding edge (r5 , r1) to graph

# %%
API.send_jsons_to_devices()
# Out:
# [INFO][2024-08-03 15:31:00,301] Sending distributed configurations to devices is completed

# %%
API.run_current_experiment_phase()
# Out:
# [INFO][2024-08-03 15:31:00,309] Experiment phase: training_phase of type training starts running...
# [INFO][2024-08-03 15:31:00,311] Sending data to sources
# [INFO][2024-08-03 15:32:11,171] Data is ready in sources
# [INFO][2024-08-03 15:32:11,318] Phase training requested from Main Server
# [INFO][2024-08-03 15:36:19,738] Processing experiment phase data
# [INFO][2024-08-03 15:36:26,895] Processing experiment phase data completed
# [INFO][2024-08-03 15:36:26,896] Start generating communication statistics for training_phase of type training
# [INFO][2024-08-03 15:36:26,898] Statistics requested from Main Server
# [INFO][2024-08-03 15:36:27,003] Statistics received from Main Server
# [INFO][2024-08-03 15:36:27,005] Phase of training_phase training completed

# %%
stats_train = API.get_experiment_flow(exp_name).generate_stats()

# %%
missed_dict = stats_train.get_missed_batches()

# %%
stats_train.get_loss_ts(plot=True)
# Out:
#            w3        w2        w5        w1        w6        w7        w8  \
# 0    0.666667  0.444444  0.544444  0.477778  0.666667  0.388889  0.533333
# 1    0.555556  0.444444  0.444444  0.333333  0.555556  0.555556  0.444444
# 2    0.555556  0.444444  0.444444  0.511111  0.555556  0.444444  0.444444
# 3    0.622222  0.444444  0.444444  0.422222  0.566667  0.433333  0.411111
# 4    0.555556  0.444444  0.400000  0.555556  0.555556  0.644444  0.444444
# ..        ...       ...       ...       ...       ...       ...       ...
# 516       NaN  0.093879  0.103785  0.069665  0.103082  0.066839  0.090858
# 517       NaN  0.091944  0.101569  0.068308  0.100671  0.065109  0.089097
# 518       NaN  0.090096  0.099408  0.067079  0.098306  0.063649  0.087470
# 519       NaN  0.088278  0.097302  0.065757  0.096039  0.062007  0.085840
# 520       NaN  0.086524       NaN  0.064538       NaN       NaN       NaN
#
#            w4        w9
# 0    0.511111  0.633333
# 1    0.422222  0.555556
# 2    0.522222  0.611111
# 3    0.444444  0.555556
# 4    0.522222  0.588889
# ..        ...       ...
# 516  0.070226  0.105061
# 517  0.068602  0.103023
# 518  0.066987  0.101027
# 519  0.065337  0.099057
# 520       NaN       NaN
#
# [521 rows x 9 columns]

# %%
import pandas as pd
workers_comm_dict = stats_train.get_communication_stats_workers()
df_train = pd.DataFrame.from_dict(workers_comm_dict)
plt.figure()
df_selected_train = df_train.iloc[[3,5]]
data_train = pd.melt(df_selected_train.reset_index(), id_vars=['index'], value_vars=df_train.columns)
batches_stats = sns.barplot(x='variable', y='value', hue='index', data=data_train)
plt.ylabel('Number Of Batches')
plt.xlabel('Worker')
plt.title("Received & Dropped Batches At Freq. 5B/s (Training Phase)")

batches_stats.legend(loc='upper right', bbox_to_anchor=(1.5, 0.2), shadow=True, ncol=1)
plt.show()

# %%
print(missed_dict)
# Out:
# {'phase:training_phase,s3->w3': [1209, 1212, 1218, 1224, 1230, 1239, 1242, 1248, 1254, 1260, 1266, 1332, 1338, 1344, 1353, 1359, 1368]}

# %%
API.next_experiment_phase()
API.run_current_experiment_phase()
# Out:
# [INFO][2024-08-03 15:36:28,181] Experiment phase: prediction_phase of type prediction starts running...
# [INFO][2024-08-03 15:36:28,182] Sending data to sources
# [INFO][2024-08-03 15:36:33,324] Data is ready in sources
# [INFO][2024-08-03 15:36:33,325] Phase prediction requested from Main Server
# [INFO][2024-08-03 15:37:34,405] Processing experiment phase data
# [INFO][2024-08-03 15:37:34,424] Processing experiment phase data completed
# [INFO][2024-08-03 15:37:34,425] Start generating communication statistics for prediction_phase of type prediction
# [INFO][2024-08-03 15:37:34,426] Statistics requested from Main Server
# [INFO][2024-08-03 15:37:34,630] Statistics received from Main Server
# [INFO][2024-08-03 15:37:34,631] Phase of prediction_phase prediction completed

# %%
stats_pred = API.get_experiment_flow(exp_name).generate_stats()

# %%
import pandas as pd
workers_comm_dict = stats_pred.get_communication_stats_workers()
df_pred = pd.DataFrame.from_dict(workers_comm_dict)
plt.figure()
df_selected_pred = df_pred.iloc[[4,6]]
data_pred = pd.melt(df_selected_pred.reset_index(), id_vars=['index'], value_vars=df_pred.columns)
batches_stats = sns.barplot(x='variable', y='value', hue='index', data=data_pred)
plt.ylabel('Number Of Batches')
plt.xlabel('Worker')
plt.title("Received & Dropped Batches At Freq. 5B/s (Prediction Phase)")

batches_stats.legend(loc='upper right', bbox_to_anchor=(1.5, 0.2), shadow=True, ncol=1)
plt.show()

# %%
missed_predict_dict = stats_pred.get_missed_batches()

# %%
print(missed_predict_dict)
# Out:
# {}

# %%
conf_mats_sources_workers , conf_mats_workers = stats_pred.get_confusion_matrices(plot=True)
# Out:
# [WARNING][2024-08-03 15:37:35,473] missed batches

# %%
model_perf = stats_pred.get_model_performence_stats(conf_mats_workers, show=True)
# Out:
# worker w7 class: 6 has only one class, skipping
# worker w7 class: 7 has only one class, skipping
# worker w7 class: 8 has only one class, skipping
# worker w7 class: 9 has only one class, skipping
# worker w4 class: 6 has only one class, skipping
# worker w4 class: 7 has only one class, skipping
# worker w4 class: 8 has only one class, skipping
# worker w4 class: 9 has only one class, skipping
# worker w1 class: 6 has only one class, skipping
# worker w1 class: 7 has only one class, skipping
# worker w1 class: 8 has only one class, skipping
# worker w1 class: 9 has only one class, skipping
# worker w5 class: 3 has only one class, skipping
# worker w5 class: 7 has only one class, skipping
# worker w5 class: 8 has only one class, skipping
# worker w5 class: 9 has only one class, skipping
# worker w2 class: 3 has only one class, skipping
# worker w2 class: 7 has only one class, skipping
# worker w2 class: 8 has only one class, skipping
# worker w2 class: 9 has only one class, skipping
# worker w8 class: 3 has only one class, skipping
# worker w8 class: 7 has only one class, skipping
# worker w8 class: 8 has only one class, skipping
# worker w8 class: 9 has only one class, skipping
# worker w3 class: 2 has only one class, skipping
# worker w3 class: 6 has only one class, skipping
# worker w3 class: 7 has only one class, skipping
# worker w3 class: 8 has only one class, skipping
# worker w3 class: 9 has only one class, skipping
# worker w6 class: 2 has only one class, skipping
# worker w6 class: 6 has only one class, skipping
# worker w6 class: 7 has only one class, skipping
# worker w6 class: 8 has only one class, skipping
# worker w6 class: 9 has only one class, skipping
# worker w9 class: 2 has only one class, skipping
# worker w9 class: 6 has only one class, skipping
# worker w9 class: 7 has only one class, skipping
# worker w9 class: 8 has only one class, skipping
# worker w9 class: 9 has only one class, skipping
# <style type="text/css">
# #T_c28b8 th {
#   text-align: center;
# }
# #T_c28b8 th.col_heading {
#   text-align: center;
# }
# #T_c28b8 th.row_heading {
#   text-align: center;
# }
# #T_c28b8_row0_col0, #T_c28b8_row0_col1, #T_c28b8_row0_col2, #T_c28b8_row0_col3, #T_c28b8_row0_col4, #T_c28b8_row0_col5, #T_c28b8_row0_col6, #T_c28b8_row0_col7, #T_c28b8_row0_col8, #T_c28b8_row0_col9, #T_c28b8_row0_col10, #T_c28b8_row0_col11, #T_c28b8_row0_col12, #T_c28b8_row1_col0, #T_c28b8_row1_col1, #T_c28b8_row1_col2, #T_c28b8_row1_col3, #T_c28b8_row1_col4, #T_c28b8_row1_col5, #T_c28b8_row1_col6, #T_c28b8_row1_col7, #T_c28b8_row1_col8, #T_c28b8_row1_col9, #T_c28b8_row1_col10, #T_c28b8_row1_col11, #T_c28b8_row1_col12, #T_c28b8_row2_col0, #T_c28b8_row2_col1, #T_c28b8_row2_col2, #T_c28b8_row2_col3, #T_c28b8_row2_col4, #T_c28b8_row2_col5, #T_c28b8_row2_col6, #T_c28b8_row2_col7, #T_c28b8_row2_col8, #T_c28b8_row2_col9, #T_c28b8_row2_col10, #T_c28b8_row2_col11, #T_c28b8_row2_col12, #T_c28b8_row3_col0, #T_c28b8_row3_col1, #T_c28b8_row3_col2, #T_c28b8_row3_col3, #T_c28b8_row3_col4, #T_c28b8_row3_col5, #T_c28b8_row3_col6, #T_c28b8_row3_col7, #T_c28b8_row3_col8, #T_c28b8_row3_col9, #T_c28b8_row3_col10, #T_c28b8_row3_col11, #T_c28b8_row3_col12, #T_c28b8_row4_col0, #T_c28b8_row4_col1, #T_c28b8_row4_col2, #T_c28b8_row4_col3, #T_c28b8_row4_col4, #T_c28b8_row4_col5, #T_c28b8_row4_col6, #T_c28b8_row4_col7, #T_c28b8_row4_col8, #T_c28b8_row4_col9, #T_c28b8_row4_col10, #T_c28b8_row4_col11, #T_c28b8_row4_col12, #T_c28b8_row5_col0, #T_c28b8_row5_col1, #T_c28b8_row5_col2, #T_c28b8_row5_col3, #T_c28b8_row5_col4, #T_c28b8_row5_col5, #T_c28b8_row5_col6, #T_c28b8_row5_col7, #T_c28b8_row5_col8, #T_c28b8_row5_col9, #T_c28b8_row5_col10, #T_c28b8_row5_col11, #T_c28b8_row5_col12, #T_c28b8_row6_col0, #T_c28b8_row6_col1, #T_c28b8_row6_col2, #T_c28b8_row6_col3, #T_c28b8_row6_col4, #T_c28b8_row6_col5, #T_c28b8_row6_col6, #T_c28b8_row6_col7, #T_c28b8_row6_col8, #T_c28b8_row6_col9, #T_c28b8_row6_col10, #T_c28b8_row6_col11, #T_c28b8_row6_col12, #T_c28b8_row7_col0, #T_c28b8_row7_col1, #T_c28b8_row7_col2, #T_c28b8_row7_col3, #T_c28b8_row7_col4, #T_c28b8_row7_col5, #T_c28b8_row7_col6, #T_c28b8_row7_col7, #T_c28b8_row7_col8, #T_c28b8_row7_col9, #T_c28b8_row7_col10, #T_c28b8_row7_col11, #T_c28b8_row7_col12, #T_c28b8_row8_col0, #T_c28b8_row8_col1, #T_c28b8_row8_col2, #T_c28b8_row8_col3, #T_c28b8_row8_col4, #T_c28b8_row8_col5, #T_c28b8_row8_col6, #T_c28b8_row8_col7, #T_c28b8_row8_col8, #T_c28b8_row8_col9, #T_c28b8_row8_col10, #T_c28b8_row8_col11, #T_c28b8_row8_col12, #T_c28b8_row9_col0, #T_c28b8_row9_col1, #T_c28b8_row9_col2, #T_c28b8_row9_col3, #T_c28b8_row9_col4, #T_c28b8_row9_col5, #T_c28b8_row9_col6, #T_c28b8_row9_col7, #T_c28b8_row9_col8, #T_c28b8_row9_col9, #T_c28b8_row9_col10, #T_c28b8_row9_col11, #T_c28b8_row9_col12, #T_c28b8_row10_col0, #T_c28b8_row10_col1, #T_c28b8_row10_col2, #T_c28b8_row10_col3, #T_c28b8_row10_col4, #T_c28b8_row10_col5, #T_c28b8_row10_col6, #T_c28b8_row10_col7, #T_c28b8_row10_col8, #T_c28b8_row10_col9, #T_c28b8_row10_col10, #T_c28b8_row10_col11, #T_c28b8_row10_col12, #T_c28b8_row11_col0, #T_c28b8_row11_col1, #T_c28b8_row11_col2, #T_c28b8_row11_col3, #T_c28b8_row11_col4, #T_c28b8_row11_col5, #T_c28b8_row11_col6, #T_c28b8_row11_col7, #T_c28b8_row11_col8, #T_c28b8_row11_col9, #T_c28b8_row11_col10, #T_c28b8_row11_col11, #T_c28b8_row11_col12, #T_c28b8_row12_col0, #T_c28b8_row12_col1, #T_c28b8_row12_col2, #T_c28b8_row12_col3, #T_c28b8_row12_col4, #T_c28b8_row12_col5, #T_c28b8_row12_col6, #T_c28b8_row12_col7, #T_c28b8_row12_col8, #T_c28b8_row12_col9, #T_c28b8_row12_col10, #T_c28b8_row12_col11, #T_c28b8_row12_col12, #T_c28b8_row13_col0, #T_c28b8_row13_col1, #T_c28b8_row13_col2, #T_c28b8_row13_col3, #T_c28b8_row13_col4, #T_c28b8_row13_col5, #T_c28b8_row13_col6, #T_c28b8_row13_col7, #T_c28b8_row13_col8, #T_c28b8_row13_col9, #T_c28b8_row13_col10, #T_c28b8_row13_col11, #T_c28b8_row13_col12, #T_c28b8_row14_col0, #T_c28b8_row14_col1, #T_c28b8_row14_col2, #T_c28b8_row14_col3, #T_c28b8_row14_col4, #T_c28b8_row14_col5, #T_c28b8_row14_col6, #T_c28b8_row14_col7, #T_c28b8_row14_col8, #T_c28b8_row14_col9, #T_c28b8_row14_col10, #T_c28b8_row14_col11, #T_c28b8_row ...

# %%
sns.barplot(data=model_perf.sort_values('Worker') , x='Worker' , y='F1',hue='Class')
# Out:
# <Axes: xlabel='Worker', ylabel='F1'>
